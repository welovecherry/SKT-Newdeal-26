# %% [markdown]
# # <mark>9/23 오전 추가 챌린지 · 가장 많은 로그인 실패가 발생한 IP 찾기</mark>
#
# 하나의 로그 사건을 여러 단계로 조사합니다.
#
# 1. 각 문제는 바로 앞 문제에서 만든 결과를 이어받습니다.
# 2. 위에서 아래로 셀을 차례대로 실행합니다.
# 3. 한 문제 셀에서는 의미 있는 결과 하나만 만듭니다.
# 4. 문제에 적힌 변수 이름은 다음 문제에서도 사용하므로 그대로 씁니다.

# %% [markdown]
# ## <mark>데이터 준비</mark>
#
# 아래 셀을 먼저 실행하세요. 로그인 성공과 파일 열기 실패도 섞여 있으므로 `result`만 보고 고르면 안 됩니다.

# %%
logs = [
    {"time": "09:01", "user": "kim01", "ip": "10.0.3.21", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:02", "user": "lee02", "ip": "10.0.7.5", "action": "LOGIN", "result": "OK"},
    {"time": "09:03", "user": "kim01", "ip": "10.0.3.21", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:04", "user": "park03", "ip": "10.0.9.8", "action": "FILE_OPEN", "result": "FAIL"},
    {"time": "09:05", "user": "lee02", "ip": "10.0.3.21", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:06", "user": "park03", "ip": "10.0.9.8", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:07", "user": "kim01", "ip": "10.0.8.15", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:08", "user": "park03", "ip": "10.0.9.8", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:09", "user": "choi04", "ip": "10.0.3.21", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:10", "user": "kim01", "ip": "10.0.3.21", "action": "FILE_OPEN", "result": "FAIL"},
    {"time": "09:11", "user": "choi04", "ip": "10.0.7.7", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:12", "user": "lee02", "ip": "10.0.7.5", "action": "FILE_OPEN", "result": "OK"},
    {"time": "09:13", "user": "admin", "ip": "10.0.1.1", "action": "LOGIN", "result": "OK"},
    {"time": "09:14", "user": "kim01", "ip": "10.0.3.21", "action": "LOGIN", "result": "OK"},
]

print(f"데이터 준비: {len(logs)}건")

# %% [markdown]
# ---
#
# ## <mark>지금 바로 풀기 · 2교시까지 배운 문법</mark>
#
# `if`, `and`, `for`, 빈 리스트, `append`, `len`만 사용합니다.

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 챌린지 1 · 로그인 실패 로그를 담을 빈 리스트 만들기</font></h3></td></tr></table>
#
# 다음 문제에서 로그인 실패 로그를 모을 준비를 합니다.
#
# 1. 아무 값도 들어 있지 않은 빈 리스트를 만드세요.
# 2. 리스트 이름은 반드시 `failed_logs`로 정하세요.
# 3. 만든 리스트를 `print()`로 출력하세요.
#
# | | |
# |---|---|
# | 주어지는 값 | 없음 |
# | 나와야 하는 결과 | `[]` |

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 챌린지 2 · 로그인 실패 로그만 모으기</font></h3></td></tr></table>
#
# 전체 로그에서 로그인 실패 기록만 골라 문제 1의 `failed_logs`에 넣으세요.
#
# 1. `logs`에서 로그 딕셔너리를 하나씩 꺼내 반복하세요.
# 2. 각 로그의 `action`이 `LOGIN`인지 확인하세요.
# 3. 같은 로그의 `result`가 `FAIL`인지 `and`로 함께 확인하세요.
# 4. 두 조건이 모두 참이면 로그 딕셔너리 전체를 `failed_logs`에 추가하세요.
# 5. 반복이 끝나면 `len(failed_logs)`를 사용해 건수를 출력하세요.
#
# `FILE_OPEN`의 결과가 `FAIL`인 로그는 넣으면 안 됩니다.
#
# | | |
# |---|---|
# | 주어지는 값 | 위 `logs` · 문제 1의 `failed_logs` |
# | 나와야 하는 결과 | `로그인 실패: 8건` |

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 챌린지 3 · 로그인 실패가 발생한 IP만 모으기</font></h3></td></tr></table>
#
# 문제 2에서 만든 `failed_logs`에서 IP 값만 꺼내 새 목록으로 만드세요.
#
# 1. IP를 담을 빈 리스트 `failed_ips`를 만드세요.
# 2. `failed_logs`에서 로그인 실패 로그를 하나씩 꺼내 반복하세요.
# 3. 각 로그의 `ip` 값을 `failed_ips`에 추가하세요.
# 4. 반복이 끝나면 `failed_ips`를 출력하세요.
#
# | | |
# |---|---|
# | 주어지는 값 | 문제 2의 `failed_logs` |
# | 나와야 하는 결과 | `['10.0.3.21', '10.0.3.21', '10.0.3.21', '10.0.9.8', '10.0.8.15', '10.0.9.8', '10.0.3.21', '10.0.7.7']` |

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# ---
#
# ## <mark>3교시 수업 뒤에 풀기 · 집합과 Counter</mark>
#
# 아래 문제는 `Counter`, `.items()`, `set`을 배운 뒤에 풉니다.

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 챌린지 4 · IP별 로그인 실패 횟수 만들기</font></h3></td></tr></table>
#
# 문제 3의 `failed_ips`를 사용해 IP별 로그인 실패 횟수를 만드세요.
#
# 1. `collections`에서 `Counter`를 가져오세요.
# 2. `Counter`에 `failed_ips`를 넣으세요.
# 3. 결과를 `ip_counts`라는 이름에 저장하세요.
# 4. 완성된 `ip_counts`를 출력하세요.
#
# | | |
# |---|---|
# | 주어지는 값 | 문제 3의 `failed_ips` |
# | 나와야 하는 결과 | `Counter({'10.0.3.21': 4, '10.0.9.8': 2, '10.0.8.15': 1, '10.0.7.7': 1})` |

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 챌린지 5 · 실패가 가장 많은 IP 직접 찾기</font></h3></td></tr></table>
#
# 문제 4의 `ip_counts`에서 로그인 실패가 가장 많이 발생한 IP를 찾으세요.
#
# 1. IP를 기억할 변수 `top_ip`에 빈 문자열을 저장하세요.
# 2. 가장 큰 횟수를 기억할 변수 `top_count`에 `0`을 저장하세요.
# 3. `ip_counts.items()`로 IP와 횟수를 하나씩 꺼내 반복하세요.
# 4. 현재 횟수가 `top_count`보다 크면 `top_ip`와 `top_count`를 현재 값으로 바꾸세요.
# 5. 반복이 끝난 뒤 최종 IP와 횟수를 출력하세요.
#
# `max()`, `sorted()`, `most_common()`은 사용하지 마세요.
#
# | | |
# |---|---|
# | 주어지는 값 | 문제 4의 `ip_counts` |
# | 나와야 하는 결과 | `가장 많은 실패: 10.0.3.21 · 4회` |

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 챌린지 6 · 최다 실패 IP에서 실패한 계정 모으기</font></h3></td></tr></table>
#
# 문제 5에서 찾은 `top_ip`에서 로그인에 실패한 계정만 모으세요.
#
# 1. 계정을 담을 빈 리스트 `top_ip_users`를 만드세요.
# 2. 문제 2의 `failed_logs`를 하나씩 반복하세요.
# 3. 각 로그의 `ip`가 `top_ip`와 같은지 확인하세요.
# 4. 같으면 해당 로그의 `user` 값을 `top_ip_users`에 추가하세요.
# 5. 반복이 끝나면 `top_ip_users`를 출력하세요.
#
# | | |
# |---|---|
# | 주어지는 값 | 문제 2의 `failed_logs` · 문제 5의 `top_ip` |
# | 나와야 하는 결과 | `['kim01', 'kim01', 'lee02', 'choi04']` |

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 챌린지 7 · 서로 다른 실패 계정 수 구하기</font></h3></td></tr></table>
#
# 문제 6의 `top_ip_users`에는 같은 계정이 여러 번 들어 있을 수 있습니다. 서로 다른 계정이 몇 명인지 구하세요.
#
# 1. `set()`으로 `top_ip_users`의 중복을 없애세요.
# 2. 중복을 없앤 결과의 길이를 구하세요.
# 3. 그 숫자를 `top_ip_user_count`에 저장하세요.
# 4. 서로 다른 계정 수를 출력하세요.
#
# | | |
# |---|---|
# | 주어지는 값 | 문제 6의 `top_ip_users` |
# | 나와야 하는 결과 | `서로 다른 실패 계정: 3명` |

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 챌린지 8 · 여러 계정을 노린 공격인지 판정하기</font></h3></td></tr></table>
#
# 문제 5와 문제 7의 결과를 사용해 최다 실패 IP의 위험도를 판정하세요.
#
# 1. `top_count`가 4 이상이면서 `top_ip_user_count`가 3 이상이면 `level`에 `여러 계정 공격 의심`을 저장하세요.
# 2. 첫 조건에는 해당하지 않지만 `top_count`가 2 이상이면 `level`에 `반복 실패`를 저장하세요.
# 3. 두 조건에 모두 해당하지 않으면 `level`에 `낮음`을 저장하세요.
# 4. 판정 결과를 출력하세요.
#
# | | |
# |---|---|
# | 주어지는 값 | 문제 5의 `top_count` · 문제 7의 `top_ip_user_count` |
# | 나와야 하는 결과 | `판정: 여러 계정 공격 의심` |

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# ---
#
# # <mark>정답 · 먼저 문제를 모두 풀어 본 뒤에 엽니다</mark>
#
# 각 정답 셀의 「코드 표시」를 눌러 확인하세요.

# %%
#@title 정답 챌린지 1 { display-mode: "form" }
failed_logs = []
print(failed_logs)

# %%
#@title 정답 챌린지 2 { display-mode: "form" }
logs = [
    {"time": "09:01", "user": "kim01", "ip": "10.0.3.21", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:02", "user": "lee02", "ip": "10.0.7.5", "action": "LOGIN", "result": "OK"},
    {"time": "09:03", "user": "kim01", "ip": "10.0.3.21", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:04", "user": "park03", "ip": "10.0.9.8", "action": "FILE_OPEN", "result": "FAIL"},
    {"time": "09:05", "user": "lee02", "ip": "10.0.3.21", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:06", "user": "park03", "ip": "10.0.9.8", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:07", "user": "kim01", "ip": "10.0.8.15", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:08", "user": "park03", "ip": "10.0.9.8", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:09", "user": "choi04", "ip": "10.0.3.21", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:10", "user": "kim01", "ip": "10.0.3.21", "action": "FILE_OPEN", "result": "FAIL"},
    {"time": "09:11", "user": "choi04", "ip": "10.0.7.7", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:12", "user": "lee02", "ip": "10.0.7.5", "action": "FILE_OPEN", "result": "OK"},
    {"time": "09:13", "user": "admin", "ip": "10.0.1.1", "action": "LOGIN", "result": "OK"},
    {"time": "09:14", "user": "kim01", "ip": "10.0.3.21", "action": "LOGIN", "result": "OK"},
]
failed_logs = []
for log in logs:
    if log["action"] == "LOGIN" and log["result"] == "FAIL":
        failed_logs.append(log)
print(f"로그인 실패: {len(failed_logs)}건")

# %%
#@title 정답 챌린지 3 { display-mode: "form" }
failed_logs = [
    {"user": "kim01", "ip": "10.0.3.21"},
    {"user": "kim01", "ip": "10.0.3.21"},
    {"user": "lee02", "ip": "10.0.3.21"},
    {"user": "park03", "ip": "10.0.9.8"},
    {"user": "kim01", "ip": "10.0.8.15"},
    {"user": "park03", "ip": "10.0.9.8"},
    {"user": "choi04", "ip": "10.0.3.21"},
    {"user": "choi04", "ip": "10.0.7.7"},
]
failed_ips = []
for log in failed_logs:
    failed_ips.append(log["ip"])
print(failed_ips)

# %%
#@title 정답 챌린지 4 { display-mode: "form" }
from collections import Counter
failed_ips = ["10.0.3.21", "10.0.3.21", "10.0.3.21", "10.0.9.8", "10.0.8.15", "10.0.9.8", "10.0.3.21", "10.0.7.7"]
ip_counts = Counter(failed_ips)
print(ip_counts)

# %%
#@title 정답 챌린지 5 { display-mode: "form" }
from collections import Counter
ip_counts = Counter(["10.0.3.21", "10.0.3.21", "10.0.3.21", "10.0.9.8", "10.0.8.15", "10.0.9.8", "10.0.3.21", "10.0.7.7"])
top_ip = ""
top_count = 0
for ip, count in ip_counts.items():
    if count > top_count:
        top_ip = ip
        top_count = count
print(f"가장 많은 실패: {top_ip} · {top_count}회")

# %%
#@title 정답 챌린지 6 { display-mode: "form" }
top_ip = "10.0.3.21"
failed_logs = [
    {"user": "kim01", "ip": "10.0.3.21"},
    {"user": "kim01", "ip": "10.0.3.21"},
    {"user": "lee02", "ip": "10.0.3.21"},
    {"user": "park03", "ip": "10.0.9.8"},
    {"user": "kim01", "ip": "10.0.8.15"},
    {"user": "park03", "ip": "10.0.9.8"},
    {"user": "choi04", "ip": "10.0.3.21"},
    {"user": "choi04", "ip": "10.0.7.7"},
]
top_ip_users = []
for log in failed_logs:
    if log["ip"] == top_ip:
        top_ip_users.append(log["user"])
print(top_ip_users)

# %%
#@title 정답 챌린지 7 { display-mode: "form" }
top_ip_users = ["kim01", "kim01", "lee02", "choi04"]
top_ip_user_count = len(set(top_ip_users))
print(f"서로 다른 실패 계정: {top_ip_user_count}명")

# %%
#@title 정답 챌린지 8 { display-mode: "form" }
top_count = 4
top_ip_user_count = 3
if top_count >= 4 and top_ip_user_count >= 3:
    level = "여러 계정 공격 의심"
elif top_count >= 2:
    level = "반복 실패"
else:
    level = "낮음"
print(f"판정: {level}")
