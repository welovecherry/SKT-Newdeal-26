# %% [markdown]
# # <mark style="display:block; background:#d1c4e9; color:#1a1a1a; padding:6px 12px; border-radius:4px">10/2(금) · 월·화·수 복습 — 심화</mark>
#
# 새로 배우는 문법이 **하나도 없습니다.** 월·화·수에 배운 것을 **이어 붙이는** 문제들입니다.
#
# | 날 | 배운 것 | 여기서 쓰는 것 |
# |---|---|---|
# | 9/28(월) | `try`·`except` · `logging` · 중첩 · JSON | 묶음 1 |
# | 9/29(화) | 정규식 · 그룹 · 탐지 룰 ①②③ | 묶음 2 |
# | 9/30(수) | `requests` · 실패 대비 · `.env` | 묶음 3 |
#
# **막히면 그날 노트북을 다시 엽니다.** 찾아보는 것이 복습입니다.
#
# 정답은 맨 아래에 있습니다. 먼저 풀어 본 뒤에 엽니다.

# %% [markdown]
# 아래 두 셀을 먼저 실행합니다. 오늘 쓸 파일 두 개가 만들어집니다.

# %%
# %%writefile broken_logs.csv
# 09:01,kim01,LOGIN_OK,10.0.3.21
# 09:03,lee02,LOGIN_FAIL,10.0.7.5
# 03:22,hacker
# 09:05,admin,LOGIN_FAIL,10.0.9.8
# 09:12,admin,LOGIN_FAIL,10.0.9.8
#
# 09:18,lee02,LOGIN_FAIL,10.0.7.5
# 09:21,admin,LOGIN_FAIL,10.0.9.8
# ??:??,unknown,LOGIN_FAIL
# 09:45,kim01,LOGIN_OK,10.0.3.21

# %%
# %%writefile raw_logs.txt
# 2026-09-29 09:02:11 INFO accepted login for kim.cs from 10.1.2.11
# 2026-09-29 09:12:00 WARN failed login for kim01 from 203.0.113.5
# 2026-09-29 09:15:31 INFO accepted login for lee.yh from 10.1.2.34
# 2026-09-29 09:16:02 INFO session closed for 10.1.2.34
# 2026-09-29 10:03:19 WARN failed login for park.js from 10.1.3.7
# 2026-09-29 10:03:31 INFO accepted login for park.js from 10.1.3.7
# 2026-09-29 11:20:55 INFO accepted login for choi.mk from 10.1.4.2
# 2026-09-29 12:40:12 INFO session closed for 10.1.4.2
# 2026-09-29 03:11:05 WARN failed login for admin from 211.45.12.9
# 2026-09-29 03:12:47 WARN failed login for admin from 211.45.12.9
# 2026-09-29 03:13:58 WARN failed login for admin from 211.45.12.9
# 2026-09-29 03:15:22 WARN failed login for admin from 211.45.12.9
# 2026-09-29 03:17:09 INFO accepted login for admin from 211.45.12.9
# 2026-09-29 14:05:38 INFO accepted login for jung.hw from 10.1.2.88
# 2026-09-29 22:14:03 WARN failed login for kim.cs from 185.220.101.34
# 2026-09-29 22:14:21 WARN failed login for lee.yh from 185.220.101.34
# 2026-09-29 22:14:40 WARN failed login for choi.mk from 185.220.101.34
# 2026-09-29 22:14:58 WARN failed login for jung.hw from 185.220.101.34
# 2026-09-29 22:15:12 INFO session closed for 185.220.101.34
# 2026-09-29 23:40:07 WARN failed login for invalid user guest from 185.220.101.34

# %%
# !ls  # 파일 두 개가 보이면 준비 끝입니다

# %% [markdown]
# ---
#
# # <mark style="display:block; background:#ffe0b2; color:#1a1a1a; padding:6px 12px; border-radius:4px">묶음 1 · 9/28 — 깨진 줄을 견디고 JSON 으로 남긴다</mark>

# %% [markdown]
# ### 되짚어 보기
#
# | 쓰는 법 | 뜻 |
# |---|---|
# | `try:` / `except IndexError:` | 예외가 나도 멈추지 않는다 |
# | `except` 여러 개 | 이름별로 갈라 잡는다 |
# | `딕셔너리[키] = [값]` | 값 자리에 리스트·딕셔너리를 둔다 |
# | `json.dump(값, f, ensure_ascii=False, indent=2)` | 파일로 남긴다 |
#
# 오늘 쓸 파일은 **`broken_logs.csv`** 입니다. 9/28에 쓴 것과 같은 모양이고, 깨진 줄이 세 개 섞여 있습니다.

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 복습 1-1 · 깨진 줄을 건너뛰고 세기</font></h3></td></tr></table>
#
# `broken_logs.csv` 를 한 줄씩 읽어 **정상 줄과 깨진 줄이 각각 몇 건인지** 출력하시오.
#
# - 칸이 네 개가 아니면 깨진 줄로 봅니다.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | `정상 7건 / 깨진 줄 3건` |
#
# **💡 힌트**
#
# 1. 파일을 읽는 뼈대는 9/28 문제 1-11 과 같습니다.
# 2. `parts[3]` 을 꺼내는 줄을 `try` 안에 둡니다.
# 3. 숫자 두 개를 반복 전에 만들어 둡니다.

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 복습 1-2 · 깨진 이유를 나눠 세기</font></h3></td></tr></table>
#
# 같은 파일을 다시 읽으면서 **시각이 깨진 줄**과 **칸이 모자란 줄**을 나눠 세시오.
#
# - 시각은 `int(parts[0].split(":")[0])` 으로 숫자가 되어야 정상입니다.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | `시각이 깨진 줄 2건 / 칸이 모자란 줄 1건` |
#
# **💡 힌트**
#
# 1. `try` 안에서 시각을 먼저 바꾸고, 그다음 `parts[3]` 을 꺼냅니다.
# 2. `except ValueError:` 와 `except IndexError:` 를 이어 씁니다.
# 3. 빈 줄은 시각이 빈 글자라 `ValueError` 쪽으로 갑니다.

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 복습 1-3 · 계정별 보고서를 중첩으로</font></h3></td></tr></table>
#
# 정상 줄만 모아 **계정별로 실패 횟수와 IP** 를 담은 보고서를 만드시오.
#
# - 모양은 `{"admin": {"fail": 3, "ip": "10.0.9.8"}, ...}` 입니다.
# - `LOGIN_FAIL` 인 줄만 셉니다.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | `admin` 은 `fail` 3, `lee02` 는 `fail` 2 |
#
# **💡 힌트**
#
# 1. 9/28 오후 도전 ⭐4-2 와 뼈대가 같습니다.
# 2. 처음 보는 계정이면 `{"fail": 1, "ip": parts[3]}` 를 넣어 자리를 만듭니다.
# 3. 이미 있으면 `report[user]["fail"]` 에 1 을 더합니다.

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 복습 1-4 · 보고서를 저장하고 다시 읽기</font></h3></td></tr></table>
#
# 문제 1-3의 보고서를 **`review_report.json`** 으로 저장한 뒤, **다시 읽어** `admin` 의 실패 횟수를 출력하시오.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | `저장했습니다` 그리고 `3` |
#
# **💡 힌트**
#
# 1. 저장은 `json.dump`, 읽기는 `json.load` 입니다.
# 2. 저장할 때 `ensure_ascii=False` 와 `indent=2` 를 넣습니다.
# 3. 읽어 온 것은 딕셔너리라 대괄호 두 번으로 꺼냅니다.

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# <table width="100%" bgcolor="#FFE0B2"><tr><td bgcolor="#FFE0B2"><h3><font color="#E65100">⭐ 도전 1-1 · 기록까지 남기기</font></h3></td></tr></table>
#
# 문제 1-4 를 **`.py` 파일로 만들어** 실행하고, 깨진 줄을 `logging.warning` 으로 `review.log` 에 남기시오.
#
# | | |
# |---|---|
# | 🎯 `review.log` | 시작 · 경고 3건 · 완료 |
#
# **💡 힌트**
#
# 1. 9/28 문제 3-8 의 `log_parser.py` 와 뼈대가 같습니다.
# 2. 설정에 `level=logging.INFO` 를 꼭 넣습니다.
# 3. 코랩 셀에서 바로 부르면 설정이 무시되니 `%%writefile` 로 만들어 `!python` 으로 돌립니다.

# %%
# %%writefile review_logger.py

# %% [markdown]
# ---
#
# # <mark style="display:block; background:#ffe0b2; color:#1a1a1a; padding:6px 12px; border-radius:4px">묶음 2 · 9/29 — 줄글에서 뽑아 판단한다</mark>

# %% [markdown]
# ### 되짚어 보기
#
# | 쓰는 법 | 뜻 |
# |---|---|
# | `re.search(r"패턴", 글자)` | 생김새로 찾는다 |
# | `(?P<이름>...)` · `.groupdict()` | 줄 하나가 딕셔너리 하나가 된다 |
# | `if m:` | 못 찾으면 `None` 이라 반드시 확인 |
# | 룰 ①②③ | 계정별 실패 · IP 마다 계정 수 · 심야 성공 |
#
# 오늘 쓸 파일은 **`raw_logs.txt`** 입니다. 9/29에 쓴 그 파일입니다.

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 복습 2-1 · 정규식으로 다시 읽기</font></h3></td></tr></table>
#
# `raw_logs.txt` 를 읽어 **정규화한 건수와 안 맞는 건수**를 출력하시오.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | `정규화 16건 / 안 맞음 4건` |
#
# **💡 힌트**
#
# 1. 패턴은 9/29 문제 2-7 에 있습니다. 그대로 가져옵니다.
# 2. `if m:` 과 `else:` 로 나눠 담습니다.
# 3. 맨 위에 `PATTERN` 으로 한 번만 적어 둡니다.

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 복습 2-2 · 등급별로 세기</font></h3></td></tr></table>
#
# 정규화한 기록을 **등급별로** 세어 출력하시오.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | `{'INFO': 6, 'WARN': 10}` 또는 같은 뜻의 딕셔너리 |
#
# **💡 힌트**
#
# 1. 문제 2-1 의 결과 `rows` 를 그대로 씁니다.
# 2. 빈 딕셔너리를 만들고 `row["level"]` 을 키로 셉니다.
# 3. 이미 있는 키인지 `if level in count:` 로 확인합니다.

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 복습 2-3 · 룰 세 개를 한 번에</font></h3></td></tr></table>
#
# 정규화한 기록에 **룰 ①②③ 을 모두** 돌려 경보를 출력하시오.
#
# | 룰 | 기준 |
# |---|---|
# | ① 브루트포스 | 계정별 실패 3회 이상 |
# | ② 의심 IP | 한 IP 에 계정 2개 이상 |
# | ③ 심야 접속 | 06시 이전의 `INFO` |
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | `[룰 1]` · `[룰 2]` · `[룰 3]` 세 줄 |
#
# **💡 힌트**
#
# 1. 9/29 오후 문제 4-10 이 이 문제입니다. 그날 노트북을 열어 보세요.
# 2. 기준값 두 개를 맨 위에 나란히 둡니다.
# 3. 한 반복 안에서 계정 세기와 IP 모으기를 함께 합니다.

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 복습 2-4 · 경보를 JSON 으로 남기기</font></h3></td></tr></table>
#
# 문제 2-3 의 경보 세 줄을 **리스트에 모아** `review_alerts.json` 으로 저장하시오.
#
# - 9/28의 JSON 과 9/29의 탐지 룰을 잇는 문제입니다.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | `경보 3건을 저장했습니다` |
#
# **💡 힌트**
#
# 1. 경보를 바로 출력하지 말고 빈 리스트에 `append` 합니다.
# 2. 모은 뒤 `json.dump` 로 저장합니다.
# 3. `ensure_ascii=False` 를 넣어야 한글이 그대로 보입니다.

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# <table width="100%" bgcolor="#FFE0B2"><tr><td bgcolor="#FFE0B2"><h3><font color="#E65100">⭐ 도전 2-1 · 안 맞는 줄이 왜 안 맞았나</font></h3></td></tr></table>
#
# 안 맞는 줄 네 개를 출력하고, **각각 패턴의 어느 부분에서 어긋났는지** 한 줄씩 적으시오. 코드는 짧습니다. 읽는 것이 목적입니다.
#
# | | |
# |---|---|
# | 🎯 확인 | `session closed` 줄에는 `login for` 가 없고, `invalid user` 줄은 계정 자리에 빈칸이 있다 |
#
# **💡 힌트**
#
# 1. 9/29 도전 ⭐2-3 과 같은 문제입니다.
# 2. `else` 에 담은 리스트를 그대로 출력합니다.
# 3. 패턴을 옆에 놓고 한 줄씩 견줍니다.

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# ---
#
# # <mark style="display:block; background:#ffe0b2; color:#1a1a1a; padding:6px 12px; border-radius:4px">묶음 3 · 9/30 — 밖에 물어보고 합친다</mark>

# %% [markdown]
# ### 되짚어 보기
#
# | 쓰는 법 | 뜻 |
# |---|---|
# | `requests.get(주소, timeout=5)` | 요청을 보낸다. 시간 제한을 꼭 붙인다 |
# | `response.raise_for_status()` | 4xx·5xx 면 예외를 낸다 |
# | `except requests.RequestException` | `requests` 가 내는 예외를 모두 잡는다 |
# | `response.json()` | 본문을 딕셔너리로 되돌린다 |
#
# 이 묶음은 **인터넷에 실제로 요청을 보냅니다.** 조회 주소는 `https://ipwho.is/<IP>` 입니다.

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 복습 3-1 · 조회해서 나라 꺼내기</font></h3></td></tr></table>
#
# IP 하나를 조회해 **나라와 통신사**를 출력하시오.
#
# - `isp` 는 `connection` 안에 들어 있습니다.
#
# | | |
# |---|---|
# | 주어지는 값 | `ip = "211.45.12.9"` |
# | 🎯 나와야 하는 결과 | `South Korea SamsungSDS Inc.` |
#
# **💡 힌트**
#
# 1. `requests.get(f"https://ipwho.is/{ip}", timeout=5)` 로 보냅니다.
# 2. `.json()` 으로 딕셔너리를 만듭니다.
# 3. `isp` 는 대괄호 두 번으로 꺼냅니다.

# %%
ip = "211.45.12.9"

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 복습 3-2 · 실패해도 멈추지 않게</font></h3></td></tr></table>
#
# 일부러 실패하는 주소(`https://postman-echo.com/status/500`)에 요청을 보내고, **세 번까지 다시 시도**한 뒤 `None` 을 돌려주는 함수를 쓰시오.
#
# - 함수 이름은 `call_with_retry` 입니다.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | `1번째 실패` · `2번째 실패` · `3번째 실패` · `None` |
#
# **💡 힌트**
#
# 1. 9/30 문제 2-8 이 이 함수입니다.
# 2. `for i in range(tries):` 안에 `try` 를 둡니다.
# 3. 성공하면 `return`, 다 실패하면 반복 밖에서 `return None` 입니다.

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 복습 3-3 · 경보에 나라를 붙인다</font></h3></td></tr></table>
#
# 묶음 2 의 **룰 ② 가 잡은 IP** 를 조회해, 경보 줄에 **나라와 통신사**를 붙여 출력하시오.
#
# - 사흘치가 한 줄로 이어지는 문제입니다 — 정규식으로 읽고, 룰로 고르고, 밖에 물어봅니다.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | `[룰 2] 185.220.101.34 — 계정 4개 시도 · Germany (Stiftung Erneuerbare Freiheit)` |
#
# **💡 힌트**
#
# 1. 룰 ② 코드는 문제 2-3 에 있습니다.
# 2. 걸린 IP 만 리스트에 모은 뒤 `for` 로 조회합니다.
# 3. 조회가 실패할 수 있으니 `if data:` 로 확인합니다.

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 복습 3-4 · 조회 결과까지 저장하기</font></h3></td></tr></table>
#
# 문제 3-3 의 결과를 **`review_enriched.json`** 으로 저장하시오.
#
# - 칸은 `ip` · `accounts` · `country` · `isp` 네 개입니다.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | `1건을 저장했습니다` |
#
# **💡 힌트**
#
# 1. 경보를 만들 때 문장이 아니라 **딕셔너리**로 담습니다.
# 2. `json.dump` 로 저장합니다.
# 3. `accounts` 는 계정 수(숫자)입니다.

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# <table width="100%" bgcolor="#FFE0B2"><tr><td bgcolor="#FFE0B2"><h3><font color="#E65100">⭐ 도전 3-1 · 실패한 조회도 남기기</font></h3></td></tr></table>
#
# 조회가 실패한 IP 도 버리지 않고 `country` 를 `unknown` 으로 채워 남기시오. 룰 ①이 잡은 `211.45.12.9` 와 실제로 조회가 안 되는 `0.0.0.0` 을 함께 넣어 확인합니다.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | 세 건. `0.0.0.0` 은 `country` 가 `unknown` |
#
# **💡 힌트**
#
# 1. `data["success"]` 가 `False` 면 실패입니다.
# 2. `if` 와 `else` 로 두 갈래를 나눠 담습니다.
# 3. 버린 것을 세지 못하면 「왜 두 건이지?」에 답할 수 없습니다.

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# ### <mark style="display:block; background:#bbdefb; color:#1a1a1a; padding:6px 12px; border-radius:4px">사흘이 한 줄로 이어진다</mark>
#
# | 단계 | 어느 날 | 무엇 |
# |---|---|---|
# | 읽는다 | 9/29 | 줄글에서 정규식으로 네 값을 꺼낸다 |
# | 버티다 | 9/28 | 깨진 줄에 멈추지 않고 기록을 남긴다 |
# | 판단한다 | 9/29 | 룰 ①②③ 으로 수상한 것을 고른다 |
# | 물어본다 | 9/30 | 밖에 조회해 나라와 통신사를 붙인다 |
# | 남긴다 | 9/28 | JSON 으로 저장해 다음 프로그램에 넘긴다 |
#
# **다섯 단계가 오늘 문제 3-4 한 개에 다 들어 있습니다.** 11월 캡스톤에서 만드는 것이 이 구조입니다.

# %% [markdown]
# ---
#
# # <mark style="display:block; background:#f8bbd0; color:#1a1a1a; padding:6px 12px; border-radius:4px">정답 · 먼저 풀어 본 뒤에 엽니다</mark>
#
# 각 셀은 제목만 보입니다. 「코드 표시」를 누르면 코드가 열립니다.

# %%
#@title 정답 1-1 { display-mode: "form" }
ok = 0
bad = 0

with open("broken_logs.csv", encoding="utf-8") as f:
    for line in f:
        parts = line.strip().split(",")
        try:
            parts[3]
            ok = ok + 1
        except IndexError:
            bad = bad + 1

print(f"정상 {ok}건 / 깨진 줄 {bad}건")

# %%
#@title 정답 1-2 { display-mode: "form" }
bad_time = 0
bad_column = 0

with open("broken_logs.csv", encoding="utf-8") as f:
    for line in f:
        parts = line.strip().split(",")
        try:
            int(parts[0].split(":")[0])
            parts[3]
        except ValueError:
            bad_time = bad_time + 1
        except IndexError:
            bad_column = bad_column + 1

print(f"시각이 깨진 줄 {bad_time}건 / 칸이 모자란 줄 {bad_column}건")

# %%
#@title 정답 1-3 { display-mode: "form" }
report = {}

with open("broken_logs.csv", encoding="utf-8") as f:
    for line in f:
        parts = line.strip().split(",")
        try:
            if parts[2] == "LOGIN_FAIL":
                user = parts[1]
                if user in report:
                    report[user]["fail"] = report[user]["fail"] + 1
                else:
                    report[user] = {"fail": 1, "ip": parts[3]}
        except IndexError:
            pass

print(report)

# %%
#@title 정답 1-4 { display-mode: "form" }
import json

report = {}
with open("broken_logs.csv", encoding="utf-8") as f:
    for line in f:
        parts = line.strip().split(",")
        try:
            if parts[2] == "LOGIN_FAIL":
                user = parts[1]
                if user in report:
                    report[user]["fail"] = report[user]["fail"] + 1
                else:
                    report[user] = {"fail": 1, "ip": parts[3]}
        except IndexError:
            pass

with open("review_report.json", "w", encoding="utf-8") as f:
    json.dump(report, f, ensure_ascii=False, indent=2)

print("저장했습니다")

with open("review_report.json", encoding="utf-8") as f:
    back = json.load(f)

print(back["admin"]["fail"])

# %%
#@title 정답 ⭐1-1 { display-mode: "form" }
code = """import logging

logging.basicConfig(
    filename="review.log",
    level=logging.INFO,
    format="%(asctime)s %(levelname)s %(message)s",
    encoding="utf-8",
)

logging.info("복습 파서 시작: broken_logs.csv")

ok = 0
with open("broken_logs.csv", encoding="utf-8") as f:
    for line in f:
        parts = line.strip().split(",")
        try:
            parts[3]
            ok = ok + 1
        except IndexError:
            logging.warning(f"깨진 줄 건너뜀: {line.strip()}")

logging.info(f"정상 {ok}건 처리 완료")
print(f"정상 {ok}건")
"""

with open("review_logger.py", "w", encoding="utf-8") as f:
    f.write(code)

print("review_logger.py 를 만들었습니다. !python review_logger.py 로 실행하세요.")

# %%
#@title 정답 2-1 { display-mode: "form" }
import re

PATTERN = r"(?P<time>\d{2}:\d{2}:\d{2}) (?P<level>\w+) \w+ login for (?P<user>[\w.]+) from (?P<ip>[\d.]+)"

rows = []
unmatched = []

with open("raw_logs.txt", encoding="utf-8") as f:
    for line in f:
        m = re.search(PATTERN, line)
        if m:
            rows.append(m.groupdict())
        else:
            unmatched.append(line.strip())

print(f"정규화 {len(rows)}건 / 안 맞음 {len(unmatched)}건")

# %%
#@title 정답 2-2 { display-mode: "form" }
import re

PATTERN = r"(?P<time>\d{2}:\d{2}:\d{2}) (?P<level>\w+) \w+ login for (?P<user>[\w.]+) from (?P<ip>[\d.]+)"

rows = []
with open("raw_logs.txt", encoding="utf-8") as f:
    for line in f:
        m = re.search(PATTERN, line)
        if m:
            rows.append(m.groupdict())

count = {}
for row in rows:
    level = row["level"]
    if level in count:
        count[level] = count[level] + 1
    else:
        count[level] = 1

print(count)

# %%
#@title 정답 2-3 { display-mode: "form" }
import re

PATTERN = r"(?P<time>\d{2}:\d{2}:\d{2}) (?P<level>\w+) \w+ login for (?P<user>[\w.]+) from (?P<ip>[\d.]+)"
THRESHOLD = 3
NIGHT_END = 6

rows = []
with open("raw_logs.txt", encoding="utf-8") as f:
    for line in f:
        m = re.search(PATTERN, line)
        if m:
            rows.append(m.groupdict())

count = {}
table = {}
for row in rows:
    user = row["user"]
    ip = row["ip"]
    if row["level"] == "WARN":
        if user in count:
            count[user] = count[user] + 1
        else:
            count[user] = 1
    if ip in table:
        if user not in table[ip]:
            table[ip].append(user)
    else:
        table[ip] = [user]

for user in count:
    if count[user] >= THRESHOLD:
        print(f"[룰 1] 확인 필요: {user} — 실패 {count[user]}회")

for ip in table:
    if len(table[ip]) >= 2:
        print(f"[룰 2] 의심 IP: {ip} — 계정 {len(table[ip])}개 시도")

for row in rows:
    if int(row["time"].split(":")[0]) < NIGHT_END and row["level"] == "INFO":
        print(f"[룰 3] 심야 접속: {row['time']} {row['user']} ({row['ip']})")

# %%
#@title 정답 2-4 { display-mode: "form" }
import re
import json

PATTERN = r"(?P<time>\d{2}:\d{2}:\d{2}) (?P<level>\w+) \w+ login for (?P<user>[\w.]+) from (?P<ip>[\d.]+)"
THRESHOLD = 3
NIGHT_END = 6

rows = []
with open("raw_logs.txt", encoding="utf-8") as f:
    for line in f:
        m = re.search(PATTERN, line)
        if m:
            rows.append(m.groupdict())

count = {}
table = {}
for row in rows:
    user = row["user"]
    ip = row["ip"]
    if row["level"] == "WARN":
        if user in count:
            count[user] = count[user] + 1
        else:
            count[user] = 1
    if ip in table:
        if user not in table[ip]:
            table[ip].append(user)
    else:
        table[ip] = [user]

alerts = []
for user in count:
    if count[user] >= THRESHOLD:
        alerts.append(f"[룰 1] 확인 필요: {user} — 실패 {count[user]}회")
for ip in table:
    if len(table[ip]) >= 2:
        alerts.append(f"[룰 2] 의심 IP: {ip} — 계정 {len(table[ip])}개 시도")
for row in rows:
    if int(row["time"].split(":")[0]) < NIGHT_END and row["level"] == "INFO":
        alerts.append(f"[룰 3] 심야 접속: {row['time']} {row['user']} ({row['ip']})")

with open("review_alerts.json", "w", encoding="utf-8") as f:
    json.dump(alerts, f, ensure_ascii=False, indent=2)

print(f"경보 {len(alerts)}건을 저장했습니다")

# %%
#@title 정답 ⭐2-1 { display-mode: "form" }
import re

PATTERN = r"(?P<time>\d{2}:\d{2}:\d{2}) (?P<level>\w+) \w+ login for (?P<user>[\w.]+) from (?P<ip>[\d.]+)"

unmatched = []
with open("raw_logs.txt", encoding="utf-8") as f:
    for line in f:
        if re.search(PATTERN, line):
            pass
        else:
            unmatched.append(line.strip())

for line in unmatched:
    print(line)

# %%
#@title 정답 3-1 { display-mode: "form" }
import requests

ip = "211.45.12.9"

response = requests.get(f"https://ipwho.is/{ip}", timeout=5)
data = response.json()

print(data["country"], data["connection"]["isp"])

# %%
#@title 정답 3-2 { display-mode: "form" }
import requests


def call_with_retry(url, tries=3):
    for i in range(tries):
        try:
            response = requests.get(url, timeout=5)
            response.raise_for_status()
            return response.json()
        except requests.RequestException:
            print(f"{i + 1}번째 실패")
    return None


print(call_with_retry("https://postman-echo.com/status/500"))

# %%
#@title 정답 3-3 { display-mode: "form" }
import re
import requests

PATTERN = r"(?P<time>\d{2}:\d{2}:\d{2}) (?P<level>\w+) \w+ login for (?P<user>[\w.]+) from (?P<ip>[\d.]+)"

rows = []
with open("raw_logs.txt", encoding="utf-8") as f:
    for line in f:
        m = re.search(PATTERN, line)
        if m:
            rows.append(m.groupdict())

table = {}
for row in rows:
    ip = row["ip"]
    user = row["user"]
    if ip in table:
        if user not in table[ip]:
            table[ip].append(user)
    else:
        table[ip] = [user]

for ip in table:
    if len(table[ip]) >= 2:
        response = requests.get(f"https://ipwho.is/{ip}", timeout=5)
        data = response.json()
        print(f"[룰 2] {ip} — 계정 {len(table[ip])}개 시도 · {data['country']} ({data['connection']['isp']})")

# %%
#@title 정답 3-4 { display-mode: "form" }
import re
import json
import requests

PATTERN = r"(?P<time>\d{2}:\d{2}:\d{2}) (?P<level>\w+) \w+ login for (?P<user>[\w.]+) from (?P<ip>[\d.]+)"

rows = []
with open("raw_logs.txt", encoding="utf-8") as f:
    for line in f:
        m = re.search(PATTERN, line)
        if m:
            rows.append(m.groupdict())

table = {}
for row in rows:
    ip = row["ip"]
    user = row["user"]
    if ip in table:
        if user not in table[ip]:
            table[ip].append(user)
    else:
        table[ip] = [user]

results = []
for ip in table:
    if len(table[ip]) >= 2:
        response = requests.get(f"https://ipwho.is/{ip}", timeout=5)
        data = response.json()
        results.append({
            "ip": ip,
            "accounts": len(table[ip]),
            "country": data["country"],
            "isp": data["connection"]["isp"],
        })

with open("review_enriched.json", "w", encoding="utf-8") as f:
    json.dump(results, f, ensure_ascii=False, indent=2)

print(f"{len(results)}건을 저장했습니다")

# %%
#@title 정답 ⭐3-1 { display-mode: "form" }
import requests


def lookup(ip):
    try:
        response = requests.get(f"https://ipwho.is/{ip}", timeout=5)
        response.raise_for_status()
        data = response.json()
    except requests.RequestException:
        return None
    if data["success"]:
        return {"ip": ip, "country": data["country"], "isp": data["connection"]["isp"]}
    else:
        return None


results = []
for ip in ["185.220.101.34", "211.45.12.9", "0.0.0.0"]:
    row = lookup(ip)
    if row:
        results.append(row)
    else:
        results.append({"ip": ip, "country": "unknown", "isp": "unknown"})

for row in results:
    print(row)
