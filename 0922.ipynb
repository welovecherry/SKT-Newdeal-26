# %% [markdown]
# # 9/22(화) · 개발환경 · 변수 · 리스트 — 연습장**직접 쳐 보는 연습장**입니다. 개념 설명과 용어는 knowledge Module 1 Chapter 1·2·3 에 있습니다.> ⚠ **맨 먼저 할 일 — 내 사본 만들기**> 위 메뉴에서 **파일 › 드라이브에 사본 저장**을 누르세요.> 사본을 만들지 않으면 **내가 쓴 코드가 저장되지 않습니다.**> 제목이 「사본: …」으로 바뀌면 된 것입니다.- 사용법: `# 주어지는 것` 줄은 **그대로 두고 실행**합니다. `# 여기에 직접 작성 👇` 아래에만 씁니다.- 셀 실행은 **Shift + Enter** 입니다.- 실습 ①~④ 는 슬라이드의 실습 전환 장과 번호가 같습니다.- 막히면 손을 드세요. 다 못 풀어도 됩니다.| 실습 | 교시 | 내용 ||---|---|---|| ① | 2교시 15:00 | Colab 첫 실행 · 로컬 설치 확인 || ② | 2교시 15:36 | 변수와 자료형 || ③ | 3교시 16:10 | f-string과 형변환 || ④ | 3교시 16:41 | 리스트와 딕셔너리 |

# %% [markdown]
# ## 실습 ① · Colab 첫 실행 (10분)오늘 코드는 **Colab**에서 씁니다. 설치가 필요 없고 인터넷만 있으면 됩니다.**로컬 설치(Python · VS Code)는 따로 계속 진행합니다** — Day 5 스케줄러부터는 로컬이 있어야 합니다.

# %% [markdown]
# ---### ✍️ 문제 1-1. 첫 셀 실행하기**설명**  아래 셀을 누르고 **Shift + Enter** 를 칩니다. 왼쪽 ▶ 를 눌러도 됩니다.**만들 것**  그대로 실행**나와야 하는 결과**```안녕하세요```

# %%
# 주어지는 것 (이 줄은 그대로 두고 실행하세요)print("안녕하세요")

# %% [markdown]
# ---### ✍️ 문제 1-2. 파이썬 버전 확인**설명**  Colab 이 쓰는 파이썬 버전을 봅니다. 내 노트북에 설치한 버전과 달라도 괜찮습니다.**만들 것**  그대로 실행**나와야 하는 결과**```3.11.x 또는 3.12.x 처럼 버전 숫자```

# %%
# 주어지는 것 (이 줄은 그대로 두고 실행하세요)import sysprint(sys.version)

# %% [markdown]
# ## 실습 ② · 변수와 자료형 (8분)

# %% [markdown]
# ---### 🔥 워밍업 — 그대로 실행하기변수 세 개를 만들고 출력합니다. **먼저 그대로 실행**해 보세요.

# %%
# 주어지는 것 (이 줄은 그대로 두고 실행하세요)user = "kim01"fail_count = 3is_blocked = Falseprint(user)print(fail_count)print(is_blocked)

# %% [markdown]
# ---### ✍️ 문제 2-1. 실패 횟수에 1 더하기**설명**  fail_count 를 1 늘린 뒤 출력하세요.**만들 것**  fail_count 를 1 늘리는 한 줄과 print 한 줄**나와야 하는 결과**```4```

# %%
# 주어지는 것 (이 줄은 그대로 두고 실행하세요)fail_count = 3# 여기에 직접 작성 👇

# %% [markdown]
# ---### ✍️ 문제 2-2. 자료형 맞히기 — 먼저 예상하고 확인**설명**  세 값의 자료형을 **머리로 먼저 맞혀 보고** type() 으로 확인하세요.**만들 것**  각 값에 type() 을 쓴 print 세 줄**나와야 하는 결과**```<class 'str'><class 'int'><class 'bool'>```

# %%
# 주어지는 것 (이 줄은 그대로 두고 실행하세요)user = "kim01"fail_count = 3is_blocked = False# 여기에 직접 작성 👇

# %% [markdown]
# ---### ✍️ 문제 2-3. 따옴표 하나의 차이 (직접 실행해 확인)**설명**  아래를 그대로 실행하면 무엇이 나오는지 눈으로 확인하세요. 화면에는 둘 다 7 로 보입니다.**만들 것**  그대로 실행 — TypeError 가 나는지 관찰**나와야 하는 결과**```8TypeError: can only concatenate str (not "int") to str```

# %%
# 주어지는 것 (이 줄은 그대로 두고 실행하세요)a = 7print(a + 1)b = "7"print(b + 1)

# %% [markdown]
# ## 실습 ③ · f-string과 형변환 (8분)

# %% [markdown]
# ---### ✍️ 문제 3-1. f-string 으로 문장 만들기**설명**  user 를 넣어 「kim01님이 로그인했습니다」를 출력하세요.**만들 것**  f-string 을 쓴 print 한 줄**나와야 하는 결과**```kim01님이 로그인했습니다```

# %%
# 주어지는 것 (이 줄은 그대로 두고 실행하세요)user = "kim01"# 여기에 직접 작성 👇

# %% [markdown]
# ---### ✍️ 문제 3-2. 보안 알림 문장 조립하기**설명**  변수 네 개를 한 문장으로 조립해 출력하세요. 형식은 아래 결과와 똑같이 맞춥니다.**만들 것**  f-string 으로 만든 alert 변수와 print 한 줄**나와야 하는 결과**```[경고] kim01 — 10.0.3.21에서 5회 실패 · 차단=True```

# %%
# 주어지는 것 (이 줄은 그대로 두고 실행하세요)user = "kim01"ip = "10.0.3.21"fail_count = 5is_blocked = True# 여기에 직접 작성 👇

# %% [markdown]
# ---### ✍️ 문제 3-3. 어떤 에러가 날까 (직접 실행해 확인)**설명**  아래를 실행하면 무엇이 나오고 「검사 완료」는 출력될지 확인하세요.**만들 것**  그대로 실행 — 어디서 멈추는지 관찰**나와야 하는 결과**```TypeError  (그리고 '검사 완료'는 안 나옴)```

# %%
# 주어지는 것 (이 줄은 그대로 두고 실행하세요)count = "7"print(count + 1)print("검사 완료")

# %% [markdown]
# ---### ✍️ 문제 3-4. 멈추지 않게 고치기**설명**  3-3 이 멈추지 않도록 count 를 숫자로 바꾸세요.**만들 것**  int() 를 쓴 한 줄**나와야 하는 결과**```8검사 완료```

# %%
# 주어지는 것 (이 줄은 그대로 두고 실행하세요)count = "7"# 여기에 직접 작성 👇

# %% [markdown]
# ## 실습 ④ · 리스트와 딕셔너리 (9분)

# %% [markdown]
# ---### ✍️ 문제 4-1. 리스트에서 꺼내기**설명**  첫 번째와 마지막 계정을 출력하고, 개수도 출력하세요.**만들 것**  print 세 줄**나와야 하는 결과**```kim01park033```

# %%
# 주어지는 것 (이 줄은 그대로 두고 실행하세요)users = ["kim01", "lee02", "park03"]# 여기에 직접 작성 👇

# %% [markdown]
# ---### ✍️ 문제 4-2. 실패한 계정 모으기**설명**  빈 리스트에 계정 두 개를 append 로 넣고 출력하세요.**만들 것**  append 두 줄과 print 한 줄**나와야 하는 결과**```['kim01', 'lee02']```

# %%
# 주어지는 것 (이 줄은 그대로 두고 실행하세요)failed_users = []# 여기에 직접 작성 👇

# %% [markdown]
# ---### ✍️ 문제 4-3. ⭐ 로그 한 줄을 딕셔너리로 적기**설명**  주석의 로그 한 줄을 딕셔너리 log 로 옮기고, 계정과 결과를 출력하세요.**만들 것**  키 다섯 개(time·user·ip·action·result)를 가진 log 와 print 두 줄**나와야 하는 결과**```kim01FAIL```> 오늘의 핵심입니다. Day 2 에 이 딕셔너리를 리스트에 담아 수백 줄을 한 번에 셉니다.

# %%
# 주어지는 것 (이 줄은 그대로 두고 실행하세요)# 2026-09-22 14:03:11  kim01  10.0.3.21  LOGIN  FAIL# 여기에 직접 작성 👇

# %% [markdown]
# ---### ✍️ 문제 4-4. 없는 키를 부르면 (직접 실행해 확인)**설명**  ip 가 없는 로그에서 ip 를 꺼내 봅니다. 「검사 완료」가 나오는지 보세요.**만들 것**  그대로 실행 — KeyError 관찰**나와야 하는 결과**```KeyError: 'ip'  (그리고 '검사 완료'는 안 나옴)```

# %%
# 주어지는 것 (이 줄은 그대로 두고 실행하세요)log = {"user": "kim01", "result": "FAIL"}print(log["ip"])print("검사 완료")

# %% [markdown]
# ---### ✍️ 문제 4-5. 멈추지 않게 고치기**설명**  4-4 가 멈추지 않도록 .get() 으로 바꾸고, 없을 때는 「알 수 없음」이 나오게 하세요.**만들 것**  .get() 을 쓴 print 한 줄과 print('검사 완료')**나와야 하는 결과**```알 수 없음검사 완료```

# %%
# 주어지는 것 (이 줄은 그대로 두고 실행하세요)log = {"user": "kim01", "result": "FAIL"}# 여기에 직접 작성 👇

# %% [markdown]
# ---### ✍️ 문제 4-6. 승인자가 배정됐나**설명**  approver 가 있으면 「승인자: (이름)」을, 없으면 「승인자 미배정」을 출력하세요.**만들 것**  .get() 과 f-string 을 쓴 코드**나와야 하는 결과**```승인자 미배정```

# %%
# 주어지는 것 (이 줄은 그대로 두고 실행하세요)request = {"id": "req-1001", "user": "kim01", "status": "review"}# 여기에 직접 작성 👇

# %% [markdown]
# ---## 오늘 여기까지다 못 푸셨어도 괜찮습니다. 남는 시간에 이어서 하세요.내일은 이 딕셔너리를 **리스트에 담아** 조건문과 반복문으로 셉니다. `day01_basic.py` 가 나옵니다.
