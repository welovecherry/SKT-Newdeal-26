# %% [markdown]
# # <mark style="display:block; background:#d1c4e9; color:#1a1a1a; padding:6px 12px; border-radius:4px">9/28(월) 오후 · 중첩 자료구조 · JSON — 실습</mark>
#
# 오늘 오후의 도착점은 **형식이 제각각인 로그를 한 모양으로 맞춰 `normalized_logs.json` 으로 남기는 것**입니다. 7교시에 `normalize_logs.py` 로 저장합니다.
#
# 이 노트북은 혼자서 돌아갑니다. 오전 노트북을 닫았어도 됩니다.

# %% [markdown]
# ## <mark style="display:block; background:#c8e6c9; color:#1a1a1a; padding:6px 12px; border-radius:4px">시작하기</mark>
#
# ### 0.1 맨 먼저 · 내 사본 만들기
#
# 1. 위 메뉴에서 파일 › 드라이브에 사본 저장을 누릅니다.
# 2. 제목이 「사본: …」으로 바뀌면 된 것입니다.
#
# ### 0.2 오늘 오후의 순서
#
# | 교시 | 무엇 |
# |---|---|
# | 5교시 | 중첩 자료구조 — 그릇 안의 그릇 |
# | 6교시 | JSON 네 명령 — `dumps`·`loads`·`dump`·`load` |
# | 7교시 | 정규화 · `normalize_logs.py` 조립 |
# | 8교시 | 돌려 보기 · 남은 도전 문제 · VS Code 설치 |
#
# ### 0.3 막혔을 때
#
# 1. 문제 아래 **💡 힌트**를 순서대로 따라 합니다.
# 2. 그래도 막히면 노트북 맨 아래 「정답」으로 갑니다. 왼쪽 목차(☰)에서 바로 갈 수 있습니다.
# 3. 도전 문제는 **안 풀고 넘어가도 됩니다.** 8교시에 모아 푸는 시간이 있습니다.

# %% [markdown]
# ---
#
# # <mark style="display:block; background:#ffe0b2; color:#1a1a1a; padding:6px 12px; border-radius:4px">5교시 (14:00–14:50) · 중첩 자료구조</mark>

# %% [markdown]
# ## <mark style="display:block; background:#b3e5fc; color:#0d3c61; padding:6px 12px; border-radius:4px">🔎 공부하는 법을 공부하기</mark>
#
# 설명을 읽기 전에 아래 **두 개념**을 스스로 찾아봅니다. 검색이든 공식 문서든 AI 든 상관없습니다. 찾은 것은 코랩에서 한 번 실행해 확인합니다.
#
# | 찾아볼 개념 | 알아 올 것 |
# |---|---|
# | **중첩(nested)** | 그릇 안에 그릇이 있다는 것이 데이터에서 무슨 뜻인가 |
# | **딕셔너리 안의 딕셔너리** | 리스트 안의 딕셔너리와 언제 갈라 쓰나 |
#
# **여기에 기록하세요** — 이 셀을 **두 번 눌러** 아래에 적습니다. 한 줄씩이면 됩니다.
#
# - 중첩(nested) →
# - 딕셔너리 안의 딕셔너리 →
#
# 맨 처음에 「드라이브에 사본 저장」을 눌렀다면 여기 적은 것은 내 드라이브의 노트북에 함께 남습니다.
#
# 적어 둔 것은 이 교시가 끝날 때 다시 봅니다. 찾은 것과 배운 것이 어디서 갈렸는지가 오늘의 공부입니다.

# %% [markdown]
# ---
#
# ## <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">4 · 중첩 — 그릇 안에 그릇이 들어 있다</mark>

# %% [markdown]
# ### 왜 필요한가
#
# 1. 오전에 만든 파서는 로그 한 건을 딕셔너리로 만들고, 그 딕셔너리를 리스트에 담았습니다. 이미 **리스트 안의 딕셔너리**를 쓰고 있었습니다.
# 2. 계정별로 묶어 보고서를 만들려면 한 겹이 더 필요합니다. **딕셔너리 안의 딕셔너리**입니다.
# 3. JSON 으로 주고받는 데이터는 거의 전부 이 모양입니다. 꺼내는 법을 익혀 두면 6교시가 쉬워집니다.

# %% [markdown]
# ### 이 시간에 나오는 말
#
# | 말 | 뜻 |
# |---|---|
# | 중첩 | 그릇 안에 또 그릇이 들어 있는 모양 |
# | 리스트 안의 딕셔너리 | 같은 모양의 기록이 여러 건 쌓인 것 |
# | 딕셔너리 안의 딕셔너리 | 이름으로 찾아 들어가는 표 |
# | 대괄호 두 번 | 바깥에서 한 겹, 안에서 한 겹 꺼낸다 |

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">4.1 리스트 안의 딕셔너리</mark>
#
# ```python
# books = [
#     {"title": "파이썬", "price": 20000},
#     {"title": "네트워크", "price": 25000},
# ]
#
# print(books[0])             # {'title': '파이썬', 'price': 20000}
# print(books[0]["title"])    # 파이썬
# print(books[1]["price"])    # 25000
# ```
#
# 바깥은 **번호**로, 안쪽은 **이름**으로 꺼냅니다. 순서를 바꾸면 안 됩니다.

# %% [markdown]
# 아래 셀을 먼저 실행합니다. 5교시 내내 이 `logs` 를 씁니다.

# %%
logs = [
    {"time": "09:01", "user": "kim01", "event": "LOGIN_OK", "ip": "10.0.3.21"},
    {"time": "09:05", "user": "admin", "event": "LOGIN_FAIL", "ip": "10.0.9.8"},
    {"time": "09:12", "user": "admin", "event": "LOGIN_FAIL", "ip": "10.0.9.8"},
    {"time": "09:18", "user": "lee02", "event": "LOGIN_FAIL", "ip": "10.0.7.5"},
    {"time": "09:21", "user": "admin", "event": "LOGIN_FAIL", "ip": "10.0.9.8"},
]

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 4-1 · 무엇이 보일까요</font></h3></td></tr></table>
#
# 아래 코드를 실행하면 화면에 무엇이 보일지 적어 보세요. 적은 뒤에 셀을 실행해 맞춰 봅니다.
#
# ```python
# print(logs[0])
# ```
#
# 막히면 바로 위 `4.1 리스트 안의 딕셔너리` 설명을 다시 봅니다.

# %%
print(logs[0])

# %% [markdown]
# ✅ `{'time': '09:01', 'user': 'kim01', 'event': 'LOGIN_OK', 'ip': '10.0.3.21'}`

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 4-2 · 무엇이 보일까요</font></h3></td></tr></table>
#
# 이번에는 그 딕셔너리에서 한 칸만 꺼냅니다.
#
# ```python
# print(logs[1]["user"])
# ```
#
# 막히면 바로 위 `4.1 리스트 안의 딕셔너리` 설명을 다시 봅니다.

# %%
print(logs[1]["user"])

# %% [markdown]
# ✅ `admin`

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 4-3 · 두 번째 로그의 사건 이름</font></h3></td></tr></table>
#
# `logs` 의 **두 번째** 로그에서 `event` 칸을 꺼내 출력하시오.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | `LOGIN_FAIL` |
#
# **💡 힌트**
#
# 1. 리스트의 번호는 0부터 셉니다. 두 번째는 1번입니다.
# 2. 바깥은 번호, 안쪽은 이름 순서입니다.
# 3. 이름은 따옴표까지 그대로 씁니다.

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 4-4 · 모든 계정 이름 출력</font></h3></td></tr></table>
#
# `logs` 를 하나씩 돌면서 **계정 이름**을 한 줄씩 출력하시오.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | `kim01` · `admin` · `admin` · `lee02` · `admin` 다섯 줄 |
#
# **💡 힌트**
#
# 1. `for log in logs:` 로 한 건씩 꺼냅니다.
# 2. 꺼낸 `log` 는 딕셔너리 하나입니다. 번호가 아니라 이름으로 꺼냅니다.
# 3. 출력을 반복 안에 둬야 다섯 줄이 나옵니다.

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 4-5 · 실패한 로그만 고르기</font></h3></td></tr></table>
#
# `event` 가 `LOGIN_FAIL` 인 로그의 **계정 이름과 IP** 를 출력하시오.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | `admin 10.0.9.8` · `lee02 10.0.7.5` · `admin 10.0.9.8` 등 실패 건만 |
#
# **💡 힌트**
#
# 1. 문제 4-4의 반복 안에 `if` 를 하나 넣습니다.
# 2. 같은지 비교할 때는 `==` 를 씁니다.
# 3. `print(a, b)` 로 두 값을 한 줄에 냅니다.

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 4-6 · 실패 건수 세기</font></h3></td></tr></table>
#
# 실패한 로그가 **몇 건**인지 세어 마지막에 한 번 출력하시오.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | `실패 4건` |
#
# **💡 힌트**
#
# 1. 숫자를 담을 이름을 반복 전에 만들고 `0` 을 넣습니다.
# 2. `if` 안에서 그 숫자에 1을 더해 다시 담습니다.
# 3. 출력은 반복이 끝난 뒤 한 번만 합니다.

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# <div style="background:#fff3e0; color:#4e342e; padding:12px 16px; border-radius:8px"><strong>⭐ 도전 문제 (선택)</strong><br>기본 문제를 다 푼 사람만 풉니다. 못 풀어도 괜찮습니다 — <strong>8교시에 남은 도전 문제를 모아 푸는 시간</strong>이 있습니다.</div>

# %% [markdown]
# <table width="100%" bgcolor="#FFE0B2"><tr><td bgcolor="#FFE0B2"><h3><font color="#E65100">⭐ 도전 4-1 · 실패한 계정 목록 만들기</font></h3></td></tr></table>
#
# 실패한 로그의 **계정 이름만** 리스트에 모아 마지막에 출력하시오. 같은 이름이 여러 번 들어가도 됩니다.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | `['admin', 'admin', 'lee02', 'admin']` |
#
# **💡 힌트**
#
# 1. 빈 리스트를 반복 전에 만듭니다.
# 2. 리스트에 값을 더할 때는 `.append()` 를 씁니다.
# 3. 출력은 반복이 끝난 뒤 한 번만 합니다.

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">4.2 딕셔너리 안의 딕셔너리</mark>
#
# ```python
# stores = {
#     "seoul": {"count": 12, "open": True},
#     "busan": {"count": 5, "open": False},
# }
#
# print(stores["seoul"])            # {'count': 12, 'open': True}
# print(stores["seoul"]["count"])   # 12
# stores["daegu"] = {"count": 3, "open": True}   # 새 칸을 만든다
# ```
#
# 바깥도 **이름**, 안쪽도 **이름**입니다. 없는 이름에 값을 넣으면 그 자리에 새로 생깁니다.

# %% [markdown]
# 아래 셀을 먼저 실행합니다.

# %%
report = {
    "admin": {"fail": 3, "ip": "10.0.9.8"},
    "lee02": {"fail": 1, "ip": "10.0.7.5"},
}

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 4-7 · 무엇이 보일까요</font></h3></td></tr></table>
#
# 아래 코드를 실행하면 화면에 무엇이 보일지 적어 보세요.
#
# ```python
# print(report["admin"])
# ```
#
# 막히면 바로 위 `4.2 딕셔너리 안의 딕셔너리` 설명을 다시 봅니다.

# %%
print(report["admin"])

# %% [markdown]
# ✅ `{'fail': 3, 'ip': '10.0.9.8'}`

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 4-8 · 무엇이 보일까요</font></h3></td></tr></table>
#
# 이번에는 안쪽까지 들어갑니다.
#
# ```python
# print(report["admin"]["fail"])
# ```
#
# 막히면 바로 위 `4.2 딕셔너리 안의 딕셔너리` 설명을 다시 봅니다.

# %%
print(report["admin"]["fail"])

# %% [markdown]
# ✅ `3`

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 4-9 · lee02 의 IP</font></h3></td></tr></table>
#
# `report` 에서 `lee02` 의 **IP** 를 꺼내 출력하시오.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | `10.0.7.5` |
#
# **💡 힌트**
#
# 1. 대괄호를 두 번 씁니다.
# 2. 바깥 이름을 먼저, 안쪽 이름을 그다음에 씁니다.
# 3. 이름은 따옴표까지 그대로 씁니다.

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 4-10 · 계정마다 실패 횟수 출력</font></h3></td></tr></table>
#
# `report` 를 하나씩 돌면서 **계정 이름과 실패 횟수**를 한 줄씩 출력하시오.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | `admin 3` · `lee02 1` |
#
# **💡 힌트**
#
# 1. `for user in report:` 로 돌면 **이름**이 하나씩 나옵니다.
# 2. 그 이름으로 `report[user]` 를 꺼내면 안쪽 딕셔너리입니다.
# 3. 안쪽에서 `fail` 칸을 다시 꺼냅니다.

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 4-11 · 실패가 잦은 계정만</font></h3></td></tr></table>
#
# 실패 횟수가 **2회 이상**인 계정만 출력하시오.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | `확인 필요: admin` |
#
# **💡 힌트**
#
# 1. 문제 4-10의 반복 안에 `if` 를 하나 넣습니다.
# 2. 2회 이상은 `>= 2` 로 씁니다.
# 3. f-string 으로 문장을 만들어 출력합니다.

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 4-12 · 계정 한 건 추가하기</font></h3></td></tr></table>
#
# `report` 에 계정 `park03` 을 추가하시오. 실패 0회, IP 는 `10.0.4.11` 입니다. 추가한 뒤 전체를 출력합니다.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | `park03` 이 포함된 딕셔너리 |
#
# **💡 힌트**
#
# 1. 없는 이름에 값을 넣으면 그 자리에 새로 생깁니다.
# 2. 넣을 값 자체가 딕셔너리입니다. 중괄호로 만듭니다.
# 3. 마지막에 `report` 를 통째로 출력합니다.

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# <div style="background:#fff3e0; color:#4e342e; padding:12px 16px; border-radius:8px"><strong>⭐ 도전 문제 (선택)</strong><br>기본 문제를 다 푼 사람만 풉니다. 못 풀어도 괜찮습니다 — <strong>8교시에 남은 도전 문제를 모아 푸는 시간</strong>이 있습니다.</div>

# %% [markdown]
# <table width="100%" bgcolor="#FFE0B2"><tr><td bgcolor="#FFE0B2"><h3><font color="#E65100">⭐ 도전 4-2 · 로그에서 보고서 만들기</font></h3></td></tr></table>
#
# `logs` 를 돌면서 **계정별 실패 횟수** 보고서를 딕셔너리 안의 딕셔너리로 만드시오.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | `{'admin': {'fail': 3}, 'lee02': {'fail': 1}}` |
#
# **💡 힌트**
#
# 1. 빈 딕셔너리를 반복 전에 만듭니다.
# 2. 처음 보는 계정이면 `{'fail': 0}` 을 먼저 넣어 자리를 만듭니다.
# 3. 이미 있는 계정인지는 `if user in report:` 로 확인합니다.

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# ### <mark style="display:block; background:#bbdefb; color:#1a1a1a; padding:6px 12px; border-radius:4px">4.정리 📋 한눈에</mark>
#
# | 쓰는 법 | 뜻 |
# |---|---|
# | `logs[0]` | 리스트에서 번호로 꺼낸다 |
# | `logs[0]["user"]` | 꺼낸 딕셔너리에서 이름으로 다시 꺼낸다 |
# | `report["admin"]["fail"]` | 이름으로 두 번 들어간다 |
# | `report["새이름"] = {...}` | 없는 이름에 넣으면 새로 생긴다 |
# | `for user in report:` | 딕셔너리를 돌면 **이름**이 나온다 |

# %% [markdown]
# ---
#
# # <mark style="display:block; background:#ffe0b2; color:#1a1a1a; padding:6px 12px; border-radius:4px">6교시 (15:00–15:50) · JSON 네 명령</mark>

# %% [markdown]
# ## <mark style="display:block; background:#b3e5fc; color:#0d3c61; padding:6px 12px; border-radius:4px">🔎 공부하는 법을 공부하기</mark>
#
# 설명을 읽기 전에 아래 **두 개념**을 스스로 찾아봅니다. 검색이든 공식 문서든 AI 든 상관없습니다. 찾은 것은 코랩에서 한 번 실행해 확인합니다.
#
# | 찾아볼 개념 | 알아 올 것 |
# |---|---|
# | **JSON** | 왜 프로그램끼리 이 글꼴로 주고받기로 약속했나 |
# | **직렬화(serialize)** | 메모리 속 값을 글자로 편다는 것이 무슨 뜻인가 |
#
# **여기에 기록하세요** — 이 셀을 **두 번 눌러** 아래에 적습니다. 한 줄씩이면 됩니다.
#
# - JSON →
# - 직렬화(serialize) →
#
# 맨 처음에 「드라이브에 사본 저장」을 눌렀다면 여기 적은 것은 내 드라이브의 노트북에 함께 남습니다.
#
# 적어 둔 것은 이 교시가 끝날 때 다시 봅니다. 찾은 것과 배운 것이 어디서 갈렸는지가 오늘의 공부입니다.

# %% [markdown]
# ---
#
# ## <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">5 · JSON — 프로그램끼리 주고받는 글꼴</mark>

# %% [markdown]
# ### 왜 필요한가
#
# 1. 5교시에 만든 딕셔너리는 **코랩을 닫으면 사라집니다.** 파일로 남겨야 다음 프로그램이 이어받습니다.
# 2. 그런데 딕셔너리를 그냥 파일에 쓰면 다시 읽었을 때 글자 덩어리일 뿐입니다. 약속된 글꼴이 필요합니다.
# 3. 그 약속이 **JSON** 입니다. 파이썬·자바·자바스크립트가 모두 읽을 수 있습니다.

# %% [markdown]
# ### 이 시간에 나오는 말
#
# | 말 | 뜻 |
# |---|---|
# | JSON | 프로그램끼리 데이터를 주고받기로 약속한 글꼴 |
# | `dumps` | 파이썬 값 → **글자** (s 는 string) |
# | `loads` | 글자 → 파이썬 값 |
# | `dump` | 파이썬 값 → **파일** |
# | `load` | 파일 → 파이썬 값 |
# | `ensure_ascii` | 한글을 그대로 쓸지 정하는 설정 |
# | `indent` | 줄을 나눠 보기 좋게 할지 정하는 설정 |

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">5.1 `dumps` 와 `loads` — 글자로 바꾼다</mark>
#
# ```python
# import json
#
# menu = {"name": "coffee", "price": 4500}
#
# text = json.dumps(menu)     # 딕셔너리 → 글자
# print(text)                 # {"name": "coffee", "price": 4500}
#
# back = json.loads(text)     # 글자 → 딕셔너리
# print(back["price"])        # 4500
# ```
#
# `dumps` 가 돌려주는 것은 **글자**입니다. 따옴표가 큰따옴표로 바뀌는 것도 JSON 의 약속입니다.

# %%
import json  # JSON 을 다루는 파이썬 기본 도구

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 5-1 · 무엇이 보일까요</font></h3></td></tr></table>
#
# 아래 코드를 실행하면 화면에 무엇이 보일지 적어 보세요. 적은 뒤에 셀을 실행해 맞춰 봅니다.
#
# ```python
# import json
#
# log = {"user": "admin", "fail": 3}
# print(json.dumps(log))
# ```
#
# 막히면 바로 위 `5.1 dumps 와 loads` 설명을 다시 봅니다.

# %%
import json

log = {"user": "admin", "fail": 3}
print(json.dumps(log))

# %% [markdown]
# ✅ `{"user": "admin", "fail": 3}`

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 5-2 · 무엇이 보일까요</font></h3></td></tr></table>
#
# 이번에는 값에 한글이 섞여 있습니다.
#
# ```python
# import json
#
# log = {"user": "admin", "note": "야간 접속"}
# print(json.dumps(log))
# ```
#
# 막히면 바로 위 `5.1 dumps 와 loads` 설명을 다시 봅니다.

# %%
import json

log = {"user": "admin", "note": "야간 접속"}
print(json.dumps(log))

# %% [markdown]
# ✅ `{"user": "admin", "note": "\uc57c\uac04 \uc811\uc18d"}`

# %% [markdown]
# 한글이 `\uc57c` 처럼 바뀌었습니다. 기본 설정이 아스키만 쓰기 때문입니다. 다음 문제에서 고칩니다.

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 5-3 · 딕셔너리를 JSON 글자로</font></h3></td></tr></table>
#
# 주어진 딕셔너리를 JSON 글자로 바꿔 출력하시오.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | `{"user": "lee02", "fail": 1}` |
#
# **💡 힌트**
#
# 1. `import json` 을 먼저 씁니다.
# 2. `json.dumps()` 안에 딕셔너리를 넣습니다.
# 3. 돌려받은 글자를 `print()` 로 출력합니다.

# %%
log = {"user": "lee02", "fail": 1}

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 5-4 · 한글이 깨지지 않게</font></h3></td></tr></table>
#
# 같은 값을 **한글이 그대로 보이게** JSON 글자로 바꿔 출력하시오.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | `{"user": "lee02", "note": "야간 접속"}` |
#
# **💡 힌트**
#
# 1. `json.dumps()` 에 설정을 하나 더 넣습니다.
# 2. 설정 이름은 `ensure_ascii` 이고 값은 `False` 입니다.
# 3. 값과 설정은 쉼표로 나눠 씁니다.

# %%
log = {"user": "lee02", "note": "야간 접속"}

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 5-5 · 보기 좋게 줄 나누기</font></h3></td></tr></table>
#
# 같은 값을 **두 칸 들여쓰기로 줄을 나눠** 출력하시오.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | 중괄호와 칸이 여러 줄로 나뉜 모양 |
#
# **💡 힌트**
#
# 1. 설정 이름은 `indent` 이고 값은 숫자 `2` 입니다.
# 2. `ensure_ascii=False` 도 함께 둡니다.
# 3. 설정 세 개는 쉼표로 나열합니다.

# %%
log = {"user": "lee02", "note": "야간 접속"}

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 5-6 · 글자를 다시 값으로</font></h3></td></tr></table>
#
# 주어진 JSON **글자**를 파이썬 딕셔너리로 되돌린 뒤, `fail` 칸을 출력하시오.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | `3` |
#
# **💡 힌트**
#
# 1. 글자를 값으로 되돌릴 때는 `json.loads()` 를 씁니다.
# 2. 돌려받은 것은 딕셔너리라서 대괄호에 이름을 써서 꺼냅니다.
# 3. 되돌린 결과를 이름 하나에 담아 두면 읽기 쉽습니다.

# %%
text = '{"user": "admin", "fail": 3}'

# %% [markdown]
# <div style="background:#fff3e0; color:#4e342e; padding:12px 16px; border-radius:8px"><strong>⭐ 도전 문제 (선택)</strong><br>기본 문제를 다 푼 사람만 풉니다. 못 풀어도 괜찮습니다 — <strong>8교시에 남은 도전 문제를 모아 푸는 시간</strong>이 있습니다.</div>

# %% [markdown]
# <table width="100%" bgcolor="#FFE0B2"><tr><td bgcolor="#FFE0B2"><h3><font color="#E65100">⭐ 도전 5-1 · 로그 목록 전체를 JSON 글자로</font></h3></td></tr></table>
#
# `logs` 리스트 **전체**를 한글이 그대로 보이고 두 칸 들여쓴 JSON 글자로 바꿔 출력하시오.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | 대괄호로 시작하는 여러 줄 JSON |
#
# **💡 힌트**
#
# 1. 리스트도 `json.dumps()` 에 그대로 넣을 수 있습니다.
# 2. 설정 두 개를 함께 씁니다.
# 3. 리스트라서 중괄호가 아니라 대괄호로 시작합니다.

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">5.2 `dump` 와 `load` — 파일로 남긴다</mark>
#
# ```python
# import json
#
# menu = {"name": "coffee", "price": 4500}
#
# with open("menu.json", "w", encoding="utf-8") as f:
#     json.dump(menu, f, ensure_ascii=False, indent=2)
#
# with open("menu.json", encoding="utf-8") as f:
#     back = json.load(f)
#
# print(back["name"])      # coffee
# ```
#
# **`s` 가 붙으면 글자, 안 붙으면 파일**입니다. 파일에 쓸 때는 모드 `"w"` 를 함께 적습니다.

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 5-7 · 무엇이 보일까요</font></h3></td></tr></table>
#
# 아래 코드를 실행하면 화면에 무엇이 보일지 적어 보세요.
#
# ```python
# import json
#
# report = {"admin": 3}
#
# with open("report.json", "w", encoding="utf-8") as f:
#     json.dump(report, f)
#
# with open("report.json", encoding="utf-8") as f:
#     print(f.read())
# ```
#
# 막히면 바로 위 `5.2 dump 와 load` 설명을 다시 봅니다.

# %%
import json

report = {"admin": 3}

with open("report.json", "w", encoding="utf-8") as f:
    json.dump(report, f)

with open("report.json", encoding="utf-8") as f:
    print(f.read())

# %% [markdown]
# ✅ `{"admin": 3}`

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 5-8 · 무엇이 보일까요</font></h3></td></tr></table>
#
# 이번에는 파일에서 값으로 되돌립니다.
#
# ```python
# import json
#
# with open("report.json", encoding="utf-8") as f:
#     back = json.load(f)
#
# print(back["admin"])
# ```
#
# 막히면 바로 위 `5.2 dump 와 load` 설명을 다시 봅니다.

# %%
import json

with open("report.json", encoding="utf-8") as f:
    back = json.load(f)

print(back["admin"])

# %% [markdown]
# ✅ `3`

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 5-9 · 파일로 저장하기</font></h3></td></tr></table>
#
# 주어진 딕셔너리를 `summary.json` 파일로 저장하시오. 한글이 그대로 보이고 두 칸 들여쓴 모양으로 합니다.
#
# | | |
# |---|---|
# | 🎯 확인 | 셀을 실행해도 화면에는 아무것도 안 나옵니다. 다음 문제에서 읽어 확인합니다. |
#
# **💡 힌트**
#
# 1. 파일을 쓸 때는 `open(이름, "w", encoding="utf-8")` 입니다.
# 2. `json.dump(값, f, ...)` 처럼 **값 다음에 파일**을 넘깁니다.
# 3. 설정 두 개는 그 뒤에 쉼표로 나열합니다.

# %%
summary = {"date": "9/28", "note": "야간 실패 많음", "fail": 4}

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 5-10 · 저장한 파일 읽기</font></h3></td></tr></table>
#
# 앞 문제에서 만든 `summary.json` 을 읽어 `note` 칸을 출력하시오.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | `야간 실패 많음` |
#
# **💡 힌트**
#
# 1. 읽을 때는 모드를 적지 않습니다.
# 2. `json.load(f)` 는 파일을 값으로 되돌려 줍니다.
# 3. 되돌린 것은 딕셔너리입니다.

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 5-11 · 로그 목록을 파일로</font></h3></td></tr></table>
#
# `logs` 리스트를 `logs.json` 으로 저장하시오. 한글 그대로, 두 칸 들여쓰기입니다.
#
# | | |
# |---|---|
# | 🎯 확인 | 저장 뒤 `print("저장했습니다")` 로 끝냅니다. |
#
# **💡 힌트**
#
# 1. 리스트도 딕셔너리와 똑같이 저장됩니다.
# 2. `json.dump()` 의 첫 자리에 리스트를 넣습니다.
# 3. 파일 이름은 `logs.json` 입니다.

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 5-12 · 파일에서 건수 세기</font></h3></td></tr></table>
#
# `logs.json` 을 읽어 로그가 **몇 건**인지 출력하시오.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | `로그 5건` |
#
# **💡 힌트**
#
# 1. `json.load(f)` 로 읽으면 리스트가 그대로 돌아옵니다.
# 2. 리스트의 길이는 `len()` 으로 셉니다.
# 3. f-string 으로 문장을 만듭니다.

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# <div style="background:#fff3e0; color:#4e342e; padding:12px 16px; border-radius:8px"><strong>⭐ 도전 문제 (선택)</strong><br>기본 문제를 다 푼 사람만 풉니다. 못 풀어도 괜찮습니다 — <strong>8교시에 남은 도전 문제를 모아 푸는 시간</strong>이 있습니다.</div>

# %% [markdown]
# <table width="100%" bgcolor="#FFE0B2"><tr><td bgcolor="#FFE0B2"><h3><font color="#E65100">⭐ 도전 5-2 · 파일에서 실패만 세기</font></h3></td></tr></table>
#
# `logs.json` 을 읽어 `LOGIN_FAIL` 이 몇 건인지 출력하시오.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | `실패 4건` |
#
# **💡 힌트**
#
# 1. 먼저 `json.load` 로 리스트를 되돌립니다.
# 2. 5교시 문제 4-6과 뼈대가 같습니다.
# 3. 숫자를 담을 이름을 반복 전에 만듭니다.

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# ### <mark style="display:block; background:#bbdefb; color:#1a1a1a; padding:6px 12px; border-radius:4px">5.정리 📋 한눈에</mark>
#
# | 쓰는 법 | 뜻 |
# |---|---|
# | `json.dumps(값)` | 값 → 글자 |
# | `json.loads(글자)` | 글자 → 값 |
# | `json.dump(값, f)` | 값 → 파일 |
# | `json.load(f)` | 파일 → 값 |
# | `ensure_ascii=False` | 한글을 그대로 쓴다 |
# | `indent=2` | 줄을 나눠 보기 좋게 한다 |

# %% [markdown]
# ---
#
# # <mark style="display:block; background:#ffe0b2; color:#1a1a1a; padding:6px 12px; border-radius:4px">7교시 (16:00–16:50) · 정규화 · normalize_logs.py</mark>

# %% [markdown]
# ## <mark style="display:block; background:#b3e5fc; color:#0d3c61; padding:6px 12px; border-radius:4px">🔎 공부하는 법을 공부하기</mark>
#
# 설명을 읽기 전에 아래 **두 개념**을 스스로 찾아봅니다. 검색이든 공식 문서든 AI 든 상관없습니다. 찾은 것은 코랩에서 한 번 실행해 확인합니다.
#
# | 찾아볼 개념 | 알아 올 것 |
# |---|---|
# | **정규화(normalize)** | 데이터를 한 모양으로 맞추면 무엇이 좋아지나 |
# | **필수 필드** | 없으면 안 되는 항목을 정해 두는 이유는 무엇인가 |
#
# **여기에 기록하세요** — 이 셀을 **두 번 눌러** 아래에 적습니다. 한 줄씩이면 됩니다.
#
# - 정규화(normalize) →
# - 필수 필드 →
#
# 맨 처음에 「드라이브에 사본 저장」을 눌렀다면 여기 적은 것은 내 드라이브의 노트북에 함께 남습니다.
#
# 적어 둔 것은 이 교시가 끝날 때 다시 봅니다. 찾은 것과 배운 것이 어디서 갈렸는지가 오늘의 공부입니다.

# %% [markdown]
# ---
#
# ## <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">6 · 정규화 — 제각각인 로그를 한 모양으로</mark>

# %% [markdown]
# ### 왜 필요한가
#
# 1. 실제 로그는 같은 사건을 `LOGIN_FAIL` 로도 `login_fail` 로도 적습니다. 그대로 세면 같은 사건이 둘로 갈립니다.
# 2. 어떤 줄은 IP 칸이 아예 없습니다. 꺼내려 하면 오전에 본 그 예외가 납니다.
# 3. 세기 전에 **한 모양으로 맞추는 일**을 정규화라고 합니다. 오늘 오후의 도착점입니다.

# %% [markdown]
# ### 이 시간에 나오는 말
#
# | 말 | 뜻 |
# |---|---|
# | 정규화 | 형식이 제각각인 데이터를 한 모양으로 맞추는 일 |
# | `.upper()` | 글자를 모두 대문자로 바꾼다 |
# | 기본값 | 값이 없을 때 대신 넣어 두는 값 |
# | `len()` | 리스트에 값이 몇 개인지 센다 |

# %% [markdown]
# 아래 셀을 먼저 실행합니다. 7교시 내내 이 파일을 씁니다. 대문자·소문자가 섞여 있고 칸이 모자란 줄도 있습니다.
#
# 오전에 쓴 `sample_logs_broken.csv` 와 **이름이 다릅니다.** 오전 파일을 덮어쓰지 않으려고 `sample_logs_raw.csv` 로 둡니다.

# %%
# %%writefile sample_logs_raw.csv
# 09:01,kim01,login_ok,10.0.3.21
# 09:03,lee02,login_fail,10.0.7.5
# 03:22,hacker
# 09:05,admin,LOGIN_FAIL,10.0.9.8
# 09:12,admin,login_fail,10.0.9.8
# 02:40,hacker,login_fail,10.0.9.9
# 09:18,lee02,login_fail,10.0.7.5
# 09:21,admin,login_fail,10.0.9.8
# 09:24,park03,LOGIN_OK,10.0.4.11
# 09:41,guest
# 09:45,kim01,login_ok,10.0.3.21

# %%
# !cat sample_logs_raw.csv

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">6.1 한 모양으로 맞추기</mark>
#
# ```python
# word = "seoul"
# print(word.upper())          # SEOUL
#
# parts = "a,b".split(",")
# print(len(parts))            # 2
# ```
#
# 칸이 모자란 줄은 **꺼내기 전에** `len()` 으로 개수를 확인해 기본값을 넣습니다.

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 6-1 · 무엇이 보일까요</font></h3></td></tr></table>
#
# 아래 코드를 실행하면 화면에 무엇이 보일지 적어 보세요. 적은 뒤에 셀을 실행해 맞춰 봅니다.
#
# ```python
# event = "login_fail"
# print(event.upper())
# ```
#
# 막히면 바로 위 `6.1 한 모양으로 맞추기` 설명을 다시 봅니다.

# %%
event = "login_fail"
print(event.upper())

# %% [markdown]
# ✅ `LOGIN_FAIL`

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 6-2 · 무엇이 보일까요</font></h3></td></tr></table>
#
# 이번에는 칸이 몇 개인지 셉니다.
#
# ```python
# line = "09:41,guest"
# parts = line.split(",")
# print(len(parts))
# ```
#
# 막히면 바로 위 `6.1 한 모양으로 맞추기` 설명을 다시 봅니다.

# %%
line = "09:41,guest"
parts = line.split(",")
print(len(parts))

# %% [markdown]
# ✅ `2`

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 6-3 · 사건 이름을 대문자로</font></h3></td></tr></table>
#
# 주어진 줄에서 **사건 이름**을 꺼내 대문자로 바꿔 출력하시오.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | `LOGIN_FAIL` |
#
# **💡 힌트**
#
# 1. 줄을 쉼표로 나눕니다.
# 2. 사건 이름은 세 번째 칸입니다. 번호는 2입니다.
# 3. 꺼낸 값 뒤에 `.upper()` 를 붙입니다.

# %%
line = "09:12,admin,login_fail,10.0.9.8"

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 6-4 · 줄 하나를 정규화하기</font></h3></td></tr></table>
#
# 줄 하나를 딕셔너리로 만들되, `event` 는 **대문자로** 넣고 `hour` 칸을 **숫자로** 더하시오.
#
# - 칸 이름은 `time`·`user`·`event`·`ip`·`hour` 다섯 개입니다.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | `{'time': '09:12', 'user': 'admin', 'event': 'LOGIN_FAIL', 'ip': '10.0.9.8', 'hour': 9}` |
#
# **💡 힌트**
#
# 1. 딕셔너리는 중괄호로 만들고 이름과 값을 콜론으로 잇습니다.
# 2. `event` 자리에는 `.upper()` 를 붙인 값을 넣습니다.
# 3. `hour` 는 시각을 콜론으로 나눠 앞 칸에 `int()` 를 씌웁니다.

# %%
line = "09:12,admin,login_fail,10.0.9.8"

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 6-5 · IP 가 없으면 unknown</font></h3></td></tr></table>
#
# 칸이 모자란 줄에서도 멈추지 않게, **IP 칸이 없으면 `unknown`** 을 넣으시오.
#
# - 칸이 네 개인지 `len()` 으로 먼저 확인합니다.
#
# | | |
# |---|---|
# | 주어지는 값 | `line = "09:41,guest"` |
# | 🎯 나와야 하는 결과 | `unknown` |
#
# **💡 힌트**
#
# 1. `parts` 의 개수를 `len()` 으로 셉니다.
# 2. 네 개 이상이면 `parts[3]`, 아니면 `unknown` 입니다.
# 3. `if` 와 `else` 로 두 갈래를 나누고 각각 이름 하나에 담습니다.

# %%
line = "09:41,guest"

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 6-6 · 파일 전체를 정규화하기</font></h3></td></tr></table>
#
# `sample_logs_raw.csv` 를 한 줄씩 읽어 **정규화한 딕셔너리를 리스트에 모으고** 건수를 출력하시오.
#
# 1. 빈 줄과 칸이 두 개 이하인 줄은 건너뜁니다.
# 2. `event` 는 대문자로, IP 가 없으면 `unknown` 으로 넣습니다.
# 3. 시각이 숫자로 안 바뀌는 줄은 `try`·`except ValueError` 로 건너뜁니다.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | `정규화 9건` |
#
# **💡 힌트**
#
# 1. 오전에 쓴 파일 읽기 뼈대를 그대로 씁니다.
# 2. 칸 수가 모자란 줄은 `if len(parts) < 3:` 일 때 `continue` 대신 `else` 로 감싸 건너뜁니다.
# 3. 딕셔너리를 만드는 줄을 `try` 안에 둡니다.

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# <div style="background:#fff3e0; color:#4e342e; padding:12px 16px; border-radius:8px"><strong>⭐ 도전 문제 (선택)</strong><br>기본 문제를 다 푼 사람만 풉니다. 못 풀어도 괜찮습니다 — <strong>8교시에 남은 도전 문제를 모아 푸는 시간</strong>이 있습니다.</div>

# %% [markdown]
# <table width="100%" bgcolor="#FFE0B2"><tr><td bgcolor="#FFE0B2"><h3><font color="#E65100">⭐ 도전 6-1 · 야간 실패만 고르기</font></h3></td></tr></table>
#
# 정규화한 목록에서 **0시부터 6시 사이의 `LOGIN_FAIL`** 만 골라 계정과 시각을 출력하시오.
#
# | | |
# |---|---|
# | 🎯 나와야 하는 결과 | `hacker 02:40` |
#
# **💡 힌트**
#
# 1. 문제 6-6의 결과 리스트를 그대로 씁니다.
# 2. `if` 조건 세 개를 `and` 로 잇습니다.
# 3. `hour` 칸은 이미 숫자라서 바로 비교할 수 있습니다.

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">6.2 `normalize_logs.py` 조립</mark>
#
# `.py` 파일 안에서도 `json.dump` 를 그대로 씁니다. 오전에 배운 `%%writefile` 과 `!python` 으로 만들고 돌립니다.
#
# ```python
# %%writefile demo_save.py
# import json
#
# data = {"city": "seoul", "count": 3}
#
# with open("demo.json", "w", encoding="utf-8") as f:
#     json.dump(data, f, ensure_ascii=False, indent=2)
#
# print("저장 완료")
# ```
#
# 아래 셀을 먼저 실행해 `demo_save.py` 를 만듭니다.

# %%
# %%writefile demo_save.py
import json

data = {"city": "seoul", "count": 3}

with open("demo.json", "w", encoding="utf-8") as f:
    json.dump(data, f, ensure_ascii=False, indent=2)

print("저장 완료")

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 6-7 · 무엇이 보일까요</font></h3></td></tr></table>
#
# 위에서 만든 파일을 실행합니다. 화면에 무엇이 보일지 적어 보세요.
#
# ```python
# !python demo_save.py
# ```
#
# 막히면 바로 위 `6.2 normalize_logs.py 조립` 설명을 다시 봅니다.

# %%
# !python demo_save.py

# %% [markdown]
# ✅ `저장 완료`

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 6-8 · 무엇이 보일까요</font></h3></td></tr></table>
#
# 이번에는 그 실행이 남긴 파일을 열어 봅니다.
#
# ```python
# !cat demo.json
# ```
#
# 막히면 바로 위 `6.2 normalize_logs.py 조립` 설명을 다시 봅니다.

# %%
# !cat demo.json

# %% [markdown]
# ✅ `{ "city": "seoul", "count": 3 } — 두 칸 들여쓴 여러 줄`

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 6-9 · normalize_logs.py 만들기</font></h3></td></tr></table>
#
# 오늘 오후의 산출물 **`normalize_logs.py`** 를 만드시오. 새 문법은 없습니다. 조각을 잇는 시간입니다.
#
# 1. 새 코드 셀 맨 첫 줄에 `%%writefile normalize_logs.py` 를 씁니다.
# 2. `import json` 을 씁니다.
# 3. 문제 6-6의 정규화 코드를 그대로 가져옵니다.
# 4. 결과 리스트를 `normalized_logs.json` 으로 저장합니다. 한글 그대로, 두 칸 들여쓰기입니다.
# 5. 마지막에 `정규화 9건` 을 화면에 출력합니다.
#
# | | |
# |---|---|
# | 🎯 화면 | `정규화 9건` |
# | 🎯 파일 | `normalized_logs.json` |
#
# **💡 힌트**
#
# 1. `%%writefile` 셀은 실행해도 코드가 돌지 않고 파일로 저장됩니다.
# 2. `json.dump(logs, f, ensure_ascii=False, indent=2)` 로 저장합니다.
# 3. `print` 는 파일 맨 아래에 둡니다.

# %%
# %%writefile normalize_logs.py

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 6-10 · 돌려 보고 결과 확인하기</font></h3></td></tr></table>
#
# 만든 파일을 실행하고, 남은 JSON 을 열어 확인하시오.
#
# 1. 새 셀에서 `!python normalize_logs.py` 를 실행합니다.
# 2. 또 새 셀에서 `!cat normalized_logs.json` 으로 내용을 봅니다.
# 3. `event` 가 전부 대문자인지, `ip` 에 `unknown` 이 들어간 줄이 있는지 봅니다.
#
# | | |
# |---|---|
# | 🎯 화면 | `정규화 9건` 과 여러 줄짜리 JSON |
#
# **💡 힌트**
#
# 1. `!` 는 터미널 명령이라는 표시입니다.
# 2. `!cat` 은 파일 내용을 화면에 보여 줍니다.
# 3. 두 명령은 셀을 나눠 실행하는 편이 보기 좋습니다.

# %%
# !python normalize_logs.py

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 6-11 · 드라이브에 남기기</font></h3></td></tr></table>
#
# 완성한 `normalize_logs.py` 를 내 드라이브 `agent_core` 폴더에 저장하시오. 오늘의 산출물입니다.
#
# 1. 아래 셀로 드라이브를 연결합니다. 계정 선택 창이 뜨면 코랩을 연 계정을 고르고 허용을 누릅니다.
# 2. `agent_core` 폴더로 들어갑니다.
# 3. 7교시 맨 위의 데이터 셀과 문제 6-9의 `%%writefile` 셀을 **다시 실행**합니다.
# 4. `!python normalize_logs.py` 로 확인합니다.
#
# | | |
# |---|---|
# | 🎯 확인 | 드라이브 `agent_core` 에 `normalize_logs.py` 와 `normalized_logs.json` 이 있다 |
#
# **💡 힌트**
#
# 1. 폴더를 옮기지 않으면 파일이 코랩 안에만 남습니다.
# 2. `%cd` 로 폴더를 옮긴 뒤 셀을 다시 실행해야 그 폴더에 저장됩니다.
# 3. 데이터 파일도 같은 폴더에 있어야 실행됩니다.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# <div style="background:#fff3e0; color:#4e342e; padding:12px 16px; border-radius:8px"><strong>⭐ 도전 문제 (선택)</strong><br>기본 문제를 다 푼 사람만 풉니다. 못 풀어도 괜찮습니다 — <strong>8교시에 남은 도전 문제를 모아 푸는 시간</strong>이 있습니다.</div>

# %% [markdown]
# <table width="100%" bgcolor="#FFE0B2"><tr><td bgcolor="#FFE0B2"><h3><font color="#E65100">⭐ 도전 6-2 · 계정별 보고서도 남기기</font></h3></td></tr></table>
#
# 정규화한 목록에서 **계정별 실패 횟수** 보고서를 만들어 `report.json` 으로 저장하시오.
#
# | | |
# |---|---|
# | 🎯 파일 | `{"admin": 3, "lee02": 2, "hacker": 1}` 모양 |
#
# **💡 힌트**
#
# 1. 5교시 도전 ⭐4-2와 뼈대가 같습니다.
# 2. 이번에는 안쪽 딕셔너리 없이 숫자만 담아도 됩니다.
# 3. 저장은 `json.dump` 로 합니다.

# %%
# 여기에 코드를 입력하세요

# %% [markdown]
# ### <mark style="display:block; background:#bbdefb; color:#1a1a1a; padding:6px 12px; border-radius:4px">6.정리 📋 한눈에</mark>
#
# | 쓰는 법 | 뜻 |
# |---|---|
# | `.upper()` | 글자를 대문자로 바꾼다 |
# | `len(parts) >= 4` | 칸이 충분한지 먼저 확인한다 |
# | 기본값 | 값이 없을 때 `unknown` 같은 값을 넣어 둔다 |
# | `json.dump(logs, f, ...)` | 정규화 결과를 파일로 남긴다 |
#
# 오늘 오후의 산출물은 드라이브 `agent_core` 폴더의 **`normalize_logs.py`** 와 그것이 남긴 **`normalized_logs.json`** 입니다.

# %% [markdown]
# ---
#
# # <mark style="display:block; background:#ffe0b2; color:#1a1a1a; padding:6px 12px; border-radius:4px">8교시 (17:00–17:30) · 돌려 보기 · 남은 도전 문제 · VS Code</mark>

# %% [markdown]
# 새 문법은 없습니다. 오늘 만든 것을 확인하고 마무리합니다.
#
# ### 8.1 오늘 만든 것 확인하기
#
# | 무엇 | 어디에 |
# |---|---|
# | `log_parser.py` · `agent.log` | 드라이브 `agent_core` (오전) |
# | `normalize_logs.py` · `normalized_logs.json` | 드라이브 `agent_core` (오후) |
#
# drive.google.com 의 `agent_core` 폴더를 열어 네 개가 다 있는지 봅니다.

# %% [markdown]
# ### 8.2 남은 ⭐도전 문제를 모아 푸는 시간
#
# 오늘 넘어간 도전 문제를 여기서 풉니다. **다 풀지 않아도 됩니다.** 하나라도 더 해 보는 것이 목적입니다.
#
# | 어디 | 도전 문제 |
# |---|---|
# | 5교시 | ⭐4-1 실패한 계정 목록 · ⭐4-2 로그에서 보고서 만들기 |
# | 6교시 | ⭐5-1 목록 전체를 JSON 글자로 · ⭐5-2 파일에서 실패만 세기 |
# | 7교시 | ⭐6-1 야간 실패만 고르기 · ⭐6-2 계정별 보고서도 남기기 |
#
# 막히면 문제 아래 **💡 힌트**를 먼저 보고, 그래도 안 되면 맨 아래 정답을 엽니다.

# %% [markdown]
# ### 8.3 오늘 배운 것 한눈에
#
# | 시간 | 배운 것 |
# |---|---|
# | 오전 | `try`·`except` · 예외 이름별로 잡기 · `finally` · `logging` |
# | 오후 | 리스트 안의 딕셔너리 · 딕셔너리 안의 딕셔너리 · JSON 네 명령 · 정규화 |
#
# 내일(9/29)은 줄글에서 필요한 조각만 꺼내는 **정규표현식**을 배웁니다. 오늘 만든 `normalized_logs.json` 을 그대로 이어서 씁니다.

# %% [markdown]
# ### 8.4 VS Code 설치
#
# 10/2(금)부터 내 컴퓨터의 터미널에서도 코드를 실행해 봅니다. 오늘 설치까지 해 둡니다.
#
# 1. `vscode 다운로드` 로 검색해 공식 페이지에서 내려받습니다.
# 2. 설치한 뒤 한 번 실행해 화면이 뜨는지만 확인합니다.
# 3. 설정은 다음 시간에 같이 합니다. 지금은 설치만 하면 됩니다.

# %% [markdown]
# ---
#
# # <mark style="display:block; background:#f8bbd0; color:#1a1a1a; padding:6px 12px; border-radius:4px">정답 · 먼저 풀어 본 뒤에 엽니다</mark>
#
# 각 셀은 제목만 보입니다. 「코드 표시」를 누르면 코드가 열립니다. 정답 셀은 혼자서 실행됩니다.

# %%
#@title 정답 4-3 { display-mode: "form" }
logs = [
    {"time": "09:01", "user": "kim01", "event": "LOGIN_OK", "ip": "10.0.3.21"},
    {"time": "09:05", "user": "admin", "event": "LOGIN_FAIL", "ip": "10.0.9.8"},
]

print(logs[1]["event"])

# %%
#@title 정답 4-4 { display-mode: "form" }
logs = [
    {"time": "09:01", "user": "kim01", "event": "LOGIN_OK", "ip": "10.0.3.21"},
    {"time": "09:05", "user": "admin", "event": "LOGIN_FAIL", "ip": "10.0.9.8"},
    {"time": "09:12", "user": "admin", "event": "LOGIN_FAIL", "ip": "10.0.9.8"},
    {"time": "09:18", "user": "lee02", "event": "LOGIN_FAIL", "ip": "10.0.7.5"},
    {"time": "09:21", "user": "admin", "event": "LOGIN_FAIL", "ip": "10.0.9.8"},
]

for log in logs:
    print(log["user"])

# %%
#@title 정답 4-5 { display-mode: "form" }
logs = [
    {"time": "09:01", "user": "kim01", "event": "LOGIN_OK", "ip": "10.0.3.21"},
    {"time": "09:05", "user": "admin", "event": "LOGIN_FAIL", "ip": "10.0.9.8"},
    {"time": "09:12", "user": "admin", "event": "LOGIN_FAIL", "ip": "10.0.9.8"},
    {"time": "09:18", "user": "lee02", "event": "LOGIN_FAIL", "ip": "10.0.7.5"},
    {"time": "09:21", "user": "admin", "event": "LOGIN_FAIL", "ip": "10.0.9.8"},
]

for log in logs:
    if log["event"] == "LOGIN_FAIL":
        print(log["user"], log["ip"])

# %%
#@title 정답 4-6 { display-mode: "form" }
logs = [
    {"time": "09:01", "user": "kim01", "event": "LOGIN_OK", "ip": "10.0.3.21"},
    {"time": "09:05", "user": "admin", "event": "LOGIN_FAIL", "ip": "10.0.9.8"},
    {"time": "09:12", "user": "admin", "event": "LOGIN_FAIL", "ip": "10.0.9.8"},
    {"time": "09:18", "user": "lee02", "event": "LOGIN_FAIL", "ip": "10.0.7.5"},
    {"time": "09:21", "user": "admin", "event": "LOGIN_FAIL", "ip": "10.0.9.8"},
]

fail_count = 0

for log in logs:
    if log["event"] == "LOGIN_FAIL":
        fail_count = fail_count + 1

print(f"실패 {fail_count}건")

# %%
#@title 정답 ⭐4-1 { display-mode: "form" }
logs = [
    {"time": "09:01", "user": "kim01", "event": "LOGIN_OK", "ip": "10.0.3.21"},
    {"time": "09:05", "user": "admin", "event": "LOGIN_FAIL", "ip": "10.0.9.8"},
    {"time": "09:12", "user": "admin", "event": "LOGIN_FAIL", "ip": "10.0.9.8"},
    {"time": "09:18", "user": "lee02", "event": "LOGIN_FAIL", "ip": "10.0.7.5"},
    {"time": "09:21", "user": "admin", "event": "LOGIN_FAIL", "ip": "10.0.9.8"},
]

failed_users = []

for log in logs:
    if log["event"] == "LOGIN_FAIL":
        failed_users.append(log["user"])

print(failed_users)

# %%
#@title 정답 4-9 { display-mode: "form" }
report = {
    "admin": {"fail": 3, "ip": "10.0.9.8"},
    "lee02": {"fail": 1, "ip": "10.0.7.5"},
}

print(report["lee02"]["ip"])

# %%
#@title 정답 4-10 { display-mode: "form" }
report = {
    "admin": {"fail": 3, "ip": "10.0.9.8"},
    "lee02": {"fail": 1, "ip": "10.0.7.5"},
}

for user in report:
    print(user, report[user]["fail"])

# %%
#@title 정답 4-11 { display-mode: "form" }
report = {
    "admin": {"fail": 3, "ip": "10.0.9.8"},
    "lee02": {"fail": 1, "ip": "10.0.7.5"},
}

for user in report:
    if report[user]["fail"] >= 2:
        print(f"확인 필요: {user}")

# %%
#@title 정답 4-12 { display-mode: "form" }
report = {
    "admin": {"fail": 3, "ip": "10.0.9.8"},
    "lee02": {"fail": 1, "ip": "10.0.7.5"},
}

report["park03"] = {"fail": 0, "ip": "10.0.4.11"}

print(report)

# %%
#@title 정답 ⭐4-2 { display-mode: "form" }
logs = [
    {"time": "09:01", "user": "kim01", "event": "LOGIN_OK", "ip": "10.0.3.21"},
    {"time": "09:05", "user": "admin", "event": "LOGIN_FAIL", "ip": "10.0.9.8"},
    {"time": "09:12", "user": "admin", "event": "LOGIN_FAIL", "ip": "10.0.9.8"},
    {"time": "09:18", "user": "lee02", "event": "LOGIN_FAIL", "ip": "10.0.7.5"},
    {"time": "09:21", "user": "admin", "event": "LOGIN_FAIL", "ip": "10.0.9.8"},
]

report = {}

for log in logs:
    if log["event"] == "LOGIN_FAIL":
        user = log["user"]
        if user in report:
            report[user]["fail"] = report[user]["fail"] + 1
        else:
            report[user] = {"fail": 1}

print(report)

# %%
#@title 정답 5-3 { display-mode: "form" }
import json

log = {"user": "lee02", "fail": 1}

print(json.dumps(log))

# %%
#@title 정답 5-4 { display-mode: "form" }
import json

log = {"user": "lee02", "note": "야간 접속"}

print(json.dumps(log, ensure_ascii=False))

# %%
#@title 정답 5-5 { display-mode: "form" }
import json

log = {"user": "lee02", "note": "야간 접속"}

print(json.dumps(log, ensure_ascii=False, indent=2))

# %%
#@title 정답 5-6 { display-mode: "form" }
import json

text = '{"user": "admin", "fail": 3}'

back = json.loads(text)

print(back["fail"])

# %%
#@title 정답 ⭐5-1 { display-mode: "form" }
import json

logs = [
    {"time": "09:01", "user": "kim01", "event": "LOGIN_OK", "ip": "10.0.3.21"},
    {"time": "09:05", "user": "admin", "event": "LOGIN_FAIL", "ip": "10.0.9.8"},
    {"time": "09:12", "user": "admin", "event": "LOGIN_FAIL", "ip": "10.0.9.8"},
    {"time": "09:18", "user": "lee02", "event": "LOGIN_FAIL", "ip": "10.0.7.5"},
    {"time": "09:21", "user": "admin", "event": "LOGIN_FAIL", "ip": "10.0.9.8"},
]

print(json.dumps(logs, ensure_ascii=False, indent=2))

# %%
#@title 정답 5-9 { display-mode: "form" }
import json

summary = {"date": "9/28", "note": "야간 실패 많음", "fail": 4}

with open("summary.json", "w", encoding="utf-8") as f:
    json.dump(summary, f, ensure_ascii=False, indent=2)

print("저장했습니다")

# %%
#@title 정답 5-10 { display-mode: "form" }
import json

summary = {"date": "9/28", "note": "야간 실패 많음", "fail": 4}
with open("summary.json", "w", encoding="utf-8") as f:
    json.dump(summary, f, ensure_ascii=False, indent=2)

with open("summary.json", encoding="utf-8") as f:
    back = json.load(f)

print(back["note"])

# %%
#@title 정답 5-11 { display-mode: "form" }
import json

logs = [
    {"time": "09:01", "user": "kim01", "event": "LOGIN_OK", "ip": "10.0.3.21"},
    {"time": "09:05", "user": "admin", "event": "LOGIN_FAIL", "ip": "10.0.9.8"},
    {"time": "09:12", "user": "admin", "event": "LOGIN_FAIL", "ip": "10.0.9.8"},
    {"time": "09:18", "user": "lee02", "event": "LOGIN_FAIL", "ip": "10.0.7.5"},
    {"time": "09:21", "user": "admin", "event": "LOGIN_FAIL", "ip": "10.0.9.8"},
]

with open("logs.json", "w", encoding="utf-8") as f:
    json.dump(logs, f, ensure_ascii=False, indent=2)

print("저장했습니다")

# %%
#@title 정답 5-12 { display-mode: "form" }
import json

logs = [
    {"time": "09:01", "user": "kim01", "event": "LOGIN_OK", "ip": "10.0.3.21"},
    {"time": "09:05", "user": "admin", "event": "LOGIN_FAIL", "ip": "10.0.9.8"},
    {"time": "09:12", "user": "admin", "event": "LOGIN_FAIL", "ip": "10.0.9.8"},
    {"time": "09:18", "user": "lee02", "event": "LOGIN_FAIL", "ip": "10.0.7.5"},
    {"time": "09:21", "user": "admin", "event": "LOGIN_FAIL", "ip": "10.0.9.8"},
]
with open("logs.json", "w", encoding="utf-8") as f:
    json.dump(logs, f, ensure_ascii=False, indent=2)

with open("logs.json", encoding="utf-8") as f:
    back = json.load(f)

print(f"로그 {len(back)}건")

# %%
#@title 정답 ⭐5-2 { display-mode: "form" }
import json

logs = [
    {"time": "09:01", "user": "kim01", "event": "LOGIN_OK", "ip": "10.0.3.21"},
    {"time": "09:05", "user": "admin", "event": "LOGIN_FAIL", "ip": "10.0.9.8"},
    {"time": "09:12", "user": "admin", "event": "LOGIN_FAIL", "ip": "10.0.9.8"},
    {"time": "09:18", "user": "lee02", "event": "LOGIN_FAIL", "ip": "10.0.7.5"},
    {"time": "09:21", "user": "admin", "event": "LOGIN_FAIL", "ip": "10.0.9.8"},
]
with open("logs.json", "w", encoding="utf-8") as f:
    json.dump(logs, f, ensure_ascii=False, indent=2)

with open("logs.json", encoding="utf-8") as f:
    back = json.load(f)

fail_count = 0
for log in back:
    if log["event"] == "LOGIN_FAIL":
        fail_count = fail_count + 1

print(f"실패 {fail_count}건")

# %%
#@title 정답 6-3 { display-mode: "form" }
line = "09:12,admin,login_fail,10.0.9.8"
parts = line.split(",")

print(parts[2].upper())

# %%
#@title 정답 6-4 { display-mode: "form" }
line = "09:12,admin,login_fail,10.0.9.8"
parts = line.split(",")

log = {
    "time": parts[0],
    "user": parts[1],
    "event": parts[2].upper(),
    "ip": parts[3],
    "hour": int(parts[0].split(":")[0]),
}

print(log)

# %%
#@title 정답 6-5 { display-mode: "form" }
line = "09:41,guest"
parts = line.split(",")

if len(parts) >= 4:
    ip = parts[3]
else:
    ip = "unknown"

print(ip)

# %%
#@title 정답 6-6 { display-mode: "form" }
logs = []

with open("sample_logs_raw.csv", encoding="utf-8") as f:
    for line in f:
        parts = line.strip().split(",")
        if len(parts) >= 3:
            if len(parts) >= 4:
                ip = parts[3]
            else:
                ip = "unknown"
            try:
                logs.append({
                    "time": parts[0],
                    "user": parts[1],
                    "event": parts[2].upper(),
                    "ip": ip,
                    "hour": int(parts[0].split(":")[0]),
                })
            except ValueError:
                pass

print(f"정규화 {len(logs)}건")

# %%
#@title 정답 ⭐6-1 { display-mode: "form" }
logs = []
with open("sample_logs_raw.csv", encoding="utf-8") as f:
    for line in f:
        parts = line.strip().split(",")
        if len(parts) >= 3:
            if len(parts) >= 4:
                ip = parts[3]
            else:
                ip = "unknown"
            try:
                logs.append({"time": parts[0], "user": parts[1],
                             "event": parts[2].upper(), "ip": ip,
                             "hour": int(parts[0].split(":")[0])})
            except ValueError:
                pass

for log in logs:
    if log["event"] == "LOGIN_FAIL" and log["hour"] >= 0 and log["hour"] <= 6:
        print(log["user"], log["time"])

# %%
#@title 정답 6-9 { display-mode: "form" }
code = """import json

logs = []

with open("sample_logs_raw.csv", encoding="utf-8") as f:
    for line in f:
        parts = line.strip().split(",")
        if len(parts) >= 3:
            if len(parts) >= 4:
                ip = parts[3]
            else:
                ip = "unknown"
            try:
                logs.append({
                    "time": parts[0],
                    "user": parts[1],
                    "event": parts[2].upper(),
                    "ip": ip,
                    "hour": int(parts[0].split(":")[0]),
                })
            except ValueError:
                pass

with open("normalized_logs.json", "w", encoding="utf-8") as f:
    json.dump(logs, f, ensure_ascii=False, indent=2)

print(f"정규화 {len(logs)}건")
"""

with open("normalize_logs.py", "w", encoding="utf-8") as f:
    f.write(code)

print("normalize_logs.py 를 만들었습니다. 새 셀에서 !python normalize_logs.py 를 실행하세요.")

# %%
#@title 정답 6-10 { display-mode: "form" }
print("아래 두 줄을 각각 새 셀에서 실행합니다.")
print("!python normalize_logs.py")
print("!cat normalized_logs.json")

# %%
#@title 정답 6-11 { display-mode: "form" }
print("!mkdir -p /content/drive/MyDrive/agent_core")
print("%cd /content/drive/MyDrive/agent_core")
print("그다음 데이터 셀과 %%writefile 셀을 다시 실행합니다.")

# %%
#@title 정답 ⭐6-2 { display-mode: "form" }
import json

logs = []
with open("sample_logs_raw.csv", encoding="utf-8") as f:
    for line in f:
        parts = line.strip().split(",")
        if len(parts) >= 3:
            if len(parts) >= 4:
                ip = parts[3]
            else:
                ip = "unknown"
            try:
                logs.append({"time": parts[0], "user": parts[1],
                             "event": parts[2].upper(), "ip": ip,
                             "hour": int(parts[0].split(":")[0])})
            except ValueError:
                pass

report = {}
for log in logs:
    if log["event"] == "LOGIN_FAIL":
        user = log["user"]
        if user in report:
            report[user] = report[user] + 1
        else:
            report[user] = 1

with open("report.json", "w", encoding="utf-8") as f:
    json.dump(report, f, ensure_ascii=False, indent=2)

print(report)
