# %% [markdown]
# # <mark style="display:block; background:#d1c4e9; color:#1a1a1a; padding:6px 12px; border-radius:4px">9/22(화) · 개발환경 · 변수 · 리스트 — 정답과 해설</mark>
#
# 오늘은 파이썬을 처음 만집니다. **외울 것은 없습니다.**
#
# 예시를 세 개 보고, 문제를 세 개 풉니다. 이것을 일곱 번 반복합니다.

# %% [markdown]
# > **교사용·복습용 정답 노트북**
# >
# > 먼저 학생용 노트북에서 문제를 푼 뒤 확인하세요. 파란색 `✅ 정답` 상자 아래에 실행 가능한 풀이 코드가 있습니다.

# %% [markdown]
# ## <mark style="display:block; background:#c8e6c9; color:#1a1a1a; padding:6px 12px; border-radius:4px">시작하기 · 이 노트북을 여는 법</mark>
#
# ### ### <mark style="display:block; background:#c8e6c9; color:#1a1a1a; padding:6px 12px; border-radius:4px">0.1 맨 먼저 · 내 사본 만들기</mark>
#
# 1. 위 메뉴에서 **파일 › 드라이브에 사본 저장** 을 누릅니다.
# 2. 제목이 **「사본: …」** 으로 바뀌면 된 것입니다.
# 3. 사본을 만들지 않으면 **내가 쓴 코드가 저장되지 않습니다.**
#
# ### ### <mark style="display:block; background:#c8e6c9; color:#1a1a1a; padding:6px 12px; border-radius:4px">0.2 셀을 실행하는 법</mark>
#
# 1. 셀을 한 번 누릅니다.
# 2. **Shift + Enter** 를 칩니다. 왼쪽 **▶** 를 눌러도 같습니다.
#
# ### ### <mark style="display:block; background:#c8e6c9; color:#1a1a1a; padding:6px 12px; border-radius:4px">0.3 이 노트북을 읽는 법</mark>
#
# 1. **📖 예시** — 읽고 **그대로 실행만** 합니다. 고쳐도 됩니다.
# 2. **🤔 이런 의문** — 처음 배울 때 누구나 걸리는 자리입니다.
# 3. **📋 정리** — 표로 한 번에 봅니다.
# 4. **✍️ 문제** — `# 여기에 직접 작성 👇` 아래에 직접 씁니다.
# 5. 문제마다 **나와야 하는 결과**가 적혀 있습니다. 그것과 같으면 맞은 것입니다.
# 6. 막히면 문제 아래 **▸ 힌트 보기** 를 누르세요. 먼저 스스로 해 보고 누르는 것이 좋습니다.
#
# ### ### <mark style="display:block; background:#c8e6c9; color:#1a1a1a; padding:6px 12px; border-radius:4px">0.4 오늘 배우는 일곱 가지</mark>
#
# 1. 변수 — 값에 이름을 지정한다
# 2. 자료형 — 값의 갈래
# 3. f-string — 문장 안에 값을 끼워 넣는다
# 4. 형변환 — 값의 갈래를 바꾼다
# 5. 리스트 — 여러 값을 순서대로 담는다
# 6. 딕셔너리 — 키로 값을 꺼낸다
# 7. `.get()` — 없는 키를 물어도 멈추지 않는다

# %%
# 이 셀의 목적 — 노트북이 제대로 도는지 확인한다
# 셀을 누르고 Shift + Enter 를 쳐 보세요.

print("준비 끝")          # print = 괄호 안의 값을 화면에 찍는다

# %% [markdown]
# ---
#
# # <mark style="display:block; background:#ffe0b2; color:#1a1a1a; padding:6px 12px; border-radius:4px">2교시 (15:00–15:50)</mark>
#
# **변수  ·  자료형  ·  f-string**
#
# 1. 먼저 **슬라이드로 개념**을 봅니다.
# 2. 여기 노트북으로 와서 **같은 것을 코드로** 한 번 더 봅니다.
# 3. 남은 시간에 **각자 문제**를 풉니다.

# %% [markdown]
# ## <mark style="display:block; background:#c8e6c9; color:#1a1a1a; padding:6px 12px; border-radius:4px">📖 같이 봅니다 — 예시 9개</mark>
#
# 강사와 함께 셀을 하나씩 실행합니다. **고쳐 보셔도 됩니다.**

# %% [markdown]
# ---
#
# ## <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">1 · 변수 — 값에 이름을 지정한다</mark>
#
# 변수(variable)는 **값 하나에 붙여 둔 이름**이다. 값을 계속 손에 들고 있을 수 없으니 이름을 지어 두는 것이다.

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">1.1 값에 이름을 지정하고 싶을 때</mark>
#
# 이름을 왼쪽에, 값을 오른쪽에 씁니다.

# %%
# 이 셀의 목적 — 값 하나에 이름을 지정하고 꺼내 본다
# 글자는 반드시 따옴표로 감쌉니다.

user = "kim01"        # 따옴표 = 글자라는 표시
print(user)           # 이름을 부르면 그 값이 나온다

# %% [markdown]
# > **🤔 이런 의문이 들 수 있습니다**
# >
# > `=` 는 「같다」 아닌가? 라는 의문이 들 수 있다.
# >
# > 수학의 등호와 다르다. 파이썬의 `=` 는 **「오른쪽 값을 왼쪽 이름에 넣어라」** 는 명령이다.
# > 방향이 있다 — **오른쪽에서 왼쪽으로.** 그래서 `3 = user` 라고 쓰면 오류가 난다.

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">1.2 값을 바꾸고 싶을 때</mark>
#
# 같은 이름에 새 값을 넣으면 앞엣것은 사라집니다.

# %%
# 이 셀의 목적 — 같은 이름에 새 값을 넣으면 어떻게 되는지 본다
# 지금 값 3 을 꺼내 1 을 더하고 같은 이름에 다시 넣습니다.

fail_count = 3                       # 로그인 실패 3회
fail_count = fail_count + 1          # 한 번 더 실패 → 4 가 되어 다시 들어간다
print(fail_count)                    # 4

# %% [markdown]
# > **⚠ 이렇게 쓰면 안 됩니다**
# >
# > ```python
# > user = kim01
# > ```
# > ```
# > NameError: name 'kim01' is not defined
# > ```
# > 따옴표를 빼먹으면 파이썬은 `kim01` 을 **또 다른 변수 이름**으로 읽는다.
# > 그런 이름이 없으니 `NameError` 가 난다. 오늘 제일 많이 볼 오류다.

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">1.3 로그 한 줄을 변수로 나누고 싶을 때</mark>
#
# 보안 로그 한 줄이 변수 셋이 됩니다.

# %%
# 이 셀의 목적 — 보안 로그 한 줄을 변수 여러 개로 쪼개 본다
# 2026-09-22 14:03:11  kim01  10.0.3.21  FAIL

user = "kim01"           # 누가
ip = "10.0.3.21"         # 어디서
result = "FAIL"          # 결과가 어땠나
print(user, ip, result)  # 쉼표로 나누면 한 줄에 나란히 찍힌다

# %% [markdown]
# ### <mark style="display:block; background:#bbdefb; color:#1a1a1a; padding:6px 12px; border-radius:4px">1.정리 📋 한눈에</mark>
#
# | 쓰는 법 | 뜻 |
# |---|---|
# | `user = "kim01"` | user 라는 이름에 글자 kim01 을 넣는다 |
# | `fail_count = 3` | 숫자는 따옴표 없이 |
# | `a = a + 1` | 지금 값을 꺼내 1 더하고 다시 넣는다 |
# | `print(a, b)` | 쉼표로 나누면 한 줄에 나란히 |

# %% [markdown]
# ---
#
# ## <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">2 · 자료형 — 값의 갈래</mark>
#
# 자료형(type)은 **그 값이 숫자인지 글자인지 하는 갈래**다. 보안 로그에서 네 가지를 다 만난다.

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">2.1 값의 갈래를 만들어 보고 싶을 때</mark>
#
# 네 갈래를 하나씩 만들어 찍어 봅니다.

# %%
# 이 셀의 목적 — 네 가지 자료형을 하나씩 만들어 본다
# bool 은 True / False 의 첫 글자가 대문자입니다.

fail_count = 3            # int   — 소수점 없는 수
risk_score = 0.75         # float — 소수점 있는 수
user = "kim01"            # str   — 따옴표로 감싼 글자
is_blocked = False        # bool  — True 아니면 False
print(fail_count, risk_score, user, is_blocked)

# %% [markdown]
# > **🤔 이런 의문이 들 수 있습니다**
# >
# > `"123"` 은 숫자인데 왜 글자지? 라는 의문이 들 수 있다.
# >
# > **따옴표로 둘러싸여 있으면 모두 글자(str)** 다. 안에 무엇이 들었는지는 상관없다.
# > 화면에 `123` 으로 보여도 따옴표가 있으면 계산에 쓸 수 없다.

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">2.2 이 값이 무슨 갈래인지 알고 싶을 때</mark>
#
# 헷갈리면 `type()` 으로 물어보면 됩니다.

# %%
# 이 셀의 목적 — 값의 자료형을 type() 으로 확인한다
# class 뒤에 나오는 것이 자료형 이름입니다.

print(type(3))            # <class 'int'>
print(type("kim01"))      # <class 'str'>
print(type(False))        # <class 'bool'>

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">2.3 따옴표가 있고 없고를 구분하고 싶을 때</mark>
#
# 화면에는 둘 다 7 로 보이지만 다른 값입니다.

# %%
# 이 셀의 목적 — 따옴표가 자료형을 어떻게 가르는지 본다
# 아래 두 값은 화면에 똑같이 7 로 보입니다.

a = 7                     # 숫자 7
b = "7"                   # 글자 7
print(a, type(a))         # 7 <class 'int'>
print(b, type(b))         # 7 <class 'str'>

# %% [markdown]
# ### <mark style="display:block; background:#bbdefb; color:#1a1a1a; padding:6px 12px; border-radius:4px">2.정리 📋 한눈에</mark>
#
# | 자료형 | 예 | 로그에서 쓰이는 곳 |
# |---|---|---|
# | `int` | `3` | 실패 횟수 · 포트 번호 |
# | `float` | `0.75` | 응답 시간 · 위험 점수 |
# | `str` | `"kim01"` | 계정 이름 · IP · 시각 |
# | `bool` | `True` · `False` | 차단 여부 · 성공 여부 |
#
# 파이썬은 자료형을 미리 적지 않는다. **넣는 값을 보고 알아서 정한다.**

# %% [markdown]
# ---
#
# ## <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">3 · f-string — 문장 안에 값을 끼워 넣는다</mark>
#
# f-string 은 **문장 안의 특정 자리에 값을 삽입하는 방법**이다. 오늘 배우는 것 중 여덟 날 내내 제일 많이 쓴다.

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">3.1 문장 안에 값을 넣고 싶을 때</mark>
#
# 따옴표 **앞에 `f`** 를 붙이고, 값이 들어갈 자리에 **중괄호**로 이름을 적습니다.

# %%
# 이 셀의 목적 — f-string 으로 문장 안에 값을 끼워 넣는다
# 따옴표 앞의 f 와 중괄호가 전부입니다.

user = "kim01"
print(f"{user}님이 로그인했습니다")

# %% [markdown]
# > **⚠ 이렇게 쓰면 안 됩니다**
# >
# > ```python
# > user = "kim01"
# > print("{user}님이 로그인했습니다")
# > ```
# > ```
# > {user}님이 로그인했습니다
# > ```
# > `f` 를 빼먹으면 **중괄호가 그대로 찍힌다.** 오류가 안 나서 더 찾기 어렵다.
# > 출력에 `{}` 가 보이면 `f` 를 빠뜨린 것이다.

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">3.2 값을 여러 개 넣고 싶을 때</mark>
#
# 중괄호를 여러 개 두면 됩니다. 중괄호 안에서 계산도 됩니다.

# %%
# 이 셀의 목적 — 값을 여러 개 넣고 중괄호 안에서 계산까지 해 본다
# 숫자를 넣을 때도 글자로 바꿀 필요가 없습니다.

user = "kim01"
fail_count = 5
print(f"{user} 계정이 {fail_count}회 실패했습니다")
print(f"한 번 더 실패하면 차단: {fail_count + 1}회")   # 중괄호 안에서 계산

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">3.3 알림 문장을 만들고 싶을 때</mark>
#
# Day 5 에 이 문장을 슬랙으로 보냅니다.

# %%
# 이 셀의 목적 — 변수 네 개를 한 문장으로 조립한다
# 이 모양이 Day 5 의 알림 메시지가 됩니다.

user = "kim01"
ip = "10.0.3.21"
fail_count = 5
is_blocked = True
alert = f"[경고] {user} — {ip}에서 {fail_count}회 실패 · 차단={is_blocked}"
print(alert)

# %% [markdown]
# ### <mark style="display:block; background:#bbdefb; color:#1a1a1a; padding:6px 12px; border-radius:4px">3.정리 📋 한눈에</mark>
#
# | 쓰는 법 | 결과 |
# |---|---|
# | `f"{user}님"` | `kim01님` |
# | `f"{a}회 · {b}건"` | 값 여러 개 |
# | `f"{n + 1}회"` | 중괄호 안에서 계산 |
# | `"{user}님"` | ⚠ `f` 없음 → `{user}님` 이 그대로 찍힘 |

# %% [markdown]
# ---
#
# ## <mark style="display:block; background:#f8bbd0; color:#1a1a1a; padding:6px 12px; border-radius:4px">✍️ 각자 풉니다 — 문제 9개</mark>
#
# **1-x** 변수 · **2-x** 자료형 · **3-x** f-string
#
# 1. 막히면 **위로 올라가 해당 절의 예시**를 다시 보세요. 왼쪽 **목차** 패널로 바로 갈 수 있습니다.
# 2. 그래도 막히면 문제 아래 **▸ 힌트 보기** 를 누릅니다.
# 3. 다 못 풀어도 괜찮습니다. 남는 시간에 이어서 하세요.

# %% [markdown]
# #### 문제 1-1. 계정 이름을 변수에 담기
#
# 계정 이름 `park03` 을 **적당한 이름의 변수에 담아** 출력하시오. 변수 이름은 직접 정한다.
#
# | | |
# |---|---|
# | **주어지는 값** | 없음 |
# | **나와야 하는 결과** | `park03` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 위 **1.1** 예시를 보세요. `이름 = 값` 순서입니다.
#
# 글자는 따옴표로 감쌉니다. 출력은 `print()`.
#
# </details>

# %% [markdown]
# <div style="background:#bbdefb; color:#10233d; padding:12px 16px; border-radius:8px"><strong>✅ 정답 1-1</strong><br>변수 이름은 직접 정할 수 있습니다. 여기서는 값의 뜻이 드러나는 `user_name`을 사용합니다.</div>

# %%
# 이 셀의 목적 — 문제 1-1. 계정 이름을 변수에 담아 출력한다
# 정답 — 문자열을 변수에 담고 print()로 출력합니다.

user_name = "park03"
print(user_name)

# %% [markdown]
# #### 문제 1-2. 실패 횟수 늘리기
#
# 계정 `lee02` 의 로그인 실패 횟수가 4회다. 한 번 더 실패했다. 지금 실패 횟수를 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | `fail_count = 4` |
# | **나와야 하는 결과** | `5` |

# %% [markdown]
# <div style="background:#bbdefb; color:#10233d; padding:12px 16px; border-radius:8px"><strong>✅ 정답 1-2</strong><br>현재 값을 꺼내 1을 더한 뒤 같은 변수에 다시 넣습니다.</div>

# %%
# 이 셀의 목적 — 문제 1-2. 실패 횟수를 1 늘린다
# 정답 — 기존 값에 1을 더해 다시 저장합니다.

fail_count = 4
fail_count = fail_count + 1
print(fail_count)

# %% [markdown]
# #### 문제 1-3. 로그 한 줄을 변수로 쪼개기
#
# 아래 로그 한 줄을 **변수 네 개로 나눠 담고**, 계정과 결과를 한 줄씩 출력하시오.
# 변수 이름은 직접 정한다.
#
# ```
# 2026-09-22 14:03:11  kim01  10.0.3.21  FAIL
# ```
#
# | | |
# |---|---|
# | **주어지는 값** | 없음 |
# | **나와야 하는 결과** | `kim01`<br>`FAIL` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 네 칸은 시각 · 계정 · IP · 결과입니다.
#
# 위 **1.3** 예시와 같은 모양입니다. 거기는 셋이었고 여기는 넷입니다.
#
# </details>

# %% [markdown]
# <div style="background:#bbdefb; color:#10233d; padding:12px 16px; border-radius:8px"><strong>✅ 정답 1-3</strong><br>로그의 네 칸을 각각 의미가 드러나는 변수에 담습니다.</div>

# %%
# 이 셀의 목적 — 문제 1-3. 로그 한 줄을 변수 네 개로 쪼갠다
# 정답 — 시각·계정·IP·결과를 각각 변수에 담습니다.

log_time = "2026-09-22 14:03:11"
user = "kim01"
ip = "10.0.3.21"
result = "FAIL"
print(user)
print(result)

# %% [markdown]
# #### 문제 2-1. 자료형 맞히기
#
# 아래 세 값의 자료형을 **머리로 먼저 맞혀 본 뒤** `type()` 으로 확인하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | `user` · `port` · `is_blocked` |
# | **나와야 하는 결과** | `<class 'str'>`<br>`<class 'int'>`<br>`<class 'bool'>` |

# %% [markdown]
# <div style="background:#bbdefb; color:#10233d; padding:12px 16px; border-radius:8px"><strong>✅ 정답 2-1</strong><br>`type()`으로 각 값의 자료형을 확인합니다.</div>

# %%
# 이 셀의 목적 — 문제 2-1. 세 값의 자료형을 확인한다
# 정답 — type()을 각 값에 적용합니다.

user = "kim01"
port = 443
is_blocked = True
print(type(user))
print(type(port))
print(type(is_blocked))

# %% [markdown]
# #### 문제 2-2. 위험 점수 만들기
#
# 위험 점수 `0.82` 를 `risk_score` 에 넣고, 값과 자료형을 한 줄씩 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | 없음 |
# | **나와야 하는 결과** | `0.82`<br>`<class 'float'>` |

# %% [markdown]
# <div style="background:#bbdefb; color:#10233d; padding:12px 16px; border-radius:8px"><strong>✅ 정답 2-2</strong><br>소수점이 있는 수는 `float`입니다.</div>

# %%
# 이 셀의 목적 — 문제 2-2. 위험 점수와 자료형을 출력한다
# 정답 — 0.82를 변수에 담고 값과 type()을 출력합니다.

risk_score = 0.82
print(risk_score)
print(type(risk_score))

# %% [markdown]
# #### 문제 2-3. 숫자 7과 글자 7은 같은가
#
# 숫자 `7` 과 글자 `"7"` 이 같은 값인지 `==` 로 비교해 출력하시오.
# 두 값의 자료형도 함께 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | 없음 |
# | **나와야 하는 결과** | `False`<br>`<class 'int'>`<br>`<class 'str'>` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# `==` 는 두 값이 같은지 묻는 기호입니다. 결과는 `True` 아니면 `False`.
#
# 자료형은 `type()` 으로 봅니다.
#
# </details>

# %% [markdown]
# <div style="background:#bbdefb; color:#10233d; padding:12px 16px; border-radius:8px"><strong>✅ 정답 2-3</strong><br>따옴표 없는 `7`은 정수이고, 따옴표로 감싼 `"7"`은 문자열입니다.</div>

# %%
# 이 셀의 목적 — 문제 2-3. 숫자 7과 문자열 7을 비교한다
# 정답 — 값 비교 뒤 두 자료형을 확인합니다.

number = 7
text = "7"
print(number == text)
print(type(number))
print(type(text))

# %% [markdown]
# #### 문제 3-1. 환영 문장 만들기
#
# 계정 `park03` 이 로그인에 성공했다. 「park03님 환영합니다」를 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | `user = "park03"` |
# | **나와야 하는 결과** | `park03님 환영합니다` |

# %% [markdown]
# <div style="background:#bbdefb; color:#10233d; padding:12px 16px; border-radius:8px"><strong>✅ 정답 3-1</strong><br>문자열 앞에 `f`를 붙이고 중괄호 안에 변수 이름을 넣습니다.</div>

# %%
# 이 셀의 목적 — 문제 3-1. 환영 문장을 만든다
# 정답 — f-string에 user 값을 끼워 넣습니다.

user = "park03"
print(f"{user}님 환영합니다")

# %% [markdown]
# #### 문제 3-2. 남은 횟수 계산해 넣기
#
# 실패가 5회면 차단된다. 지금 2회 실패했다. 「앞으로 3번 남았습니다」를 출력하시오. **숫자는 중괄호 안에서 계산**하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | `fail_count = 2` |
# | **나와야 하는 결과** | `앞으로 3번 남았습니다` |

# %% [markdown]
# <div style="background:#bbdefb; color:#10233d; padding:12px 16px; border-radius:8px"><strong>✅ 정답 3-2</strong><br>차단 기준 5에서 현재 실패 횟수를 빼고, 그 계산을 중괄호 안에 씁니다.</div>

# %%
# 이 셀의 목적 — 문제 3-2. 남은 횟수를 계산해 문장에 넣는다
# 정답 — f-string 중괄호 안에서 5 - fail_count를 계산합니다.

fail_count = 2
print(f"앞으로 {5 - fail_count}번 남았습니다")

# %% [markdown]
# #### 문제 3-3. 차단 알림 조립하기
#
# 아래 값들로 다음 문장을 만들어 출력하시오.
#
# `[차단] lee02 · 10.0.7.5 · 실패 5회`
#
# | | |
# |---|---|
# | **주어지는 값** | `user` · `ip` · `fail_count` |
# | **나와야 하는 결과** | `[차단] lee02 · 10.0.7.5 · 실패 5회` |

# %% [markdown]
# <div style="background:#bbdefb; color:#10233d; padding:12px 16px; border-radius:8px"><strong>✅ 정답 3-3</strong><br>세 변수의 값을 f-string 한 줄에 순서대로 넣습니다.</div>

# %%
# 이 셀의 목적 — 문제 3-3. 차단 알림을 조립한다
# 정답 — user·ip·fail_count를 한 문장에 넣습니다.

user = "lee02"
ip = "10.0.7.5"
fail_count = 5
print(f"[차단] {user} · {ip} · 실패 {fail_count}회")

# %% [markdown]
# ---
#
# # <mark style="display:block; background:#ffe0b2; color:#1a1a1a; padding:6px 12px; border-radius:4px">3교시 (16:00–16:50)</mark>
#
# **형변환  ·  리스트  ·  딕셔너리  ·  .get()**
#
# 1. 먼저 **슬라이드로 개념**을 봅니다.
# 2. 여기 노트북으로 와서 **같은 것을 코드로** 한 번 더 봅니다.
# 3. 남은 시간에 **각자 문제**를 풉니다.

# %% [markdown]
# ## <mark style="display:block; background:#c8e6c9; color:#1a1a1a; padding:6px 12px; border-radius:4px">📖 같이 봅니다 — 예시 12개</mark>
#
# 강사와 함께 셀을 하나씩 실행합니다. **고쳐 보셔도 됩니다.**

# %% [markdown]
# ---
#
# ## <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">4 · 형변환 — 값의 갈래를 바꾼다</mark>
#
# 형변환(casting)은 **값의 자료형을 다른 자료형으로 바꾸는 일**이다. 파일에서 읽은 값은 숫자처럼 보여도 전부 글자라서 이 작업이 꼭 필요하다.

# %% [markdown]
# > **🤔 이런 의문이 들 수 있습니다**
# >
# > 화면에 `7` 이라고 나오는데 왜 1 을 못 더하지? 라는 의문이 들 수 있다.
# >
# > 화면에 보이는 모양과 자료형은 다르다. `"7"` 과 `7` 은 **화면에 똑같이 7** 로 보이지만
# > 앞엣것은 글자다. **글자와 숫자는 더할 수 없다.**

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">4.1 글자를 숫자로 바꾸고 싶을 때</mark>
#
# `int()` 로 감싸면 계산할 수 있게 됩니다.

# %%
# 이 셀의 목적 — 글자로 된 숫자를 int() 로 바꿔 계산한다
# int 로 감싼 순간 숫자가 됩니다.

count = int("7")          # 글자 "7" 을 숫자 7 로
print(count + 1)          # 8

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">4.2 숫자를 글자로 바꾸고 싶을 때</mark>
#
# 이어 붙이려면 글자여야 합니다.

# %%
# 이 셀의 목적 — 숫자를 글자로 바꿔 이어 붙인다
# f-string 을 쓰면 이렇게 할 일이 거의 없습니다.

count = 7
print("실패 " + str(count) + "회")     # str() 로 감싸야 이어 붙는다
print(f"실패 {count}회")               # f-string 이면 그냥 된다

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">4.3 파일에서 읽은 값을 다루고 싶을 때</mark>
#
# Day 2 에 실제로 만날 장면입니다.

# %%
# 이 셀의 목적 — 파일에서 읽은 값이 글자라서 생기는 문제를 미리 본다
# split(",") 는 쉼표를 기준으로 줄을 자릅니다. Day 2 에 배웁니다.

row = "kim01,10.0.3.21,5"
parts = row.split(",")               # ['kim01', '10.0.3.21', '5']
fail_count = int(parts[2])           # "5" 를 숫자 5 로 바꾼다
if fail_count >= 5:                  # 숫자여야 크기를 비교할 수 있다
    print("차단 대상")

# %% [markdown]
# ### <mark style="display:block; background:#bbdefb; color:#1a1a1a; padding:6px 12px; border-radius:4px">4.정리 📋 한눈에</mark>
#
# | 함수 | 하는 일 | 예 |
# |---|---|---|
# | `int(x)` | 정수로 | `int("7")` → `7` |
# | `str(x)` | 글자로 | `str(7)` → `"7"` |
# | `float(x)` | 소수로 | `float("0.75")` → `0.75` |
#
# ⚠ **파일·CSV 에서 읽은 값은 전부 `str` 이다.** 비교하거나 더하기 전에 `int()` 로 바꾼다.

# %% [markdown]
# ---
#
# ## <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">5 · 리스트 — 여러 값을 순서대로 담는다</mark>
#
# 리스트(list)는 **값을 순서대로 줄 세워 담은 것**이다. 계정이 서른 개면 변수를 서른 개 만들 수 없으니 한 이름에 담는다.

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">5.1 여러 값을 한 이름에 담고 싶을 때</mark>
#
# 대괄호로 감싸고 쉼표로 나눕니다.

# %%
# 이 셀의 목적 — 리스트를 만들고 번호로 값을 꺼낸다
# 번호는 0 부터 셉니다.

users = ["kim01", "lee02", "park03"]
print(users[0])           # kim01  ← 첫 번째가 0번
print(users[2])           # park03 ← 마지막이 2번
print(len(users))         # 3      ← len = 개수 세기

# %% [markdown]
# > **🤔 이런 의문이 들 수 있습니다**
# >
# > `users[2]` 가 왜 세 번째지? 라는 의문이 들 수 있다.
# >
# > **파이썬은 0 부터 센다.** 그래서 첫 번째가 `[0]`, 두 번째가 `[1]`, 세 번째가 `[2]` 다.
# > 세 개짜리 리스트의 마지막은 `[2]` 이고 `[3]` 은 없다.
# >
# > 처음엔 다 헷갈린다. 며칠 쓰면 몸에 붙는다.

# %% [markdown]
# > **⚠ 이렇게 쓰면 안 됩니다**
# >
# > ```python
# > users = ["kim01", "lee02", "park03"]
# > print(users[3])
# > ```
# > ```
# > IndexError: list index out of range
# > ```
# > 「범위를 벗어났다」는 뜻이다. 개수가 3 이면 마지막 번호는 **2** 다.

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">5.2 값을 나중에 더하고 싶을 때</mark>
#
# 빈 리스트로 시작해 하나씩 붙입니다.

# %%
# 이 셀의 목적 — 빈 리스트에 값을 하나씩 더한다
# 점을 찍고 부르는 것을 메서드라고 합니다.

failed_users = []                    # 빈 대괄호 = 빈 리스트
failed_users.append("kim01")         # 뒤에 하나 붙인다
failed_users.append("lee02")
print(failed_users)                  # ['kim01', 'lee02']

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">5.3 조건에 맞는 것만 모으고 싶을 때</mark>
#
# Day 2 에 반복문과 만나면 이 모양이 됩니다.

# %%
# 이 셀의 목적 — 실패한 계정만 골라 리스트에 모으는 모양을 미리 본다
# 조건문·반복문은 Day 2 에 배웁니다. 지금은 모양만 보세요.

logs = ["kim01 FAIL", "lee02 OK", "park03 FAIL"]
failed_users = []
for line in logs:                    # 한 줄씩 꺼내서
    if "FAIL" in line:               # FAIL 이 들어 있으면
        failed_users.append(line)    # 모은다
print(failed_users)
print(f"실패 {len(failed_users)}건")

# %% [markdown]
# ### <mark style="display:block; background:#bbdefb; color:#1a1a1a; padding:6px 12px; border-radius:4px">5.정리 📋 한눈에</mark>
#
# | 쓰는 법 | 뜻 |
# |---|---|
# | `[a, b, c]` | 리스트를 만든다 |
# | `users[0]` | 첫 번째 (0 부터) |
# | `users[-1]` | 맨 마지막 |
# | `len(users)` | 개수를 센다 |
# | `users.append(x)` | 뒤에 하나 붙인다 |

# %% [markdown]
# ---
#
# ## <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">6 · 딕셔너리 — 키로 값을 꺼낸다</mark>
#
# 딕셔너리(dictionary)는 **이름(키)과 값을 짝지어 담은 것**이다. 리스트는 번호로 꺼내지만 딕셔너리는 이름으로 꺼낸다.

# %% [markdown]
# > **🤔 이런 의문이 들 수 있습니다**
# >
# > 리스트가 있는데 왜 딕셔너리가 또 필요하지? 라는 의문이 들 수 있다.
# >
# > 리스트는 번호로 꺼낸다. 그런데 **3번이 부서였나 등급이었나** 외우기 어렵다.
# > 그래서 번호 대신 `"dept"` 같은 **이름**을 붙인다.

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">6.1 이름으로 값을 꺼내고 싶을 때</mark>
#
# 중괄호로 감싸고, 키와 값을 콜론으로 짝지어 둡니다.

# %%
# 이 셀의 목적 — 딕셔너리를 만들고 키로 값을 꺼낸다
# 키는 이름표, 값은 그 안에 든 내용입니다.

user = {"name": "kim01", "dept": "finance", "level": "read"}
print(user["name"])       # kim01
print(user["dept"])       # finance

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">6.2 값을 바꾸거나 새로 넣고 싶을 때</mark>
#
# 있는 키면 바뀌고, 없는 키면 새로 생깁니다.

# %%
# 이 셀의 목적 — 딕셔너리의 값을 바꾸고 새 키를 추가한다
# 이 모양이 10월 접근통제 과목의 승인 처리 코드가 됩니다.

user = {"name": "kim01", "level": "read"}
user["level"] = "admin"              # 있는 키 → 값이 바뀐다
user["approver"] = "hr_mgr"          # 없는 키 → 새로 생긴다
print(user)

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">6.3 로그 한 줄을 통째로 담고 싶을 때</mark>
#
# ⭐ 오늘의 핵심입니다. 이 모양이 여덟 날 내내 따라다닙니다.

# %%
# 이 셀의 목적 — 보안 로그 한 줄을 딕셔너리 하나로 옮긴다
# 칸 이름이 키가 되고, 칸 내용이 값이 됩니다.

# 2026-09-22 14:03:11  kim01  10.0.3.21  LOGIN  FAIL
log = {
    "time": "2026-09-22 14:03:11",
    "user": "kim01",
    "ip": "10.0.3.21",
    "action": "LOGIN",
    "result": "FAIL",
}
print(log["user"], log["result"])
# Day 2 에는 이런 딕셔너리를 리스트에 담아 수백 줄을 한 번에 센다.

# %% [markdown]
# ### <mark style="display:block; background:#bbdefb; color:#1a1a1a; padding:6px 12px; border-radius:4px">6.정리 📋 한눈에</mark>
#
# | | 리스트 | 딕셔너리 |
# |---|---|---|
# | 만들기 | `[ ]` 대괄호 | `{ }` 중괄호 |
# | 꺼내기 | 번호 `users[0]` | 키 `log["user"]` |
# | 언제 | **같은 것이 여러 개** | **하나에 대한 여러 정보** |
# | 예 | 계정 이름 서른 개 | 로그 한 줄의 시각·계정·IP·결과 |

# %% [markdown]
# ---
#
# ## <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">7 · .get() — 없는 키를 물어도 멈추지 않는다</mark>
#
# 로그에는 **빈 칸이 늘 있다.** 어떤 줄은 IP 가 있고 어떤 줄은 없다.
#
# 없는 키를 대괄호로 꺼내면 `KeyError` 가 나면서 **거기서 프로그램이 멈춘다.** 수백 줄을 돌리다 한 줄에서 멈추면 나머지를 못 본다.
#
# > **⚠ 이렇게 쓰면 안 됩니다**
# >
# > ```python
# > log = {"user": "kim01"}
# > print(log["ip"])
# > ```
# > ```
# > KeyError: 'ip'
# > ```
# > `log` 에 `ip` 라는 키가 없어서 난다. **이 코드는 실행하지 않는다** — 아래 `.get()` 을 쓴다.

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">7.1 키가 있는지 먼저 확인하고 싶을 때</mark>
#
# `in` 을 쓰면 그 키가 있는지 `True` · `False` 로 알려 줍니다.

# %%
# 이 셀의 목적 — 딕셔너리에 그 키가 있는지 in 으로 확인한다
# 있으면 True, 없으면 False 가 나옵니다.

log = {"user": "kim01", "result": "FAIL"}    # ip 가 없다
print("user" in log)      # True
print("ip" in log)        # False

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">7.2 멈추지 않게 하고 싶을 때</mark>
#
# `.get()` 은 없으면 `None` 을 줍니다.

# %%
# 이 셀의 목적 — .get() 이 없는 키를 물어도 멈추지 않는 것을 확인한다
# 맨 아래 검사 완료가 찍히는지 보세요. 아까와 다릅니다.

log = {"user": "kim01", "result": "FAIL"}
print(log.get("ip"))                  # None = 값이 없다는 뜻
print(log.get("ip", "알 수 없음"))      # 두 번째 칸 = 없을 때 대신 쓸 값
print("검사 완료")                      # 이번엔 실행된다

# %% [markdown]
# > **🤔 이런 의문이 들 수 있습니다**
# >
# > 그럼 항상 `.get()` 을 쓰면 되지 않나? 라는 의문이 들 수 있다.
# >
# > 아니다. **없으면 그게 문제인 칸**은 멈추는 게 맞다.
# > 조용히 `None` 으로 넘어가면 나중에 훨씬 찾기 어려운 버그가 된다.
# >
# > 계정 이름은 없으면 안 되니 대괄호, IP 는 없을 수 있으니 `.get()` 이다.

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">7.3 상황에 맞게 갈라 쓰고 싶을 때</mark>
#
# 반드시 있어야 하는 칸과 없을 수도 있는 칸을 갈라 씁니다.

# %%
# 이 셀의 목적 — 대괄호와 .get() 을 상황에 맞게 갈라 쓴다
# user 는 없으면 문제다 → 대괄호. ip 는 없을 수 있다 → .get()

log = {"user": "kim01", "result": "FAIL"}
print(f"계정 {log['user']} · IP {log.get('ip', '-')} · 결과 {log['result']}")

# %% [markdown]
# ### <mark style="display:block; background:#bbdefb; color:#1a1a1a; padding:6px 12px; border-radius:4px">7.정리 📋 한눈에</mark>
#
# | 쓰는 법 | 없을 때 | 언제 쓰나 |
# |---|---|---|
# | `log["user"]` | `KeyError` 로 **멈춘다** | 반드시 있어야 하는 칸 |
# | `log.get("ip")` | `None` | 없을 수도 있는 칸 |
# | `log.get("ip", "-")` | `"-"` | 없을 때 대신 쓸 값이 있을 때 |

# %% [markdown]
# ---
#
# ## <mark style="display:block; background:#f8bbd0; color:#1a1a1a; padding:6px 12px; border-radius:4px">✍️ 각자 풉니다 — 문제 12개</mark>
#
# **4-x** 형변환 · **5-x** 리스트 · **6-x** 딕셔너리 · **7-x** .get()
#
# 1. 막히면 **위로 올라가 해당 절의 예시**를 다시 보세요. 왼쪽 **목차** 패널로 바로 갈 수 있습니다.
# 2. 그래도 막히면 문제 아래 **▸ 힌트 보기** 를 누릅니다.
# 3. 다 못 풀어도 괜찮습니다. 남는 시간에 이어서 하세요.

# %% [markdown]
# #### 문제 4-1. 글자로 들어온 횟수에 1 더하기
#
# 파일에서 읽어 온 실패 횟수가 글자 `"7"` 로 들어왔다.
# 이 값을 숫자로 바꿔 1 을 더한 뒤 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | `count = "7"` |
# | **나와야 하는 결과** | `8` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 글자를 숫자로 바꾸는 함수는 `int()` 입니다.
#
# 위 **4.1** 예시와 같은 모양입니다.
#
# </details>

# %% [markdown]
# <div style="background:#bbdefb; color:#10233d; padding:12px 16px; border-radius:8px"><strong>✅ 정답 4-1</strong><br>`int()`로 문자열을 정수로 바꾼 뒤 1을 더합니다.</div>

# %%
# 이 셀의 목적 — 문제 4-1. 문자열 횟수에 1을 더한다
# 정답 — int(count)로 바꾼 뒤 계산합니다.

count = "7"
print(int(count) + 1)

# %% [markdown]
# #### 문제 4-2. 응답 시간 더하기
#
# 글자로 들어온 응답 시간 두 개를 더해 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | `a = "0.4"` · `b = "0.35"` |
# | **나와야 하는 결과** | `0.75` |

# %% [markdown]
# <div style="background:#bbdefb; color:#10233d; padding:12px 16px; border-radius:8px"><strong>✅ 정답 4-2</strong><br>소수 문자열은 `float()`로 바꿔야 소수 덧셈을 할 수 있습니다.</div>

# %%
# 이 셀의 목적 — 문제 4-2. 문자열 응답 시간 두 개를 더한다
# 정답 — 두 값을 각각 float로 바꿔 더합니다.

a = "0.4"
b = "0.35"
print(float(a) + float(b))

# %% [markdown]
# #### 문제 4-3. 차단 판정하기
#
# 글자로 들어온 실패 횟수가 5 이상이면 「차단 대상」, 아니면 「정상」을 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | `fail_count = "6"` |
# | **나와야 하는 결과** | `차단 대상` |

# %% [markdown]
# <div style="background:#bbdefb; color:#10233d; padding:12px 16px; border-radius:8px"><strong>✅ 정답 4-3</strong><br>먼저 `int()`로 바꾸고 5 이상인지 비교합니다.</div>

# %%
# 이 셀의 목적 — 문제 4-3. 실패 횟수로 차단 여부를 판단한다
# 정답 — 문자열을 정수로 바꾼 뒤 if로 갈라 출력합니다.

fail_count = "6"
if int(fail_count) >= 5:
    print("차단 대상")
else:
    print("정상")

# %% [markdown]
# #### 문제 5-1. 첫 번째와 마지막
#
# 아래 리스트에서 첫 번째 계정, 마지막 계정, 전체 개수를 한 줄씩 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | `users = ["kim01", "lee02", "park03", "choi04"]` |
# | **나와야 하는 결과** | `kim01`<br>`choi04`<br>`4` |

# %% [markdown]
# <div style="background:#bbdefb; color:#10233d; padding:12px 16px; border-radius:8px"><strong>✅ 정답 5-1</strong><br>첫 번째는 `[0]`, 마지막은 `[-1]`, 전체 개수는 `len()`으로 구합니다.</div>

# %%
# 이 셀의 목적 — 문제 5-1. 첫 번째·마지막·전체 개수를 출력한다
# 정답 — 인덱스와 len()을 사용합니다.

users = ["kim01", "lee02", "park03", "choi04"]
print(users[0])
print(users[-1])
print(len(users))

# %% [markdown]
# #### 문제 5-2. 차단 목록 만들기
#
# 빈 리스트 `blocked` 에 `kim01` 과 `lee02` 를 넣고 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | `blocked = []` |
# | **나와야 하는 결과** | `['kim01', 'lee02']` |

# %% [markdown]
# <div style="background:#bbdefb; color:#10233d; padding:12px 16px; border-radius:8px"><strong>✅ 정답 5-2</strong><br>빈 리스트에 `append()`를 두 번 사용합니다.</div>

# %%
# 이 셀의 목적 — 문제 5-2. 차단 목록을 만든다
# 정답 — append()로 두 계정을 차례로 추가합니다.

blocked = []
blocked.append("kim01")
blocked.append("lee02")
print(blocked)

# %% [markdown]
# #### 문제 5-3. IP 목록의 두 번째
#
# 아래 IP 목록에서 **두 번째** IP 를 출력하시오. 번호가 0 부터라는 것에 주의하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | `ips = ["10.0.1.5", "10.0.3.21", "10.0.7.5"]` |
# | **나와야 하는 결과** | `10.0.3.21` |

# %% [markdown]
# <div style="background:#bbdefb; color:#10233d; padding:12px 16px; border-radius:8px"><strong>✅ 정답 5-3</strong><br>번호는 0부터 시작하므로 두 번째 항목의 번호는 1입니다.</div>

# %%
# 이 셀의 목적 — 문제 5-3. 두 번째 IP를 출력한다
# 정답 — 인덱스 1을 사용합니다.

ips = ["10.0.1.5", "10.0.3.21", "10.0.7.5"]
print(ips[1])

# %% [markdown]
# #### 문제 6-1. 부서 꺼내기
#
# 아래 딕셔너리에서 **부서**를 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | `user = {"name": "lee02", "dept": "sales", "level": "read"}` |
# | **나와야 하는 결과** | `sales` |

# %% [markdown]
# <div style="background:#bbdefb; color:#10233d; padding:12px 16px; border-radius:8px"><strong>✅ 정답 6-1</strong><br>딕셔너리의 부서는 `dept` 키로 꺼냅니다.</div>

# %%
# 이 셀의 목적 — 문제 6-1. 딕셔너리에서 부서를 꺼낸다
# 정답 — 대괄호 안에 dept 키를 씁니다.

user = {"name": "lee02", "dept": "sales", "level": "read"}
print(user["dept"])

# %% [markdown]
# #### 문제 6-2. 승인 처리하기
#
# 요청의 `status` 를 `approved` 로 바꾸고, `approver` 에 `hr_manager` 를 새로 넣은 뒤 전체를 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | `request = {"id": "req-1002", "user": "lee02", "status": "review"}` |
# | **나와야 하는 결과** | `{'id': 'req-1002', 'user': 'lee02', 'status': 'approved', 'approver': 'hr_manager'}` |

# %% [markdown]
# <div style="background:#bbdefb; color:#10233d; padding:12px 16px; border-radius:8px"><strong>✅ 정답 6-2</strong><br>있는 `status` 키는 수정하고, 없는 `approver` 키는 새로 추가합니다.</div>

# %%
# 이 셀의 목적 — 문제 6-2. 요청을 승인 처리한다
# 정답 — status를 바꾸고 approver를 추가합니다.

request = {"id": "req-1002", "user": "lee02", "status": "review"}
request["status"] = "approved"
request["approver"] = "hr_manager"
print(request)

# %% [markdown]
# #### 문제 6-3. ⭐ 로그 한 줄을 딕셔너리로
#
# 아래 로그 한 줄을 **키 다섯 개를 가진 딕셔너리로 옮기고**, 계정과 결과를 한 줄씩 출력하시오.
# **키 이름도 직접 정한다.**
#
# ```
# 2026-09-22 09:41:02  choi04  10.0.9.8  LOGIN  OK
# ```
#
# | | |
# |---|---|
# | **주어지는 값** | 없음 |
# | **나와야 하는 결과** | `choi04`<br>`OK` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 위 **6.3** 예시와 같은 모양입니다.
#
# 다섯 칸은 시각 · 계정 · IP · 동작 · 결과입니다.
#
# 키는 영문 소문자로 짓는 것이 관례입니다.
#
# </details>

# %% [markdown]
# <div style="background:#bbdefb; color:#10233d; padding:12px 16px; border-radius:8px"><strong>✅ 정답 6-3</strong><br>로그의 다섯 칸을 키 다섯 개로 옮긴 뒤 필요한 값을 키로 꺼냅니다.</div>

# %%
# 이 셀의 목적 — 문제 6-3. 로그 한 줄을 딕셔너리로 옮긴다
# 정답 — time·user·ip·action·result 키를 사용합니다.

log = {
    "time": "2026-09-22 09:41:02",
    "user": "choi04",
    "ip": "10.0.9.8",
    "action": "LOGIN",
    "result": "OK",
}
print(log["user"])
print(log["result"])

# %% [markdown]
# #### 문제 7-1. 없는 키를 안전하게 꺼내기
#
# 아래 로그에는 `ip` 가 없다. `.get()` 으로 `ip` 를 꺼내되, 없으면 `알 수 없음` 이 나오게 하시오.
# 그 아래 「검사 완료」도 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | `log = {"user": "kim01", "result": "FAIL"}` |
# | **나와야 하는 결과** | `알 수 없음`<br>`검사 완료` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# `.get("키", "없을 때 쓸 값")` — 괄호 안 두 번째 칸이 기본값입니다.
#
# 위 **7.2** 예시를 보세요.
#
# </details>

# %% [markdown]
# <div style="background:#bbdefb; color:#10233d; padding:12px 16px; border-radius:8px"><strong>✅ 정답 7-1</strong><br>`.get()`의 두 번째 값은 키가 없을 때 대신 반환할 기본값입니다.</div>

# %%
# 이 셀의 목적 — 문제 7-1. 없는 IP를 안전하게 꺼낸다
# 정답 — .get("ip", "알 수 없음")을 사용합니다.

log = {"user": "kim01", "result": "FAIL"}
print(log.get("ip", "알 수 없음"))
print("검사 완료")

# %% [markdown]
# #### 문제 7-2. 승인자 배정 여부
#
# `approver` 가 있으면 그 이름을, 없으면 `미배정` 을 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | `request = {"id": "req-1001", "user": "kim01", "status": "review"}` |
# | **나와야 하는 결과** | `미배정` |

# %% [markdown]
# <div style="background:#bbdefb; color:#10233d; padding:12px 16px; border-radius:8px"><strong>✅ 정답 7-2</strong><br>`approver`가 없을 때 반환할 기본값으로 `미배정`을 지정합니다.</div>

# %%
# 이 셀의 목적 — 문제 7-2. 승인자 배정 여부를 출력한다
# 정답 — .get()의 두 번째 인수에 미배정을 넣습니다.

request = {"id": "req-1001", "user": "kim01", "status": "review"}
print(request.get("approver", "미배정"))

# %% [markdown]
# #### 문제 7-3. 알림 한 줄 만들기
#
# 아래 로그로 다음 문장을 만들어 출력하시오. `ip` 가 없으면 `-` 로 채우시오.
#
# `[FAIL] kim01 · IP - · 09:41`
#
# | | |
# |---|---|
# | **주어지는 값** | `log = {"user": "kim01", "result": "FAIL", "time": "09:41"}` |
# | **나와야 하는 결과** | `[FAIL] kim01 · IP - · 09:41` |

# %% [markdown]
# <div style="background:#bbdefb; color:#10233d; padding:12px 16px; border-radius:8px"><strong>✅ 정답 7-3</strong><br>없을 수 있는 IP만 `.get()`으로 꺼내고, 나머지는 반드시 있어야 하므로 대괄호를 씁니다.</div>

# %%
# 이 셀의 목적 — 문제 7-3. 빠진 IP를 채워 알림을 만든다
# 정답 — ip만 .get()으로 안전하게 꺼냅니다.

log = {"user": "kim01", "result": "FAIL", "time": "09:41"}
print(f"[{log['result']}] {log['user']} · IP {log.get('ip', '-')} · {log['time']}")

# %% [markdown]
# ---
#
# ## <mark style="display:block; background:#c8e6c9; color:#1a1a1a; padding:6px 12px; border-radius:4px">오늘 여기까지</mark>
#
# 다 못 푸셨어도 괜찮습니다. 남는 시간에 이어서 하세요.
#
# ### ### <mark style="display:block; background:#c8e6c9; color:#1a1a1a; padding:6px 12px; border-radius:4px">오늘 손에 남은 것</mark>
#
# 1. **Python 이 도는 PC** — 터미널에서 `python --version` 이 나옵니다
# 2. **변수 · 자료형 · f-string · 형변환** — 값에 이름을 지정하고 문장을 조립합니다
# 3. **리스트 · 딕셔너리 · `.get()`** — 로그 한 줄을 담습니다
#
# ### ### <mark style="display:block; background:#c8e6c9; color:#1a1a1a; padding:6px 12px; border-radius:4px">알아 둘 오류 네 가지</mark>
#
# | 오류 | 뜻 | 고치는 법 |
# |---|---|---|
# | `NameError` | 없는 이름을 불렀다 | 따옴표를 빠뜨렸는지 본다 |
# | `TypeError` | 자료형이 안 맞는다 | `int()` · `str()` 로 바꾼다 |
# | `IndexError` | 리스트 범위를 벗어났다 | 번호가 0 부터인지 본다 |
# | `KeyError` | 없는 키를 불렀다 | `.get()` 을 쓴다 |
#
# ### ### <mark style="display:block; background:#c8e6c9; color:#1a1a1a; padding:6px 12px; border-radius:4px">내일 할 것</mark>
#
# 내일은 이 딕셔너리를 **리스트에 담아** 조건문과 반복문으로 셉니다.
# 첫 스크립트 `day01_basic.py` 가 나옵니다.
