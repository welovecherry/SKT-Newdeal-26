# %% [markdown]
# # <mark style="display:block; background:#d1c4e9; color:#1a1a1a; padding:6px 12px; border-radius:4px">9/23(수) 오후 · 함수 · 파일 — 연습장</mark>
#
# 오전에 만든 **실패 계정 찾기 코드**를 함수로 묶고, 코드 안에 적던 로그를 **파일에서 읽어 옵니다.**
#
# 오늘은 최종 `.py` 파일을 제출하지 않습니다. **코랩 안에서 실행 결과가 맞는지 확인**하는 데 집중합니다.

# %% [markdown]
# ## <mark style="display:block; background:#c8e6c9; color:#1a1a1a; padding:6px 12px; border-radius:4px">시작하기 · 이 노트북을 여는 법</mark>
#
# ### 0.1 맨 먼저 · 내 사본 만들기
#
# 1. 위 메뉴에서 **파일 › 드라이브에 사본 저장**을 누릅니다.
# 2. 제목이 **「사본: …」**으로 바뀌면 된 것입니다.
# 3. 사본을 만들지 않으면 내가 쓴 코드가 저장되지 않습니다.
#
# ### 0.2 셀 실행하기
#
# 셀을 누르고 **Shift + Enter**를 칩니다. 왼쪽 **▶**를 눌러도 같습니다.
#
# ### 0.3 오늘 오후의 순서
#
# 1. 함수 — 여러 줄의 일에 이름을 붙인다
# 2. 파일 — 코드 밖의 글자를 읽고 쓴다
#
# ### 0.4 막혔을 때
#
# 1. 문제 아래 **▸ 힌트 보기**를 눌러 순서대로 따라 합니다.
# 2. 그래도 막히면 노트북 **맨 아래 「정답」**으로 갑니다. 왼쪽 목차(☰)에서 바로 갈 수 있습니다.
# 3. 정답 셀은 제목만 보입니다. **「코드 표시」를 누르면 코드가 열립니다.** 먼저 스스로 해 본 뒤 엽니다.

# %%
print("9/23 오후 준비 끝")  # 노트북 실행 확인

# %% [markdown]
# ---
#
# # <mark style="display:block; background:#ffe0b2; color:#1a1a1a; padding:6px 12px; border-radius:4px">5교시 (14:30–15:20) · 함수</mark>

# %% [markdown]
# ---
#
# ## <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">5 · 함수 — 여러 줄의 일에 이름을 붙인다</mark>
#
# 오전에 만든 코드를 이름 하나로 다시 부를 수 있게 만듭니다.

# %% [markdown]
# <div style="background:#e8f5e9; color:#17351f; padding:12px 16px; border-radius:8px"><strong>🔎 코드를 읽는 법</strong><br>`def` 줄은 ‘이런 일을 이 이름으로 부르겠다’고 적어 두는 것입니다. 적기만 하면 아무 일도 일어나지 않습니다. 이름 뒤에 괄호를 붙여 **불러야** 실행됩니다.</div>

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">5.1 여러 줄의 일에 이름을 붙이고 싶을 때</mark>
#
# `def 이름():` 아래 들여쓴 줄이 함수가 하는 일입니다. 부를 때마다 한 번씩 실행됩니다.

# %%
def say_hello():  # say_hello라는 이름으로 적어 둔다 (아직 실행 안 됨)
    print("안녕하세요")

say_hello()  # 부르는 순간 실행된다
say_hello()  # 또 부르면 또 실행된다

# %% [markdown]
# > **⚠ 이렇게 쓰면 안 됩니다** — 이 코드는 실행하지 않습니다.
# >
# > ```python
# > say_hello   # 괄호가 없다
# > ```
# >
# > 에러는 나지 않지만 함수가 **실행되지 않습니다.** 코랩에서는 `<function say_hello at 0x…>` 같은 글자만 나옵니다. 부를 때는 반드시 괄호까지 씁니다.

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 5-1 · 점검 시작 함수</font></h3></td></tr></table>
#
# 「점검을 시작합니다」를 출력하는 `start_check()`를 만들고 **두 번** 부르시오.
#
# | | |
# |---|---|
# | **주어지는 값** | 없음 |
# | **🎯 나와야 하는 결과** | `점검을 시작합니다`<br>`점검을 시작합니다` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. 첫 줄은 `def start_check():`입니다. 이름 뒤 괄호와 줄 끝 콜론(`:`)을 빠뜨리지 않습니다.
# 2. 그 아래에 **네 칸 들여써서** `print("점검을 시작합니다")`를 씁니다.
# 3. 들여쓰기를 끝내고(맨 왼쪽에서) `start_check()`를 두 줄 씁니다.
# 4. 한 줄만 나오면 부르는 줄이 하나뿐인지, 부르는 줄이 들여써져 함수 안에 들어갔는지 봅니다.
#
# 그래도 막히면 맨 아래 **정답 5-1** 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">5.2 함수에 값을 넘겨주고 싶을 때</mark>
#
# 괄호 안에 적은 이름(매개변수)에 부를 때 넘긴 값이 담깁니다. 값이 둘이면 쉼표로 나눕니다.

# %%
def show_alert(user):  # 넘겨받은 값을 user라고 부른다
    print(f"{user} 계정을 확인하세요")

show_alert("kim01")  # user에 "kim01"이 담겨 실행된다
show_alert("park03")

# %%
def show_count(user, count):  # 값 두 개를 차례로 받는다
    print(f"{user}: {count}회")

show_count("kim01", 3)  # 첫째 값은 user, 둘째 값은 count에 담긴다

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 5-2 · 계정을 받는 함수</font></h3></td></tr></table>
#
# 계정 이름을 받아 「kim01 확인」처럼 출력하는 `show_user(user)`를 만들고, `"kim01"`을 넘겨 부르시오.
#
# | | |
# |---|---|
# | **주어지는 값** | `"kim01"` |
# | **🎯 나와야 하는 결과** | `kim01 확인` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. 첫 줄은 `def show_user(user):`입니다. 괄호 안의 `user`가 넘겨받은 값을 담을 이름입니다.
# 2. 함수 안에서 f-string으로 `f"{user} 확인"`을 출력합니다.
# 3. 함수 밖에서 `show_user("kim01")`로 부릅니다.
# 4. 결과에 `user`라는 글자가 그대로 나오면 f-string 앞의 `f`를 빠뜨린 것입니다.
#
# 그래도 막히면 맨 아래 **정답 5-2** 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">5.3 결과를 돌려받고 싶을 때</mark>
#
# `return`은 함수가 만든 값을 부른 곳으로 돌려줍니다. 돌려받은 값은 변수에 담아 다음 일에 씁니다.

# %%
def add(a, b):
    return a + b  # 결과를 부른 곳으로 돌려준다

result = add(3, 5)  # 돌려받은 8이 result에 담긴다
print(result)

# %% [markdown]
# > **🤔 이런 의문이 들 수 있습니다 — `print`와 `return`은 뭐가 다른가요?**
# >
# > 1. `print`는 화면에 **보여 주기만** 합니다. 그 값을 변수에 담을 수 없습니다.
# > 2. `return`은 값을 **돌려줍니다.** 받은 쪽에서 담아 두고 계산을 이어 갈 수 있습니다.
# > 3. 그래서 결과를 다음 일에 쓸 함수는 `return`으로 끝냅니다.

# %%
logs = [
    {"result": "FAIL"}, {"result": "OK"},
    {"result": "FAIL"}, {"result": "FAIL"},
]

def count_failed(logs):  # 오전 2-4의 코드를 함수로 묶었다
    fail_count = 0
    for log in logs:
        if log["result"] == "FAIL":
            fail_count = fail_count + 1
    return fail_count  # 반복이 끝난 뒤 돌려준다

total = count_failed(logs)
print(f"실패 {total}건")

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 5-3 · 실패인지 돌려주기</font></h3></td></tr></table>
#
# 결과 글자를 받아 `FAIL`이면 `True`, 아니면 `False`를 **돌려주는** `is_failed(result)`를 만들고, 돌려받은 값을 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | `"FAIL"` |
# | **🎯 나와야 하는 결과** | `True` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. 첫 줄은 `def is_failed(result):`입니다.
# 2. 비교식 `result == "FAIL"`은 그 자체가 `True` 또는 `False`입니다. 그래서 `return result == "FAIL"` 한 줄이면 됩니다.
# 3. 함수 밖에서 `print(is_failed("FAIL"))`로 돌려받은 값을 출력합니다.
# 4. `None`이 나오면 `return` 대신 `print`를 썼거나 `return`을 빠뜨린 것입니다.
#
# 그래도 막히면 맨 아래 **정답 5-3** 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 5-4 · 실패 계정 모아 돌려주기</font></h3></td></tr></table>
#
# 로그 목록을 받아 실패한 계정만 모은 목록을 **돌려주는** `collect_failed_users(logs)`를 만들고, 돌려받은 목록을 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | 로그 딕셔너리 3건 |
# | **🎯 나와야 하는 결과** | `['kim01', 'park03']` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. 오전 문제 2-3의 코드를 함수 안으로 옮긴다고 생각합니다.
# 2. 함수 **안에서** `failed_users = []`로 빈 목록을 만들고, `for` → `if` → `append` 순서로 채웁니다.
# 3. 반복이 끝난 뒤(`for`와 같은 칸) `return failed_users`로 돌려줍니다. `return`이 `for` 안에 들어가면 첫 번째에서 멈춥니다.
# 4. 함수 밖에서 `print(collect_failed_users(logs))`로 확인합니다.
#
# 그래도 막히면 맨 아래 **정답 5-4** 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %%
logs = [
    {"user": "kim01", "result": "FAIL"},
    {"user": "lee02", "result": "OK"},
    {"user": "park03", "result": "FAIL"},
]

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">5.4 값을 안 넘기면 정해 둔 값을 쓰고 싶을 때</mark>
#
# 매개변수에 `=값`을 붙이면 기본값이 됩니다. 넘기지 않으면 기본값을, 넘기면 넘긴 값을 씁니다.

# %%
def needs_review(count, threshold=2):  # threshold를 안 넘기면 2
    return count >= threshold

print(needs_review(3))     # 기본값 2와 비교 → True
print(needs_review(3, 5))  # 넘긴 값 5와 비교 → False

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 5-5 · 위험도 기본값</font></h3></td></tr></table>
#
# 계정과 위험도를 받아 「kim01: 주의」처럼 출력하는 `show_level(user, level="주의")`를 만드시오. 위험도를 넘기지 않으면 「주의」입니다.
#
# | | |
# |---|---|
# | **주어지는 값** | `show_level("kim01")` · `show_level("park03", "높음")` |
# | **🎯 나와야 하는 결과** | `kim01: 주의`<br>`park03: 높음` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. 첫 줄은 `def show_level(user, level="주의"):`입니다. 기본값이 있는 매개변수는 **뒤쪽**에 둡니다.
# 2. 함수 안에서 `f"{user}: {level}"`을 출력합니다.
# 3. 함수 밖에서 위에 주어진 두 줄로 부릅니다. 첫 줄은 기본값, 둘째 줄은 넘긴 값이 쓰입니다.
#
# 그래도 막히면 맨 아래 **정답 5-5** 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">5.5 오전 코드를 통째로 함수에 넣고 싶을 때</mark>
#
# 오전 3교시의 Counter와 기준값 코드를 함수로 묶으면, 어떤 목록이든 한 줄로 확인할 계정을 찾습니다.

# %%
from collections import Counter  # 항목별 횟수를 세는 도구

def find_suspects(failed_users, threshold=2):
    counts = Counter(failed_users)
    suspects = []
    for user, count in counts.items():
        if count >= threshold:
            suspects.append(user)
    return suspects

print(find_suspects(["kim01", "kim01", "lee02", "kim01"]))
print(find_suspects(["kim01", "kim01", "lee02", "kim01"], 5))  # 기준을 바꿔 다시 확인

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 5-6 · 확인할 계정 찾는 함수</font></h3></td></tr></table>
#
# 실패 계정 목록을 받아 **기준 이상인 계정과 횟수**를 「확인 필요: kim01 · 3회」 모양으로 출력하는 `report_suspects(failed_users, threshold=2)`를 만들고 부르시오.
#
# | | |
# |---|---|
# | **주어지는 값** | `["kim01", "kim01", "kim01", "park03"]` |
# | **🎯 나와야 하는 결과** | `확인 필요: kim01 · 3회` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. 5.5 예시와 같은 모양입니다. 첫 줄은 `def report_suspects(failed_users, threshold=2):`입니다.
# 2. 함수 안에서 `Counter(failed_users)`로 센 뒤 `.items()`로 계정과 횟수를 꺼냅니다.
# 3. `if count >= threshold:`일 때 목록에 담는 대신 **바로 출력**합니다. 이번에는 돌려줄 값이 없어서 `return`이 필요 없습니다.
# 4. 함수 밖에서 주어진 목록을 넘겨 부릅니다.
#
# 그래도 막히면 맨 아래 **정답 5-6** 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %%
from collections import Counter
failed_users = ["kim01", "kim01", "kim01", "park03"]

# %% [markdown]
# ### <mark style="display:block; background:#bbdefb; color:#1a1a1a; padding:6px 12px; border-radius:4px">5.정리 📋 한눈에</mark>
#
# | 쓰는 법 | 뜻 |
# |---|---|
# | `def 이름():` | 여러 줄의 일에 이름을 붙인다 (아직 실행 안 됨) |
# | `이름()` | 함수를 부른다 — 괄호까지 써야 실행된다 |
# | `def 이름(a, b):` | 부를 때 넘긴 값을 a, b에 담는다 (매개변수) |
# | `return 값` | 값을 부른 곳으로 돌려준다 |
# | `threshold=2` | 안 넘기면 쓸 기본값 |

# %% [markdown]
# ---
#
# # <mark style="display:block; background:#ffe0b2; color:#1a1a1a; padding:6px 12px; border-radius:4px">6교시 (15:30–16:20) · 파일 읽기 · 쓰기</mark>

# %% [markdown]
# ---
#
# ## <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">6 · 파일 — 코드 밖의 글자를 읽고 쓴다</mark>
#
# 지금까지는 로그를 코드에 직접 적었습니다. 실제 로그는 파일로 옵니다.

# %% [markdown]
# <div style="background:#e8f5e9; color:#17351f; padding:12px 16px; border-radius:8px"><strong>🔎 코드를 읽는 법</strong><br>파일 코드는 ‘연다 → 읽거나 쓴다 → 닫는다’ 순서입니다. `with` 아래 들여쓴 줄이 끝나면 파이썬이 알아서 닫아 줍니다. 만든 파일은 코랩 왼쪽 📁 파일 탭에서 볼 수 있습니다.</div>

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">6.1 파일에 글자를 쓰고 싶을 때</mark>
#
# `"w"`는 쓰기(write) 모드입니다. 파일이 없으면 새로 만들고, 있으면 **지우고 새로 씁니다.**

# %%
with open("memo.txt", "w", encoding="utf-8") as f:  # 쓰기 모드로 열고 f라고 부른다
    f.write("첫 번째 줄\n")  # \n은 줄바꿈 문자
    f.write("두 번째 줄\n")

print("memo.txt를 만들었습니다")

# %% [markdown]
# 1. `encoding="utf-8"`은 한글이 깨지지 않게 하는 설정입니다. 파일을 열 때마다 붙입니다.
# 2. `write()`는 줄을 알아서 바꾸지 않습니다. 줄 끝마다 `\n`을 붙여야 다음 줄로 넘어갑니다.

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 6-1 · 점검 파일 쓰기</font></h3></td></tr></table>
#
# `check.txt`에 「점검 시작」「점검 끝」 두 줄을 쓰시오.
#
# | | |
# |---|---|
# | **주어지는 값** | 없음 |
# | **🎯 나와야 하는 결과** | 왼쪽 📁 파일 탭에 `check.txt`가 생긴다 (내용은 문제 6-2에서 확인) |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. `with open("check.txt", "w", encoding="utf-8") as f:`로 엽니다.
# 2. 그 아래 네 칸 들여써서 `f.write("점검 시작\n")`, `f.write("점검 끝\n")` 두 줄을 씁니다.
# 3. 📁 탭에 파일이 안 보이면 탭 위의 새로고침 아이콘을 누릅니다.
#
# 그래도 막히면 맨 아래 **정답 6-1** 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">6.2 파일 전체를 읽고 싶을 때</mark>
#
# 모드를 적지 않으면 읽기 모드입니다. `read()`는 파일 전체를 글자 한 덩어리로 가져옵니다.

# %%
with open("memo.txt", encoding="utf-8") as f:  # 모드를 안 쓰면 읽기
    print(f.read())

# %% [markdown]
# > **⚠ 이렇게 쓰면 안 됩니다** — 이 코드는 실행하지 않습니다.
# >
# > ```python
# > with open("없는파일.txt", encoding="utf-8") as f:
# >     print(f.read())
# > ```
# >
# > ```
# > FileNotFoundError: [Errno 2] No such file or directory: '없는파일.txt'
# > ```
# >
# > 「그런 파일이 없다」는 뜻입니다. 파일 이름의 글자·확장자와, 그 파일을 만드는 셀을 먼저 실행했는지 확인합니다.

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 6-2 · 점검 파일 읽기</font></h3></td></tr></table>
#
# 문제 6-1에서 만든 `check.txt`를 읽어 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | 문제 6-1의 `check.txt` |
# | **🎯 나와야 하는 결과** | `점검 시작`<br>`점검 끝` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. 6.2 예시에서 파일 이름만 바꿉니다.
# 2. 읽을 때는 `"w"`를 쓰지 않습니다. `"w"`로 열면 내용이 **지워집니다.**
# 3. `FileNotFoundError`가 나면 문제 6-1 셀을 먼저 실행합니다.
#
# 그래도 막히면 맨 아래 **정답 6-2** 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">6.3 한 줄씩 읽고 싶을 때</mark>
#
# 로그는 한 줄이 한 건입니다. 먼저 아래 셀로 오늘 쓸 로그 파일 `sample_logs.csv`를 만듭니다.

# %%
# 오늘 사용할 로그 파일을 만듭니다. 이 셀을 먼저 실행하세요.
lines = [
    "09:01,kim01,10.0.3.21,LOGIN,FAIL",
    "09:03,lee02,10.0.7.5,LOGIN,OK",
    "09:05,kim01,10.0.3.21,LOGIN,FAIL",
    "09:08,park03,10.0.9.8,FILE_OPEN,OK",
    "09:11,kim01,10.0.3.21,LOGIN,FAIL",
    "09:14,park03,10.0.9.8,LOGIN,FAIL",
]

with open("sample_logs.csv", "w", encoding="utf-8") as f:
    for line in lines:
        f.write(f"{line}\n")

print("sample_logs.csv를 만들었습니다")

# %% [markdown]
# `for line in f`는 파일에서 **한 줄씩** 꺼냅니다. 오전의 `for log in logs`와 같은 모양입니다.

# %%
with open("sample_logs.csv", encoding="utf-8") as f:
    for line in f:  # 한 줄씩 꺼내 line에 담는다
        print(line)

# %% [markdown]
# > **🤔 이런 의문이 들 수 있습니다 — 줄 사이에 왜 빈 줄이 생기나요?**
# >
# > 1. 파일의 각 줄 끝에는 줄바꿈 문자 `\n`이 붙어 있습니다.
# > 2. `print`도 줄을 한 번 바꿉니다. 그래서 두 번 바뀌어 빈 줄이 생깁니다.
# > 3. `strip()`은 글자 양쪽의 빈칸과 줄바꿈을 지웁니다.

# %%
with open("sample_logs.csv", encoding="utf-8") as f:
    for line in f:
        print(line.strip())  # 줄 끝의 \n을 지우고 출력

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 6-3 · 로그 줄 수 세기</font></h3></td></tr></table>
#
# `sample_logs.csv`를 한 줄씩 읽어 **빈 줄 없이** 출력하고, 마지막에 전체 줄 수를 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | `sample_logs.csv` (6.3의 준비 셀) |
# | **🎯 나와야 하는 결과** | 로그 6줄<br>`총 6줄` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. 반복문 **위에서** `count = 0`을 만듭니다. 오전 문제 2-4와 같은 모양입니다.
# 2. `for line in f:` 안에서 `print(line.strip())`로 출력하고, `count = count + 1`로 하나씩 셉니다.
# 3. `총 6줄`은 반복이 **다 끝난 뒤** 한 번만 출력합니다. 들여쓰기를 없애 `with`와 같은 칸에 둡니다.
# 4. `FileNotFoundError`가 나면 6.3의 준비 셀을 먼저 실행합니다.
#
# 그래도 막히면 맨 아래 **정답 6-3** 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">6.4 특정 글자가 든 줄만 고르고 싶을 때</mark>
#
# `"FAIL" in line`은 `line` 안에 `FAIL`이라는 글자가 있으면 `True`입니다.

# %%
print("FAIL" in "09:01,kim01,10.0.3.21,LOGIN,FAIL")  # True
print("FAIL" in "09:03,lee02,10.0.7.5,LOGIN,OK")     # False

# %%
with open("sample_logs.csv", encoding="utf-8") as f:
    for line in f:
        if "park03" in line:  # park03이 들어 있는 줄만
            print(line.strip())

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 6-4 · 실패한 줄만 출력하기</font></h3></td></tr></table>
#
# `sample_logs.csv`에서 `FAIL`이 들어 있는 줄만 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | `sample_logs.csv` |
# | **🎯 나와야 하는 결과** | `09:01,kim01,10.0.3.21,LOGIN,FAIL`<br>`09:05,kim01,…`<br>`09:11,kim01,…`<br>`09:14,park03,…` — 4줄 |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. 6.4의 두 번째 예시에서 찾는 글자만 바꿉니다.
# 2. `for` 안에 `if "FAIL" in line:`을 넣습니다. `if`는 네 칸, `print`는 여덟 칸 들여씁니다.
# 3. 대문자 `FAIL`로 씁니다. `fail`로 쓰면 하나도 안 나옵니다.
#
# 그래도 막히면 맨 아래 **정답 6-4** 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">6.5 기존 파일 뒤에 이어서 쓰고 싶을 때</mark>
#
# `"a"`는 덧붙이기(append) 모드입니다. 원래 내용을 두고 **맨 뒤에** 씁니다.

# %%
with open("memo.txt", "a", encoding="utf-8") as f:  # 덧붙이기 모드
    f.write("세 번째 줄\n")

with open("memo.txt", encoding="utf-8") as f:
    print(f.read())

# %% [markdown]
# `"w"`로 열었다면 앞의 두 줄이 사라지고 「세 번째 줄」만 남습니다. 기록을 쌓을 때는 `"a"`를 씁니다.

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 6-5 · 점검 기록 덧붙이기</font></h3></td></tr></table>
#
# `check.txt` 뒤에 「추가 점검」 한 줄을 덧붙인 뒤, 파일 전체를 읽어 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | 문제 6-1의 `check.txt` |
# | **🎯 나와야 하는 결과** | `점검 시작`<br>`점검 끝`<br>`추가 점검` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. `open("check.txt", "a", encoding="utf-8")`로 엽니다. 모드는 `"a"`입니다.
# 2. `f.write("추가 점검\n")`으로 한 줄 씁니다.
# 3. `with`를 **새로 한 번 더** 써서 읽기 모드로 열고 `read()`로 출력합니다.
# 4. 「추가 점검」이 두 번 나오면 이 셀을 두 번 실행한 것입니다. 문제 6-1을 다시 실행하면 처음 상태로 돌아갑니다.
#
# 그래도 막히면 맨 아래 **정답 6-5** 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %% [markdown]
# ### <mark style="display:block; background:#bbdefb; color:#1a1a1a; padding:6px 12px; border-radius:4px">6.정리 📋 한눈에</mark>
#
# | 쓰는 법 | 뜻 |
# |---|---|
# | `with open(이름, "w", encoding="utf-8") as f:` | 새로 쓴다 (있던 내용은 지워진다) |
# | `"a"` | 맨 뒤에 이어서 쓴다 |
# | 모드 생략 | 읽는다 |
# | `f.write("글자\n")` | 파일에 쓴다 — 줄바꿈은 직접 붙인다 |
# | `f.read()` | 파일 전체를 한 덩어리로 읽는다 |
# | `for line in f:` | 한 줄씩 읽는다 |
# | `line.strip()` | 양쪽 빈칸과 줄바꿈을 지운다 |
# | `"FAIL" in line` | 글자가 들어 있으면 True |

# %% [markdown]
# ---
#
# # <mark style="display:block; background:#c8e6c9; color:#1a1a1a; padding:6px 12px; border-radius:4px">정답 · 먼저 풀어 본 뒤에 엽니다</mark>
#
# 1. 각 셀은 제목만 보입니다. **「코드 표시」를 누르면 코드가 열립니다.**
# 2. 정답 셀은 혼자서도 실행됩니다. ▶를 눌러 결과를 비교해 보세요.
# 3. 답이 달라도 결과가 같으면 맞은 것입니다. 코드를 쓰는 방법은 여러 가지입니다.

# %%
#@title 정답 5-1 { display-mode: "form" }
def start_check():
    print("점검을 시작합니다")

start_check()
start_check()

# %%
#@title 정답 5-2 { display-mode: "form" }
def show_user(user):
    print(f"{user} 확인")

show_user("kim01")

# %%
#@title 정답 5-3 { display-mode: "form" }
def is_failed(result):
    return result == "FAIL"

print(is_failed("FAIL"))

# %%
#@title 정답 5-4 { display-mode: "form" }
logs = [
    {"user": "kim01", "result": "FAIL"},
    {"user": "lee02", "result": "OK"},
    {"user": "park03", "result": "FAIL"},
]

def collect_failed_users(logs):
    failed_users = []
    for log in logs:
        if log["result"] == "FAIL":
            failed_users.append(log["user"])
    return failed_users

print(collect_failed_users(logs))

# %%
#@title 정답 5-5 { display-mode: "form" }
def show_level(user, level="주의"):
    print(f"{user}: {level}")

show_level("kim01")
show_level("park03", "높음")

# %%
#@title 정답 5-6 { display-mode: "form" }
from collections import Counter
failed_users = ["kim01", "kim01", "kim01", "park03"]

def report_suspects(failed_users, threshold=2):
    counts = Counter(failed_users)
    for user, count in counts.items():
        if count >= threshold:
            print(f"확인 필요: {user} · {count}회")

report_suspects(failed_users)

# %%
#@title 정답 6-1 { display-mode: "form" }
with open("check.txt", "w", encoding="utf-8") as f:
    f.write("점검 시작\n")
    f.write("점검 끝\n")

# %%
#@title 정답 6-2 { display-mode: "form" }
with open("check.txt", "w", encoding="utf-8") as f:  # 문제 6-1
    f.write("점검 시작\n")
    f.write("점검 끝\n")

with open("check.txt", encoding="utf-8") as f:
    print(f.read())

# %%
#@title 정답 6-3 { display-mode: "form" }
lines = [
    "09:01,kim01,10.0.3.21,LOGIN,FAIL",
    "09:03,lee02,10.0.7.5,LOGIN,OK",
    "09:05,kim01,10.0.3.21,LOGIN,FAIL",
    "09:08,park03,10.0.9.8,FILE_OPEN,OK",
    "09:11,kim01,10.0.3.21,LOGIN,FAIL",
    "09:14,park03,10.0.9.8,LOGIN,FAIL",
]

with open("sample_logs.csv", "w", encoding="utf-8") as f:
    for line in lines:
        f.write(f"{line}\n")

count = 0
with open("sample_logs.csv", encoding="utf-8") as f:
    for line in f:
        print(line.strip())
        count = count + 1

print(f"총 {count}줄")

# %%
#@title 정답 6-4 { display-mode: "form" }
lines = [
    "09:01,kim01,10.0.3.21,LOGIN,FAIL",
    "09:03,lee02,10.0.7.5,LOGIN,OK",
    "09:05,kim01,10.0.3.21,LOGIN,FAIL",
    "09:08,park03,10.0.9.8,FILE_OPEN,OK",
    "09:11,kim01,10.0.3.21,LOGIN,FAIL",
    "09:14,park03,10.0.9.8,LOGIN,FAIL",
]

with open("sample_logs.csv", "w", encoding="utf-8") as f:
    for line in lines:
        f.write(f"{line}\n")

with open("sample_logs.csv", encoding="utf-8") as f:
    for line in f:
        if "FAIL" in line:
            print(line.strip())

# %%
#@title 정답 6-5 { display-mode: "form" }
with open("check.txt", "w", encoding="utf-8") as f:  # 문제 6-1
    f.write("점검 시작\n")
    f.write("점검 끝\n")

with open("check.txt", "a", encoding="utf-8") as f:
    f.write("추가 점검\n")

with open("check.txt", encoding="utf-8") as f:
    print(f.read())
