# %% [markdown]
# # <mark style="display:block; background:#d1c4e9; color:#1a1a1a; padding:6px 12px; border-radius:4px">9/23(수) 오전 · 조건문 · 반복문 · 집계 — 연습장</mark>
#
# 어제 만든 **로그 딕셔너리와 리스트**를 오늘 계속 사용합니다. 외우지 말고, 위 예시를 찾아 고쳐 쓰면 됩니다.
#
# 오늘은 최종 `.py` 파일을 제출하지 않습니다. **코랩 안에서 실행 결과가 맞는지 확인**하는 데 집중합니다.

# %% [markdown]
# ## <mark style="display:block; background:#c8e6c9; color:#1a1a1a; padding:6px 12px; border-radius:4px">시작하기 · 이 노트북을 여는 법</mark>
#
# ### 0.1 맨 먼저 · 내 사본 만들기
#
# 1. 위 메뉴에서 **파일 › 드라이브에 사본 저장**을 누릅니다.
# 2. 제목이 **「사본: …」**으로 바뀌면 된 것입니다.
# 3. 사본을 만들지 않으면 내가 쓴 코드가 저장되지 않습니다.
#
# ### 0.2 셀 실행하기
#
# 셀을 누르고 **Shift + Enter**를 칩니다. 왼쪽 **▶**를 눌러도 같습니다.
#
# ### 0.3 오늘의 순서
#
# 1. 조건문 — 한 건을 판단한다
# 2. 반복문 — 모든 로그에 같은 판단을 한다
# 3. 집합과 Counter — 사람 수와 횟수를 센다
# 4. 종합 — 로그 목록에서 확인할 계정을 찾는다
#
# 오늘 필요한 문법만 사용해 한 단계씩 완성합니다.

# %%
# 이 셀의 목적 — 노트북이 제대로 도는지 확인한다
print("9/23 준비 끝")

# %% [markdown]
# ---
#
# # <mark style="display:block; background:#ffe0b2; color:#1a1a1a; padding:6px 12px; border-radius:4px">1교시 (09:00–09:50) · 아침 리추얼 30분 + 조건문 20분</mark>

# %% [markdown]
# ---
#
# ## <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">1 · 조건문 — 값에 따라 실행할 길을 고른다</mark>
#
# 로그 한 건을 보고 정상인지 확인이 필요한지 판단합니다.

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">1.1 실패 로그인지 확인하고 싶을 때</mark>
#
# 조건이 참일 때만 들여쓴 줄이 실행됩니다.

# %%
# 이 셀의 목적 — 로그인 실패 한 건을 판단한다
log = {"user": "kim01", "result": "FAIL", "fail_count": 2}

if log["result"] == "FAIL":
    print("실패 로그입니다")

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">1.2 두 갈래로 나누고 싶을 때</mark>
#
# `if`가 거짓이면 `else` 쪽이 실행됩니다.

# %%
# 이 셀의 목적 — 실패와 정상을 두 갈래로 나눈다
log = {"user": "lee02", "result": "OK", "fail_count": 0}

if log["result"] == "FAIL":
    print("확인 필요")
else:
    print("정상")

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">1.3 여러 단계로 나누고 싶을 때</mark>
#
# 위에서부터 검사하고 처음 참인 한 갈래만 실행됩니다.

# %%
# 이 셀의 목적 — 실패 횟수에 따라 위험도를 세 단계로 나눈다
fail_count = 5

if fail_count >= 5:
    print("높음")
elif fail_count >= 2:
    print("주의")
else:
    print("낮음")

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">1.4 조건을 함께 확인하고 싶을 때</mark>
#
# `and`는 두 조건이 모두 참이어야 합니다. `or`는 하나만 참이어도 됩니다.

# %%
# 이 셀의 목적 — 로그인 실패이면서 횟수가 기준 이상인지 확인한다
log = {"user": "park03", "action": "LOGIN", "result": "FAIL", "fail_count": 4}

if log["action"] == "LOGIN" and log["result"] == "FAIL":
    print("로그인 실패")

if log["fail_count"] >= 5 or log["user"] == "admin":
    print("즉시 확인")
else:
    print("계속 관찰")

# %% [markdown]
# ### <mark style="display:block; background:#bbdefb; color:#1a1a1a; padding:6px 12px; border-radius:4px">1.정리 📋 한눈에</mark>
#
# | 쓰는 법 | 뜻 |
# |---|---|
# | `if 조건:` | 조건이 참이면 아래 들여쓴 줄을 실행한다 |
# | `elif 조건:` | 앞 조건이 거짓일 때 다음 조건을 검사한다 |
# | `else:` | 앞 조건이 모두 거짓일 때 실행한다 |
# | `and` | 양쪽 조건이 모두 참 |
# | `or` | 양쪽 중 하나라도 참 |

# %% [markdown]
# ---
#
# ## <mark style="display:block; background:#f8bbd0; color:#1a1a1a; padding:6px 12px; border-radius:4px">✍️ 각자 풉니다 — 문제 5개</mark>
#
# **1-1~1-5 · 조건문**
#
# 1. 먼저 위 예시를 다시 봅니다.
# 2. 그래도 막히면 문제 아래 **▸ 힌트 보기**를 누릅니다.
# 3. 결과가 표와 같으면 맞은 것입니다. 다 못 풀어도 괜찮습니다.

# %% [markdown]
# #### 문제 1-1. 실패 로그 찾기
#
# `result`가 `FAIL`이면 「확인 필요」를 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | `result = "FAIL"` |
# | **나와야 하는 결과** | `확인 필요` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# `if result == "FAIL":` 아래에 출력문을 들여씁니다.
#
# </details>

# %%
# 이 셀의 목적 — 문제 1-1. 실패 로그 찾기
# 나와야 하는 결과 — 확인 필요

result = "FAIL"

# 여기에 직접 작성 👇

# %% [markdown]
# #### 문제 1-2. 정상과 실패 나누기
#
# `result`가 `OK`이면 「정상」, 아니면 「실패」를 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | `result = "OK"` |
# | **나와야 하는 결과** | `정상` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# `if`와 `else` 두 갈래를 사용합니다.
#
# </details>

# %%
# 이 셀의 목적 — 문제 1-2. 정상과 실패 나누기
# 나와야 하는 결과 — 정상

result = "OK"

# 여기에 직접 작성 👇

# %% [markdown]
# #### 문제 1-3. 위험도 세 단계
#
# 5회 이상은 「높음」, 2회 이상은 「주의」, 나머지는 「낮음」을 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | `fail_count = 3` |
# | **나와야 하는 결과** | `주의` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 큰 값인 5부터 먼저 검사합니다.
#
# </details>

# %%
# 이 셀의 목적 — 문제 1-3. 위험도 세 단계
# 나와야 하는 결과 — 주의

fail_count = 3

# 여기에 직접 작성 👇

# %% [markdown]
# #### 문제 1-4. 두 조건 모두 확인하기
#
# 동작이 `LOGIN`이고 결과가 `FAIL`이면 「로그인 실패」를 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | `action = "LOGIN"` · `result = "FAIL"` |
# | **나와야 하는 결과** | `로그인 실패` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 두 비교식 사이에 `and`를 씁니다.
#
# </details>

# %%
# 이 셀의 목적 — 문제 1-4. 두 조건 모두 확인하기
# 나와야 하는 결과 — 로그인 실패

action = "LOGIN"
result = "FAIL"

# 여기에 직접 작성 👇

# %% [markdown]
# #### 문제 1-5. 관리자 또는 다섯 번 이상
#
# 계정이 `admin`이거나 실패가 5회 이상이면 「즉시 확인」을 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | `user = "kim01"` · `fail_count = 6` |
# | **나와야 하는 결과** | `즉시 확인` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 두 비교식 사이에 `or`를 씁니다.
#
# </details>

# %%
# 이 셀의 목적 — 문제 1-5. 관리자 또는 다섯 번 이상
# 나와야 하는 결과 — 즉시 확인

user = "kim01"
fail_count = 6

# 여기에 직접 작성 👇

# %% [markdown]
# ---
#
# # <mark style="display:block; background:#ffe0b2; color:#1a1a1a; padding:6px 12px; border-radius:4px">2교시 (10:00–10:50) · 반복문 · for + if + append</mark>

# %% [markdown]
# ---
#
# ## <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">2 · 반복문 — 같은 일을 모든 값에 적용한다</mark>
#
# 한 건에 하던 판단을 로그 목록 전체에 적용합니다.

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">2.1 리스트를 처음부터 끝까지 보고 싶을 때</mark>
#
# `for`는 리스트에서 값을 하나씩 꺼냅니다.

# %%
# 이 셀의 목적 — 계정 이름을 하나씩 꺼내 출력한다
users = ["kim01", "lee02", "park03"]

for user in users:
    print(user)

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">2.2 로그 딕셔너리를 하나씩 보고 싶을 때</mark>
#
# 한 번 돌 때마다 `log`에는 딕셔너리 하나가 들어갑니다.

# %%
# 이 셀의 목적 — 로그 세 건의 계정과 결과를 차례로 출력한다
logs = [
    {"user": "kim01", "result": "FAIL"},
    {"user": "lee02", "result": "OK"},
    {"user": "park03", "result": "FAIL"},
]

for log in logs:
    print(log["user"], log["result"])

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">2.3 실패한 계정만 모으고 싶을 때</mark>
#
# 빈 리스트를 만들고, 조건을 통과한 값만 `append()`합니다.

# %%
# 이 셀의 목적 — 실패한 계정만 새 리스트에 모은다
logs = [
    {"user": "kim01", "result": "FAIL"},
    {"user": "lee02", "result": "OK"},
    {"user": "park03", "result": "FAIL"},
]

failed_users = []
for log in logs:
    if log["result"] == "FAIL":
        failed_users.append(log["user"])

print(failed_users)
print(f"실패 {len(failed_users)}건")

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">2.4 정해진 횟수만큼 되풀이하고 싶을 때</mark>
#
# `range(3)`은 0, 1, 2를 차례로 만듭니다.

# %%
# 이 셀의 목적 — 점검 번호를 세 번 출력한다
for number in range(3):
    print(f"{number + 1}번째 점검")

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">2.5 조건이 참인 동안 되풀이하고 싶을 때</mark>
#
# `while`은 조건이 참인 동안 반복합니다. 조건에 쓰는 값이 바뀌어야 끝납니다.

# %%
# 이 셀의 목적 — 실패 횟수가 3이 될 때까지 1씩 늘린다
fail_count = 0

while fail_count < 3:
    fail_count = fail_count + 1
    print(fail_count)

# %% [markdown]
# ### <mark style="display:block; background:#bbdefb; color:#1a1a1a; padding:6px 12px; border-radius:4px">2.정리 📋 한눈에</mark>
#
# | 쓰는 법 | 뜻 |
# |---|---|
# | `for x in 목록:` | 목록에서 값을 하나씩 꺼낸다 |
# | `range(3)` | 0, 1, 2를 만든다 |
# | `while 조건:` | 조건이 참인 동안 되풀이한다 |
# | `결과 = []` | 모을 빈 리스트를 먼저 만든다 |
# | `결과.append(x)` | 조건에 맞는 값을 뒤에 붙인다 |

# %% [markdown]
# ---
#
# ## <mark style="display:block; background:#f8bbd0; color:#1a1a1a; padding:6px 12px; border-radius:4px">✍️ 각자 풉니다 — 문제 6개</mark>
#
# **2-1~2-6 · 반복문**
#
# 1. 먼저 위 예시를 다시 봅니다.
# 2. 그래도 막히면 문제 아래 **▸ 힌트 보기**를 누릅니다.
# 3. 결과가 표와 같으면 맞은 것입니다. 다 못 풀어도 괜찮습니다.

# %% [markdown]
# #### 문제 2-1. 계정 모두 출력하기
#
# 계정 목록을 반복해 한 줄에 하나씩 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | `users = ["kim01", "lee02", "park03"]` |
# | **나와야 하는 결과** | `kim01`<br>`lee02`<br>`park03` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# `for user in users:`를 사용합니다.
#
# </details>

# %%
# 이 셀의 목적 — 문제 2-1. 계정 모두 출력하기
# 나와야 하는 결과 — kim01 / lee02 / park03

users = ["kim01", "lee02", "park03"]

# 여기에 직접 작성 👇

# %% [markdown]
# #### 문제 2-2. 실패 결과만 출력하기
#
# 로그를 반복하면서 결과가 `FAIL`인 계정만 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | 로그 딕셔너리 3건 |
# | **나와야 하는 결과** | `kim01`<br>`park03` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 반복문 안에 조건문을 넣습니다.
#
# </details>

# %%
# 이 셀의 목적 — 문제 2-2. 실패 결과만 출력하기
# 나와야 하는 결과 — kim01 / park03

logs = [
    {"user": "kim01", "result": "FAIL"},
    {"user": "lee02", "result": "OK"},
    {"user": "park03", "result": "FAIL"},
]

# 여기에 직접 작성 👇

# %% [markdown]
# #### 문제 2-3. 실패 계정 목록 만들기
#
# 실패한 계정만 `failed_users`에 모아 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | 로그 딕셔너리 3건 |
# | **나와야 하는 결과** | `['kim01', 'park03']` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 빈 리스트는 반복문 위에 만들고, 조건 안에서 `append()`합니다.
#
# </details>

# %%
# 이 셀의 목적 — 문제 2-3. 실패 계정 목록 만들기
# 나와야 하는 결과 — ['kim01', 'park03']

logs = [
    {"user": "kim01", "result": "FAIL"},
    {"user": "lee02", "result": "OK"},
    {"user": "park03", "result": "FAIL"},
]
failed_users = []

# 여기에 직접 작성 👇

# %% [markdown]
# #### 문제 2-4. 실패 건수 세기
#
# 실패한 로그가 몇 건인지 숫자로 세어 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | 로그 딕셔너리 4건 |
# | **나와야 하는 결과** | `3` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 실패를 만날 때마다 `fail_count = fail_count + 1`로 늘립니다.
#
# </details>

# %%
# 이 셀의 목적 — 문제 2-4. 실패 건수 세기
# 나와야 하는 결과 — 3

logs = [
    {"result": "FAIL"}, {"result": "OK"},
    {"result": "FAIL"}, {"result": "FAIL"},
]
fail_count = 0

# 여기에 직접 작성 👇

# %% [markdown]
# #### 문제 2-5. 다섯 번 점검하기
#
# `range()`를 사용해 「1번째 점검」부터 「5번째 점검」까지 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | 없음 |
# | **나와야 하는 결과** | `1번째 점검` … `5번째 점검` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# `range(5)`의 값은 0부터 4까지라 출력할 때 1을 더합니다.
#
# </details>

# %%
# 이 셀의 목적 — 문제 2-5. 다섯 번 점검하기
# 나와야 하는 결과 — 1번째 점검 … 5번째 점검

# 여기에 직접 작성 👇

# %% [markdown]
# #### 문제 2-6. 세 번이 될 때까지
#
# `while`을 사용해 0에서 시작한 `count`를 3까지 늘려 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | `count = 0` |
# | **나와야 하는 결과** | `1`<br>`2`<br>`3` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 조건은 `count < 3`입니다. 반복문 안에서 값을 꼭 늘립니다.
#
# </details>

# %%
# 이 셀의 목적 — 문제 2-6. 세 번이 될 때까지
# 나와야 하는 결과 — 1 / 2 / 3

count = 0

# 여기에 직접 작성 👇

# %% [markdown]
# ---
#
# # <mark style="display:block; background:#ffe0b2; color:#1a1a1a; padding:6px 12px; border-radius:4px">3교시 (11:00–11:50) · 집합 · Counter · 기준값</mark>

# %% [markdown]
# ---
#
# ## <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">3 · 집합과 Counter — 중복을 지우고 횟수를 센다</mark>
#
# 실패한 사람이 몇 명인지, 각자 몇 번 실패했는지를 구분합니다.

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">3.1 중복을 지우고 싶을 때</mark>
#
# `set()`은 같은 값을 하나만 남깁니다. 결과의 순서는 달라질 수 있습니다.

# %%
# 이 셀의 목적 — 실패 계정의 중복을 지운다
failed_users = ["kim01", "kim01", "lee02", "park03", "kim01"]
unique_users = set(failed_users)

print(unique_users)
print(f"실패 계정 {len(unique_users)}명")

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">3.2 값마다 횟수를 세고 싶을 때</mark>
#
# `Counter`는 값마다 나온 횟수를 딕셔너리처럼 돌려줍니다.

# %%
# 이 셀의 목적 — 계정별 실패 횟수를 센다
from collections import Counter

failed_users = ["kim01", "kim01", "lee02", "park03", "kim01"]
counts = Counter(failed_users)

print(counts)
print(counts["kim01"])

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">3.3 계정과 횟수를 함께 돌고 싶을 때</mark>
#
# `.items()`는 키와 값을 한 쌍씩 꺼냅니다.

# %%
# 이 셀의 목적 — 모든 계정의 실패 횟수를 한 줄씩 출력한다
from collections import Counter

counts = Counter(["kim01", "kim01", "lee02", "park03", "kim01"])
for user, count in counts.items():
    print(f"{user}: {count}회")

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">3.4 기준 이상인 계정만 찾고 싶을 때</mark>
#
# 기준값에는 대문자 이름을 붙여 한 곳에서 바꿉니다.

# %%
# 이 셀의 목적 — 기준 이상 실패한 계정만 출력한다
from collections import Counter

THRESHOLD = 2
counts = Counter(["kim01", "kim01", "lee02", "park03", "kim01"])

for user, count in counts.items():
    if count >= THRESHOLD:
        print(f"확인 필요: {user} · {count}회")

# %% [markdown]
# ### <mark style="display:block; background:#bbdefb; color:#1a1a1a; padding:6px 12px; border-radius:4px">3.정리 📋 한눈에</mark>
#
# | 쓰는 법 | 뜻 |
# |---|---|
# | `set(목록)` | 중복을 지워 서로 다른 값만 남긴다 |
# | `Counter(목록)` | 값마다 몇 번 나왔는지 센다 |
# | `counts.items()` | 값과 횟수를 한 쌍씩 꺼낸다 |
# | `THRESHOLD = 2` | 여러 곳에서 쓸 기준값에 이름을 붙인다 |

# %% [markdown]
# ---
#
# ## <mark style="display:block; background:#f8bbd0; color:#1a1a1a; padding:6px 12px; border-radius:4px">✍️ 각자 풉니다 — 문제 6개</mark>
#
# **3-1~3-6 · 집합과 카운팅**
#
# 1. 먼저 위 예시를 다시 봅니다.
# 2. 그래도 막히면 문제 아래 **▸ 힌트 보기**를 누릅니다.
# 3. 결과가 표와 같으면 맞은 것입니다. 다 못 풀어도 괜찮습니다.

# %% [markdown]
# #### 문제 3-1. 실패한 사람 수
#
# 중복된 계정을 지우고 서로 다른 계정 수를 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | `failed_users = ["kim01", "kim01", "lee02", "kim01"]` |
# | **나와야 하는 결과** | `2` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# `set()`으로 바꾼 뒤 `len()`으로 셉니다.
#
# </details>

# %%
# 이 셀의 목적 — 문제 3-1. 실패한 사람 수
# 나와야 하는 결과 — 2

failed_users = ["kim01", "kim01", "lee02", "kim01"]

# 여기에 직접 작성 👇

# %% [markdown]
# #### 문제 3-2. 계정별 횟수
#
# `Counter`로 계정별 실패 횟수를 만들어 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | 실패 계정 목록 |
# | **나와야 하는 결과** | `Counter({'kim01': 3, 'lee02': 1})` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# `Counter(failed_users)`를 출력합니다.
#
# </details>

# %%
# 이 셀의 목적 — 문제 3-2. 계정별 횟수
# 나와야 하는 결과 — Counter({'kim01': 3, 'lee02': 1})

from collections import Counter
failed_users = ["kim01", "kim01", "lee02", "kim01"]

# 여기에 직접 작성 👇

# %% [markdown]
# #### 문제 3-3. 한 계정의 횟수
#
# `kim01`의 실패 횟수만 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | `counts = Counter(...)` |
# | **나와야 하는 결과** | `3` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# Counter 결과는 딕셔너리처럼 대괄호로 꺼냅니다.
#
# </details>

# %%
# 이 셀의 목적 — 문제 3-3. 한 계정의 횟수
# 나와야 하는 결과 — 3

from collections import Counter
counts = Counter(["kim01", "kim01", "lee02", "kim01"])

# 여기에 직접 작성 👇

# %% [markdown]
# #### 문제 3-4. 모든 횟수 출력하기
#
# 계정과 횟수를 「계정: N회」 모양으로 한 줄씩 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | `counts` |
# | **나와야 하는 결과** | `kim01: 2회`<br>`lee02: 1회` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# `.items()`로 계정과 횟수를 함께 꺼냅니다.
#
# </details>

# %%
# 이 셀의 목적 — 문제 3-4. 모든 횟수 출력하기
# 나와야 하는 결과 — kim01: 2회 / lee02: 1회

from collections import Counter
counts = Counter(["kim01", "kim01", "lee02"])

# 여기에 직접 작성 👇

# %% [markdown]
# #### 문제 3-5. 기준 이상만 출력하기
#
# 실패가 2회 이상인 계정만 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | `THRESHOLD = 2` · `counts` |
# | **나와야 하는 결과** | `kim01` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 반복문 안에서 `count >= THRESHOLD`를 확인합니다.
#
# </details>

# %%
# 이 셀의 목적 — 문제 3-5. 기준 이상만 출력하기
# 나와야 하는 결과 — kim01

from collections import Counter
THRESHOLD = 2
counts = Counter(["kim01", "kim01", "lee02"])

# 여기에 직접 작성 👇

# %% [markdown]
# #### 문제 3-6. 기준 바꿔 다시 보기
#
# 기준을 3으로 바꾸고, 3회 이상인 계정과 횟수를 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | 계정별 실패 횟수 |
# | **나와야 하는 결과** | `park03 · 3회` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 기준값은 위 한 줄에서만 바꾸고 아래 코드는 그대로 둡니다.
#
# </details>

# %%
# 이 셀의 목적 — 문제 3-6. 기준 바꿔 다시 보기
# 나와야 하는 결과 — park03 · 3회

from collections import Counter
THRESHOLD = 3
counts = Counter(["kim01", "kim01", "lee02", "park03", "park03", "park03"])

# 여기에 직접 작성 👇

# %% [markdown]
# ---
#
# # <mark style="display:block; background:#ffe0b2; color:#1a1a1a; padding:6px 12px; border-radius:4px">4교시 (12:00–12:50) · 오전 종합 실습</mark>

# %% [markdown]
# ---
#
# ## <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">4 · 오전 종합 — 로그 목록에서 확인할 계정을 찾는다</mark>
#
# 같은 데이터로 조건문 → 반복문 → Counter → 기준값 판정을 이어 갑니다.

# %% [markdown]
# ### 오늘 사용할 로그
#
# 아래 셀을 먼저 실행합니다. 이후 문제는 이 `logs`를 계속 사용합니다.

# %%
logs = [
    {"time": "09:01", "user": "kim01", "ip": "10.0.3.21", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:03", "user": "lee02", "ip": "10.0.7.5", "action": "LOGIN", "result": "OK"},
    {"time": "09:05", "user": "kim01", "ip": "10.0.3.21", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:08", "user": "park03", "ip": "10.0.9.8", "action": "FILE_OPEN", "result": "OK"},
    {"time": "09:11", "user": "kim01", "ip": "10.0.3.21", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:14", "user": "park03", "ip": "10.0.9.8", "action": "LOGIN", "result": "FAIL"},
]

# %% [markdown]
# ---
#
# ## <mark style="display:block; background:#f8bbd0; color:#1a1a1a; padding:6px 12px; border-radius:4px">✍️ 각자 풉니다 — 단계 문제 5개</mark>
#
# **4-1~4-5 · 오전 통합**
#
# 1. 먼저 위 예시를 다시 봅니다.
# 2. 그래도 막히면 문제 아래 **▸ 힌트 보기**를 누릅니다.
# 3. 결과가 표와 같으면 맞은 것입니다. 다 못 풀어도 괜찮습니다.

# %% [markdown]
# #### 문제 4-1. 모든 로그 확인하기
#
# 각 로그의 시각·계정·동작·결과를 한 줄씩 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | 위 `logs` |
# | **나와야 하는 결과** | `09:01 kim01 LOGIN FAIL` 등 6줄 |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# `for log in logs:`로 딕셔너리를 하나씩 꺼냅니다.
#
# </details>

# %%
# 이 셀의 목적 — 문제 4-1. 모든 로그 확인하기
# 나와야 하는 결과 — 09:01 kim01 LOGIN FAIL 등 6줄

# 여기에 직접 작성 👇

# %% [markdown]
# #### 문제 4-2. 로그인 실패만 모으기
#
# 동작이 `LOGIN`이고 결과가 `FAIL`인 계정만 `failed_users`에 모으시오.
#
# | | |
# |---|---|
# | **주어지는 값** | 위 `logs` |
# | **나와야 하는 결과** | `['kim01', 'kim01', 'kim01', 'park03']` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 두 조건을 `and`로 잇고 계정 이름을 `append()`합니다.
#
# </details>

# %%
# 이 셀의 목적 — 문제 4-2. 로그인 실패만 모으기
# 나와야 하는 결과 — ['kim01', 'kim01', 'kim01', 'park03']

failed_users = []

# 여기에 직접 작성 👇

# %% [markdown]
# #### 문제 4-3. 실패한 사람과 건수 비교하기
#
# 서로 다른 실패 계정 수와 전체 실패 건수를 각각 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | 문제 4-2의 `failed_users` |
# | **나와야 하는 결과** | `실패 계정 2명`<br>`실패 로그 4건` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 사람 수는 `len(set(...))`, 건수는 `len(...)`입니다.
#
# </details>

# %%
# 이 셀의 목적 — 문제 4-3. 실패한 사람과 건수 비교하기
# 나와야 하는 결과 — 실패 계정 2명 / 실패 로그 4건

# 여기에 직접 작성 👇

# %% [markdown]
# #### 문제 4-4. 계정별 로그인 실패 횟수
#
# `Counter`로 계정별 실패 횟수를 세어 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | 문제 4-2의 `failed_users` |
# | **나와야 하는 결과** | `kim01: 3회`<br>`park03: 1회` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# Counter 결과의 `.items()`를 반복합니다.
#
# </details>

# %%
# 이 셀의 목적 — 문제 4-4. 계정별 로그인 실패 횟수
# 나와야 하는 결과 — kim01: 3회 / park03: 1회

from collections import Counter

# 여기에 직접 작성 👇

# %% [markdown]
# #### 문제 4-5. 확인할 계정 찾기
#
# 기준을 2회로 두고, 기준 이상인 계정을 「확인 필요: 계정 · N회」 모양으로 출력하시오.
#
# | | |
# |---|---|
# | **주어지는 값** | `THRESHOLD = 2` |
# | **나와야 하는 결과** | `확인 필요: kim01 · 3회` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 문제 4-4의 Counter 결과를 다시 사용합니다.
#
# </details>

# %%
# 이 셀의 목적 — 문제 4-5. 확인할 계정 찾기
# 나와야 하는 결과 — 확인 필요: kim01 · 3회

THRESHOLD = 2

# 여기에 직접 작성 👇
