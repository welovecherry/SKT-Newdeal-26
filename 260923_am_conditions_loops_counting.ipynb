# %% [markdown]
# # <mark style="display:block; background:#d1c4e9; color:#1a1a1a; padding:6px 12px; border-radius:4px">9/23(수) 오전 · 조건문 · 반복문 · 집계 — 실습</mark>
#
# 어제 만든 로그 딕셔너리와 리스트를 오늘 계속 사용합니다. 외우지 말고, 위 예시를 찾아 고쳐 쓰면 됩니다.
#
# 오늘은 최종 `.py` 파일을 제출하지 않습니다. 코랩 안에서 실행 결과가 맞는지 확인하는 데 집중합니다.

# %% [markdown]
# ## <mark style="display:block; background:#c8e6c9; color:#1a1a1a; padding:6px 12px; border-radius:4px">시작하기 · 이 노트북을 여는 법</mark>
#
# ### 0.1 맨 먼저 · 내 사본 만들기
#
# 1. 위 메뉴에서 파일 › 드라이브에 사본 저장을 누릅니다.
# 2. 제목이 「사본: …」으로 바뀌면 된 것입니다.
# 3. 사본을 만들지 않으면 내가 쓴 코드가 저장되지 않습니다.
#
# ### 0.2 셀 실행하기
#
# 셀을 누르고 Shift + Enter를 칩니다. 왼쪽 ▶를 눌러도 같습니다.
#
# ### 0.3 오늘의 순서
#
# 1. 조건문 — 한 건을 판단한다
# 2. 반복문 — 모든 로그에 같은 판단을 한다
# 3. 집합과 Counter — 사람 수와 횟수를 센다
# 4. 종합 — 로그 목록에서 확인할 계정을 찾는다
#
# 오늘 필요한 문법만 사용해 한 단계씩 완성합니다.
#
#
# ### 0.4 막혔을 때
#
# 1. 문제 아래 ▸ 힌트 보기를 눌러 순서대로 따라 합니다.
# 2. 그래도 막히면 노트북 맨 아래 「정답」으로 갑니다. 왼쪽 목차(☰)에서 바로 갈 수 있습니다.
# 3. 정답 셀은 제목만 보입니다. 「코드 표시」를 누르면 코드가 열립니다. 먼저 스스로 해 본 뒤 엽니다.

# %%
print("9/23 준비 끝")  # 노트북 실행 확인

# %% [markdown]
# ---
#
# # <mark style="display:block; background:#ffe0b2; color:#1a1a1a; padding:6px 12px; border-radius:4px">1교시 (09:00–09:50) · 아침 리추얼 30분 + 조건문 20분</mark>

# %% [markdown]
# ---
#
# ## <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">1 · 조건문 — 값에 따라 실행할 길을 고른다</mark>
#
# 로그 한 건을 보고 정상인지 확인이 필요한지 판단합니다.

# %% [markdown]
# ### 왜 조건문이 필요한가
#
# 1. 지금까지 쓴 코드는 위에서 아래로 한 번씩 다 실행됐습니다. 로그가 정상이든 실패든 똑같이 돌았습니다.
# 2. 실무에서는 「실패일 때만」 알림을 보냅니다. 값을 보고 할 일을 고르는 것이 조건문입니다.
# 3. 갈림길에서 표지판을 보고 길을 고르는 것과 같습니다. 표지판이 조건이고, 고른 길이 실행될 코드입니다.

# %% [markdown]
# ### 이 시간에 나오는 말
#
# | 말 | 뜻 | 예 |
# |---|---|---|
# | 조건문 | 값에 따라 실행할 코드를 고르는 문장 | `if fail_count >= 5:` |
# | 비교식 | 두 값을 견주는 식. 결과는 `True` 아니면 `False` | `result == "FAIL"` |
# | `if` | 조건이 참일 때 아래 묶음을 실행한다 | |
# | `elif` | 앞 조건이 거짓일 때 다음 조건을 검사한다 | |
# | `else` | 앞 조건이 모두 거짓일 때 실행한다 | |
# | 들여쓰기 | 어디까지가 그 조건의 묶음인지 나타내는 빈칸 네 칸 | |

# %% [markdown]
# ### 조건문을 쓰는 규칙 네 가지
#
# 1. 줄 끝에 콜론 `:` 을 붙입니다. 빠뜨리면 `SyntaxError` 가 납니다.
# 2. 조건이 참일 때 할 일은 네 칸 들여씁니다. 들여쓰기가 끝나는 곳이 묶음의 끝입니다.
# 3. 같은지 견줄 때는 `==` 를 씁니다. `=` 는 값을 담을 때만 씁니다.
# 4. `if` → `elif` → `else` 는 위에서부터 검사하고, 처음 참이 된 갈래 하나만 실행합니다.

# %% [markdown]
# <div style="background:#e8f5e9; color:#17351f; padding:12px 16px; border-radius:8px"><strong>🔎 코드를 읽는 법</strong><br>코드는 위에서 아래로 읽습니다. `if` 줄을 질문으로 읽고, 들여쓴 줄을 ‘참일 때 하는 일’로 읽어 보세요.</div>

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">1.1 실패 로그인지 확인하고 싶을 때</mark>
#
# 조건이 참일 때만 들여쓴 줄이 실행됩니다.

# %%
# 로그인 로그 한 건을 준비합니다.
log = {"user": "kim01", "result": "FAIL", "fail_count": 2}

if log["result"] == "FAIL":  # 실패 로그인지 확인
    print("실패 로그입니다")  # 조건이 참일 때 실행

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 1-1 · 실패 로그 찾기</font></h3></td></tr></table>
#
# `result` 가 `FAIL` 인지 확인해, 맞으면 `확인 필요` 를 출력하시오.
#
# - 갈래는 하나입니다. `if` 만 쓰고 `else` 는 쓰지 않습니다.
#
# | | |
# |---|---|
# | 주어지는 값 | `result = "FAIL"` |
# | 🎯 나와야 하는 결과 | `확인 필요` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. 조건문은 `if 조건:` 한 줄로 시작합니다. 줄 끝의 콜론(`:`)을 빠뜨리지 않습니다.
# 2. 같은지 비교할 때는 `=`가 아니라 `==`를 씁니다. `=`는 값을 넣을 때만 씁니다.
# 3. 조건이 참일 때 할 일(`print`)은 네 칸 들여써서 `if` 아래에 둡니다.
# 4. 문자열 `"FAIL"`은 따옴표까지 똑같이 씁니다. 대문자·소문자가 다르면 다른 값입니다.
#
# 그래도 막히면 맨 아래 정답 1-1 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %%
result = "FAIL"

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">1.2 두 갈래로 나누고 싶을 때</mark>
#
# `if`가 거짓이면 `else` 쪽이 실행됩니다.

# %%
# 정상 로그인 로그 한 건을 준비합니다.
log = {"user": "lee02", "result": "OK", "fail_count": 0}

if log["result"] == "FAIL":  # 실패인지 확인
    print("확인 필요")  # 실패일 때 실행
else:  # 실패가 아닐 때 실행
    print("정상")

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 1-2 · 정상과 실패 나누기</font></h3></td></tr></table>
#
# `result` 가 `OK` 이면 `정상` 을, 아니면 `실패` 를 출력하시오.
#
# - 갈래가 둘입니다. `if` 와 `else` 를 씁니다.
#
# | | |
# |---|---|
# | 주어지는 값 | `result = "OK"` |
# | 🎯 나와야 하는 결과 | `정상` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. 갈래가 둘이면 `if`와 `else`를 씁니다.
# 2. `if result == "OK":` 아래에 「정상」을 출력합니다.
# 3. `else:`는 `if`와 같은 칸에서 시작합니다. `else` 뒤에는 조건을 쓰지 않고 콜론만 붙입니다.
# 4. `else:` 아래에 네 칸 들여써서 「실패」를 출력합니다.
#
# 그래도 막히면 맨 아래 정답 1-2 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %%
result = "OK"

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">1.3 여러 단계로 나누고 싶을 때</mark>
#
# 위에서부터 검사하고 처음 참인 한 갈래만 실행됩니다.

# %%
fail_count = 5  # 현재 실패 횟수

if fail_count >= 5:  # 5회 이상인지 확인
    print("높음")
elif fail_count >= 2:  # 2회 이상인지 확인
    print("주의")
else:  # 두 조건에 모두 해당하지 않을 때 실행
    print("낮음")

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 1-3 · 위험도 세 단계</font></h3></td></tr></table>
#
# `fail_count` 를 보고 위험도를 출력하시오.
#
# | 조건 | 출력할 말 |
# |---|---|
# | 5회 이상 | `높음` |
# | 2회 이상 | `주의` |
# | 그 밖 | `낮음` |
#
# | | |
# |---|---|
# | 주어지는 값 | `fail_count = 3` |
# | 🎯 나와야 하는 결과 | `주의` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. 갈래가 셋이면 `if` → `elif` → `else` 순서로 씁니다.
# 2. 위에서부터 검사해서 처음 참이 되는 갈래 하나만 실행됩니다.
# 3. 그래서 큰 기준(`>= 5`)을 먼저 검사합니다. `>= 2`를 먼저 쓰면 5회도 「주의」가 됩니다.
# 4. `>=`는 같은 값도 포함합니다. `fail_count`가 정확히 5여도 「높음」입니다.
#
# 그래도 막히면 맨 아래 정답 1-3 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %%
fail_count = 3

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">1.4 조건을 함께 확인하고 싶을 때</mark>
#
# `and`는 두 조건이 모두 참이어야 합니다. `or`는 하나만 참이어도 됩니다.

# %%
# 로그인 로그 한 건을 준비합니다.
log = {"user": "park03", "action": "LOGIN", "result": "FAIL", "fail_count": 4}

if log["action"] == "LOGIN" and log["result"] == "FAIL":  # 두 조건을 모두 확인
    print("로그인 실패")

if log["fail_count"] >= 5 or log["user"] == "admin":  # 둘 중 하나를 확인
    print("즉시 확인")
else:
    print("계속 관찰")

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 1-4 · 두 조건 모두 확인하기</font></h3></td></tr></table>
#
# 두 조건이 모두 맞을 때만 `로그인 실패` 를 출력하시오.
#
# - 조건 ① 동작이 `LOGIN` 이다 · 조건 ② 결과가 `FAIL` 이다
# - 두 조건을 `and` 로 잇습니다.
#
# | | |
# |---|---|
# | 주어지는 값 | `action = "LOGIN"` · `result = "FAIL"` |
# | 🎯 나와야 하는 결과 | `로그인 실패` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. 두 조건이 모두 참이어야 하면 `and`로 잇습니다.
# 2. 비교식 두 개를 따로 먼저 만들어 봅니다: `action == "LOGIN"`, `result == "FAIL"`.
# 3. 두 식 사이에 `and`를 넣어 `if` 한 줄에 씁니다. 줄 끝에는 콜론을 붙입니다.
# 4. 참일 때 네 칸 들여써서 「로그인 실패」를 출력합니다.
#
# 그래도 막히면 맨 아래 정답 1-4 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %%
action = "LOGIN"
result = "FAIL"

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 1-5 · 관리자 또는 다섯 번 이상</font></h3></td></tr></table>
#
# 둘 중 하나만 맞아도 `즉시 확인` 을 출력하시오.
#
# - 조건 ① 계정이 `admin` 이다 · 조건 ② 실패가 5회 이상이다
# - 두 조건을 `or` 로 잇습니다.
#
# | | |
# |---|---|
# | 주어지는 값 | `user = "kim01"` · `fail_count = 6` |
# | 🎯 나와야 하는 결과 | `즉시 확인` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. 둘 중 하나만 참이어도 되면 `or`로 잇습니다.
# 2. 비교식 두 개: `user == "admin"`, `fail_count >= 5`.
# 3. 이번 값은 `user`가 `admin`이 아니지만 `fail_count`가 6이라서 전체가 참이 됩니다.
# 4. 참일 때 네 칸 들여써서 「즉시 확인」을 출력합니다.
#
# 그래도 막히면 맨 아래 정답 1-5 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %%
user = "kim01"
fail_count = 6

# %% [markdown]
# ### <mark style="display:block; background:#bbdefb; color:#1a1a1a; padding:6px 12px; border-radius:4px">1.정리 📋 한눈에</mark>
#
# | 쓰는 법 | 뜻 |
# |---|---|
# | `if 조건:` | 조건이 참이면 아래 들여쓴 줄을 실행한다 |
# | `elif 조건:` | 앞 조건이 거짓일 때 다음 조건을 검사한다 |
# | `else:` | 앞 조건이 모두 거짓일 때 실행한다 |
# | `and` | 양쪽 조건이 모두 참 |
# | `or` | 양쪽 중 하나라도 참 |

# %% [markdown]
# ---
#
# # <mark style="display:block; background:#ffe0b2; color:#1a1a1a; padding:6px 12px; border-radius:4px">2교시 (10:00–10:50) · 반복문 · for + if + append</mark>

# %% [markdown]
# ---
#
# ## <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">2 · 반복문 — 같은 일을 모든 값에 적용한다</mark>
#
# 한 건에 하던 판단을 로그 목록 전체에 적용합니다.

# %% [markdown]
# ### 왜 반복문이 필요한가
#
# 1. 1교시에는 로그 한 건만 판단했습니다. 실제 로그는 하루에 수만 건입니다.
# 2. 같은 판단을 손으로 수만 번 적을 수는 없습니다. 목록에서 하나씩 꺼내며 같은 일을 시키는 것이 반복문입니다.
# 3. 명단을 위에서부터 한 명씩 부르며 출석을 확인하는 것과 같습니다.

# %% [markdown]
# ### 이 시간에 나오는 말
#
# | 말 | 뜻 |
# |---|---|
# | 반복문 | 같은 일을 여러 값에 되풀이하는 문장 |
# | `for` | 목록에서 값을 하나씩 꺼내며 반복한다 |
# | `while` | 조건이 참인 동안 반복한다 |
# | `range(3)` | 0, 1, 2 를 차례로 만든다 |
# | `append()` | 목록의 맨 뒤에 값을 하나 붙인다 |

# %% [markdown]
# ### 반복문을 쓰는 규칙 네 가지
#
# 1. `for 이름 in 목록:` 에서 `이름` 은 꺼낸 값을 담을 이름입니다. 내가 짓습니다.
# 2. 줄 끝에 콜론, 반복할 일은 네 칸 들여쓰기 — 조건문과 같습니다.
# 3. 결과를 모을 빈 목록은 반복문 위에서 한 번만 만듭니다. 안에서 만들면 매번 비워집니다.
# 4. `while` 은 조건에 쓰는 값을 반복문 안에서 바꿔야 끝납니다. 안 바꾸면 영원히 돕니다.

# %% [markdown]
# <div style="background:#e8f5e9; color:#17351f; padding:12px 16px; border-radius:8px"><strong>🔎 코드를 읽는 법</strong><br>`for 값 in 목록`은 ‘목록에서 값을 하나씩 꺼내며’라고 읽습니다. 들여쓰기가 끝나는 곳까지가 한 번에 반복할 일입니다.</div>

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">2.1 리스트를 처음부터 끝까지 보고 싶을 때</mark>
#
# `for`는 리스트에서 값을 하나씩 꺼냅니다.

# %%
users = ["kim01", "lee02", "park03"]  # 확인할 계정 목록

for user in users:  # 계정을 하나씩 꺼내 반복
    print(user)

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 2-1 · 계정 모두 출력하기</font></h3></td></tr></table>
#
# 계정 목록을 반복해 한 줄에 하나씩 출력하시오.
#
# - 반복문 안에서 할 일은 `print(user)` 한 줄입니다.
#
# | | |
# |---|---|
# | 주어지는 값 | `users = ["kim01", "lee02", "park03"]` |
# | 🎯 나와야 하는 결과 | `kim01`<br>`lee02`<br>`park03` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. `for user in users:`는 「`users`에서 값을 하나씩 꺼내 `user`라고 부른다」라고 읽습니다.
# 2. 줄 끝에 콜론(`:`)을 붙이고, 반복할 일은 네 칸 들여씁니다.
# 3. 반복할 일은 `print(user)` 한 줄입니다.
# 4. 목록에 값이 세 개라서 `print`가 세 번 실행됩니다.
#
# 그래도 막히면 맨 아래 정답 2-1 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %%
users = ["kim01", "lee02", "park03"]

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">2.2 로그 딕셔너리를 하나씩 보고 싶을 때</mark>
#
# 한 번 돌 때마다 `log`에는 딕셔너리 하나가 들어갑니다.

# %%
# 확인할 로그인 로그 세 건을 준비합니다.
logs = [
    {"user": "kim01", "result": "FAIL"},
    {"user": "lee02", "result": "OK"},
    {"user": "park03", "result": "FAIL"},
]

for log in logs:  # 로그를 하나씩 꺼내 반복
    print(log["user"], log["result"])

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 2-2 · 실패 결과만 출력하기</font></h3></td></tr></table>
#
# 로그를 하나씩 꺼내면서, 결과가 `FAIL` 인 로그의 계정만 출력하시오.
#
# - 반복문 안에 조건문을 넣습니다. 출력할 것은 계정 이름(`log["user"]`)뿐입니다.
#
# | | |
# |---|---|
# | 주어지는 값 | 로그 딕셔너리 3건 |
# | 🎯 나와야 하는 결과 | `kim01`<br>`park03` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. `for log in logs:`로 딕셔너리를 하나씩 꺼냅니다.
# 2. 반복문 안에 `if`를 넣습니다. `if`는 네 칸, `if` 안의 `print`는 여덟 칸 들여씁니다.
# 3. 결과는 `log["result"]`로, 계정은 `log["user"]`로 꺼냅니다.
# 4. 조건은 `log["result"] == "FAIL"`이고, 참일 때 계정만 출력합니다.
#
# 그래도 막히면 맨 아래 정답 2-2 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %%
logs = [
    {"user": "kim01", "result": "FAIL"},
    {"user": "lee02", "result": "OK"},
    {"user": "park03", "result": "FAIL"},
]

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">2.3 실패한 계정만 모으고 싶을 때</mark>
#
# 빈 리스트를 만들고, 조건을 통과한 값만 `append()`합니다.

# %%
# 확인할 로그인 로그 세 건을 준비합니다.
logs = [
    {"user": "kim01", "result": "FAIL"},
    {"user": "lee02", "result": "OK"},
    {"user": "park03", "result": "FAIL"},
]

failed_users = []  # 실패 계정을 담을 빈 목록
for log in logs:  # 로그를 하나씩 꺼내 반복
    if log["result"] == "FAIL":  # 실패 로그만 선택
        failed_users.append(log["user"])  # 계정을 목록에 추가

print(failed_users)
print(f"실패 {len(failed_users)}건")  # 목록 길이로 실패 건수 확인

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 2-3 · 실패 계정 목록 만들기</font></h3></td></tr></table>
#
# 실패한 로그의 계정만 `failed_users` 목록에 모아, 반복이 끝난 뒤 그 목록을 출력하시오.
#
# - 빈 목록은 이미 만들어져 있습니다. 조건이 맞을 때 `append()` 로 붙입니다.
#
# | | |
# |---|---|
# | 주어지는 값 | 로그 딕셔너리 3건 |
# | 🎯 나와야 하는 결과 | `['kim01', 'park03']` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. `failed_users = []`는 이미 있습니다. 빈 목록은 반복문 위에서 한 번만 만듭니다.
# 2. 문제 2-2처럼 `for` 안에 `if`를 넣어 실패 로그만 고릅니다.
# 3. `print` 대신 `failed_users.append(log["user"])`로 목록에 계정을 붙입니다.
# 4. 반복이 다 끝난 뒤 목록을 출력합니다. `print`는 `for`와 같은 칸(들여쓰기 없음)에 둡니다.
#
# 그래도 막히면 맨 아래 정답 2-3 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %%
logs = [
    {"user": "kim01", "result": "FAIL"},
    {"user": "lee02", "result": "OK"},
    {"user": "park03", "result": "FAIL"},
]
failed_users = []

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 2-4 · 실패 건수 세기</font></h3></td></tr></table>
#
# 실패한 로그가 몇 건인지 세어 숫자만 출력하시오.
#
# - 세는 값 `fail_count = 0` 은 이미 있습니다. 실패를 만날 때마다 1을 더합니다.
#
# | | |
# |---|---|
# | 주어지는 값 | 로그 딕셔너리 4건 |
# | 🎯 나와야 하는 결과 | `3` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. `fail_count = 0`은 이미 있습니다. 세는 값은 0에서 시작합니다.
# 2. `for` 안에서 `log["result"] == "FAIL"`인지 확인합니다.
# 3. 실패를 만나면 `fail_count = fail_count + 1`로 1을 더합니다.
# 4. 반복이 끝난 뒤 들여쓰기 없이 `fail_count`를 출력합니다.
#
# 그래도 막히면 맨 아래 정답 2-4 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %%
logs = [
    {"result": "FAIL"}, {"result": "OK"},
    {"result": "FAIL"}, {"result": "FAIL"},
]
fail_count = 0

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">2.4 정해진 횟수만큼 되풀이하고 싶을 때</mark>
#
# `range(3)`은 0, 1, 2를 차례로 만듭니다.

# %%
for number in range(3):  # 0부터 2까지 반복
    print(f"{number + 1}번째 점검")

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 2-5 · 다섯 번 점검하기</font></h3></td></tr></table>
#
# `range()` 를 써서 `1번째 점검` 부터 `5번째 점검` 까지 다섯 줄을 출력하시오.
#
# - 출력 줄은 `print(f"{number + 1}번째 점검")` 을 그대로 쓰면 됩니다.
# - `range(5)` 는 0부터 4까지라서 1을 더합니다.
#
# | | |
# |---|---|
# | 주어지는 값 | 없음 |
# | 🎯 나와야 하는 결과 | `1번째 점검` … `5번째 점검` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. `range(5)`는 0, 1, 2, 3, 4를 차례로 만듭니다. 값은 다섯 개지만 1이 아니라 0부터 시작합니다.
# 2. `for number in range(5):`로 반복합니다.
# 3. 화면에는 1부터 나와야 하므로 f-string 안에서 `{number + 1}`로 1을 더합니다.
# 4. 2.4 예시에서 숫자 하나만 바꾸면 됩니다.
#
# 그래도 막히면 맨 아래 정답 2-5 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">2.5 조건이 참인 동안 되풀이하고 싶을 때</mark>
#
# `while`은 조건이 참인 동안 반복합니다. 조건에 쓰는 값이 바뀌어야 끝납니다.

# %%
fail_count = 0  # 반복을 시작할 값

while fail_count < 3:  # 3보다 작은 동안 반복
    fail_count = fail_count + 1  # 1씩 증가
    print(fail_count)

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 2-6 · 세 번이 될 때까지</font></h3></td></tr></table>
#
# `while` 을 써서 `count` 를 1씩 늘리며 1, 2, 3을 한 줄씩 출력하시오.
#
# - 조건은 `count < 3` 입니다.
# - 반복문 안에서 값을 늘리지 않으면 영원히 멈추지 않습니다.
#
# | | |
# |---|---|
# | 주어지는 값 | `count = 0` |
# | 🎯 나와야 하는 결과 | `1`<br>`2`<br>`3` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. `while count < 3:`은 「`count`가 3보다 작은 동안 되풀이」라고 읽습니다.
# 2. 반복문 안에서 `count = count + 1`로 값을 늘립니다. 이 줄이 없으면 영원히 끝나지 않습니다.
# 3. 값을 늘린 다음에 출력해야 1, 2, 3이 나옵니다. 순서를 바꾸면 0, 1, 2가 나옵니다.
# 4. 셀이 멈추지 않으면 왼쪽 ■ 버튼을 눌러 멈춥니다.
#
# 그래도 막히면 맨 아래 정답 2-6 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %%
count = 0

# %% [markdown]
# ### <mark style="display:block; background:#bbdefb; color:#1a1a1a; padding:6px 12px; border-radius:4px">2.정리 📋 한눈에</mark>
#
# | 쓰는 법 | 뜻 |
# |---|---|
# | `for x in 목록:` | 목록에서 값을 하나씩 꺼낸다 |
# | `range(3)` | 0, 1, 2를 만든다 |
# | `while 조건:` | 조건이 참인 동안 되풀이한다 |
# | `결과 = []` | 모을 빈 리스트를 먼저 만든다 |
# | `결과.append(x)` | 조건에 맞는 값을 뒤에 붙인다 |

# %% [markdown]
# ---
#
# # <mark style="display:block; background:#ffe0b2; color:#1a1a1a; padding:6px 12px; border-radius:4px">3교시 (11:00–11:50) · 집합 · Counter · 기준값</mark>

# %% [markdown]
# ---
#
# ## <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">3 · 집합과 Counter — 중복을 지우고 횟수를 센다</mark>
#
# 실패한 사람이 몇 명인지, 각자 몇 번 실패했는지를 구분합니다.

# %% [markdown]
# ### 왜 집합과 Counter가 필요한가
#
# 1. 2교시에서 모은 실패 계정 목록에는 같은 이름이 여러 번 들어 있습니다.
# 2. 「몇 명이 실패했나」와 「누가 몇 번 실패했나」는 다른 질문입니다. 목록만으로는 둘 다 바로 답할 수 없습니다.
# 3. 사람 수는 `set`, 각자의 횟수는 `Counter` 가 답해 줍니다. 무엇을 세려는지 말로 먼저 정하는 것이 중요합니다.

# %% [markdown]
# ### 이 시간에 나오는 말
#
# | 말 | 뜻 | 답하는 질문 |
# |---|---|---|
# | 집합(`set`) | 같은 값을 하나만 남긴 묶음 | 몇 명인가 |
# | `Counter` | 값마다 몇 번 나왔는지 세어 주는 도구 | 각자 몇 번인가 |
# | `.items()` | 값과 횟수를 한 쌍씩 꺼낸다 | |
# | 임계값 | 「여기부터 확인한다」고 정해 둔 기준 숫자 | |

# %% [markdown]
# <div style="background:#e8f5e9; color:#17351f; padding:12px 16px; border-radius:8px"><strong>🔎 코드를 읽는 법</strong><br>`set`은 ‘몇 명’, `Counter`는 ‘각자 몇 번’이라는 질문에 답합니다. 먼저 무엇을 세려는지 말로 정하세요.</div>

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">3.1 중복을 지우고 싶을 때</mark>
#
# `set()`은 같은 값을 하나만 남깁니다. 결과의 순서는 달라질 수 있습니다.

# %%
# 중복이 있는 실패 계정 목록을 준비합니다.
failed_users = ["kim01", "kim01", "lee02", "park03", "kim01"]
unique_users = set(failed_users)  # 중복 제거

print(unique_users)
print(f"실패 계정 {len(unique_users)}명")  # 서로 다른 계정 수 확인

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 3-1 · 실패한 사람 수</font></h3></td></tr></table>
#
# 중복된 계정을 지우고, 서로 다른 계정이 몇 명인지 숫자만 출력하시오.
#
# - `set()` 으로 중복을 지운 뒤 `len()` 으로 셉니다.
#
# | | |
# |---|---|
# | 주어지는 값 | `failed_users = ["kim01", "kim01", "lee02", "kim01"]` |
# | 🎯 나와야 하는 결과 | `2` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. `set(failed_users)`는 중복을 지운 집합을 돌려줍니다.
# 2. 결과를 `unique_users` 같은 새 이름에 담습니다.
# 3. `len()`으로 집합의 개수를 셉니다. 이 개수가 「서로 다른 계정 수」입니다.
# 4. 원래 목록은 4건, 집합은 2명입니다. 두 숫자의 뜻이 다릅니다.
#
# 그래도 막히면 맨 아래 정답 3-1 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %%
failed_users = ["kim01", "kim01", "lee02", "kim01"]

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">3.2 값마다 횟수를 세고 싶을 때</mark>
#
# `Counter`는 값마다 나온 횟수를 딕셔너리처럼 돌려줍니다.

# %%
from collections import Counter  # 항목별 횟수를 세는 도구

# 중복이 있는 실패 계정 목록을 준비합니다.
failed_users = ["kim01", "kim01", "lee02", "park03", "kim01"]
counts = Counter(failed_users)  # 계정별 횟수 계산

print(counts)
print(counts["kim01"])  # kim01의 횟수만 확인

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 3-2 · 계정별 횟수</font></h3></td></tr></table>
#
# `Counter` 로 계정별 실패 횟수를 만들어 그대로 출력하시오.
#
# - 결과는 `Counter({'kim01': 3, 'lee02': 1})` 모양으로 나옵니다.
#
# | | |
# |---|---|
# | 주어지는 값 | 실패 계정 목록 |
# | 🎯 나와야 하는 결과 | `Counter({'kim01': 3, 'lee02': 1})` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. `from collections import Counter`는 이미 있습니다. 이 줄이 있어야 `Counter`를 쓸 수 있습니다.
# 2. `Counter(failed_users)`로 계정마다 몇 번 나왔는지 셉니다.
# 3. 결과를 `counts`에 담고 `print(counts)`로 출력합니다.
# 4. 결과는 `Counter({...})` 모양이고, 안쪽은 딕셔너리처럼 `계정: 횟수`입니다.
#
# 그래도 막히면 맨 아래 정답 3-2 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %%
from collections import Counter
failed_users = ["kim01", "kim01", "lee02", "kim01"]

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 3-3 · 한 계정의 횟수</font></h3></td></tr></table>
#
# 이미 만들어진 `counts` 에서 `kim01` 의 횟수만 꺼내 출력하시오.
#
# - 딕셔너리처럼 대괄호에 계정 이름을 넣어 꺼냅니다.
#
# | | |
# |---|---|
# | 주어지는 값 | `counts = Counter(...)` |
# | 🎯 나와야 하는 결과 | `3` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. `counts`는 이미 만들어져 있습니다.
# 2. `Counter`는 딕셔너리처럼 대괄호에 키를 넣어 값을 꺼냅니다.
# 3. 키는 계정 이름 `"kim01"`입니다. 따옴표를 빠뜨리지 않습니다.
# 4. 꺼낸 값을 `print()`로 감쌉니다.
#
# 그래도 막히면 맨 아래 정답 3-3 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %%
from collections import Counter
counts = Counter(["kim01", "kim01", "lee02", "kim01"])

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">3.3 계정과 횟수를 함께 돌고 싶을 때</mark>
#
# `.items()`는 키와 값을 한 쌍씩 꺼냅니다.

# %%
from collections import Counter  # 항목별 횟수를 세는 도구

# 실패 계정별 횟수를 계산합니다.
counts = Counter(["kim01", "kim01", "lee02", "park03", "kim01"])
for user, count in counts.items():  # 계정과 횟수를 함께 반복
    print(f"{user}: {count}회")

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 3-4 · 모든 횟수 출력하기</font></h3></td></tr></table>
#
# 계정과 횟수를 한 쌍씩 꺼내, 계정마다 한 줄씩 출력하시오.
#
# - `.items()` 로 두 값을 함께 꺼냅니다.
# - 출력 줄은 `print(f"{user}: {count}회")` 를 그대로 쓰면 됩니다.
#
# | | |
# |---|---|
# | 주어지는 값 | `counts` |
# | 🎯 나와야 하는 결과 | `kim01: 2회`<br>`lee02: 1회` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. `.items()`는 계정과 횟수를 한 쌍씩 꺼냅니다.
# 2. `for user, count in counts.items():`처럼 이름을 두 개 붙입니다. 앞은 계정, 뒤는 횟수입니다.
# 3. f-string으로 `f"{user}: {count}회"` 모양을 만듭니다.
# 4. 반복 안에서 출력하므로 계정 수만큼 줄이 나옵니다.
#
# 그래도 막히면 맨 아래 정답 3-4 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %%
from collections import Counter
counts = Counter(["kim01", "kim01", "lee02"])

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">3.4 기준 이상인 계정만 찾고 싶을 때</mark>
#
# 기준값에는 대문자 이름을 붙여 한 곳에서 바꿉니다.

# %%
from collections import Counter  # 항목별 횟수를 세는 도구

THRESHOLD = 2  # 확인이 필요한 기준 횟수
# 실패 계정별 횟수를 계산합니다.
counts = Counter(["kim01", "kim01", "lee02", "park03", "kim01"])

for user, count in counts.items():  # 계정과 횟수를 함께 반복
    if count >= THRESHOLD:  # 기준 이상인지 확인
        print(f"확인 필요: {user} · {count}회")

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 3-5 · 기준 이상만 출력하기</font></h3></td></tr></table>
#
# 계정과 횟수를 한 쌍씩 꺼내면서, 횟수가 기준 이상인 계정 이름만 출력하시오.
#
# - 기준값 `THRESHOLD` 는 이미 있습니다. 숫자 `2` 를 직접 쓰지 않습니다.
#
# | | |
# |---|---|
# | 주어지는 값 | `THRESHOLD = 2` · `counts` |
# | 🎯 나와야 하는 결과 | `kim01` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. 문제 3-4처럼 `.items()`로 계정과 횟수를 함께 꺼냅니다.
# 2. 반복 안에 `if count >= THRESHOLD:`를 넣습니다. 숫자 `2`를 직접 쓰지 않고 이름을 씁니다.
# 3. 조건이 참일 때 계정 이름(`user`)만 출력합니다.
# 4. `lee02`는 1회라 기준에 못 미쳐 출력되지 않습니다.
#
# 그래도 막히면 맨 아래 정답 3-5 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %%
from collections import Counter
THRESHOLD = 2
counts = Counter(["kim01", "kim01", "lee02"])

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 3-6 · 기준 바꿔 다시 보기</font></h3></td></tr></table>
#
# 기준이 3으로 바뀌었습니다. 기준 이상인 계정과 횟수를 출력하시오.
#
# - 아래 코드는 문제 3-5와 같은 모양입니다. 기준값에 이름을 붙여 두었기 때문에 고칠 곳이 없습니다.
# - 출력 줄은 `print(f"{user} · {count}회")` 를 그대로 쓰면 됩니다.
#
# | | |
# |---|---|
# | 주어지는 값 | 계정별 실패 횟수 |
# | 🎯 나와야 하는 결과 | `park03 · 3회` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. `THRESHOLD = 3`으로 기준이 이미 바뀌어 있습니다.
# 2. 아래 코드는 문제 3-5와 같은 모양입니다. 기준값 이름만 쓰면 숫자를 고칠 곳이 없습니다.
# 3. 출력만 `f"{user} · {count}회"` 모양으로 바꿉니다.
# 4. `kim01`은 2회라 이번에는 빠집니다.
#
# 그래도 막히면 맨 아래 정답 3-6 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %%
from collections import Counter
THRESHOLD = 3
counts = Counter(["kim01", "kim01", "lee02", "park03", "park03", "park03"])

# %% [markdown]
# ### <mark style="display:block; background:#bbdefb; color:#1a1a1a; padding:6px 12px; border-radius:4px">3.정리 📋 한눈에</mark>
#
# | 쓰는 법 | 뜻 |
# |---|---|
# | `set(목록)` | 중복을 지워 서로 다른 값만 남긴다 |
# | `Counter(목록)` | 값마다 몇 번 나왔는지 센다 |
# | `counts.items()` | 값과 횟수를 한 쌍씩 꺼낸다 |
# | `THRESHOLD = 2` | 여러 곳에서 쓸 기준값에 이름을 붙인다 |

# %% [markdown]
# ---
#
# # <mark style="display:block; background:#ffe0b2; color:#1a1a1a; padding:6px 12px; border-radius:4px">4교시 (12:00–12:50) · 오전 종합 실습</mark>

# %% [markdown]
# ---
#
# ## <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">4 · 오전 종합 — 로그 목록에서 확인할 계정을 찾는다</mark>
#
# 같은 데이터로 조건문 → 반복문 → Counter → 기준값 판정을 이어 갑니다.

# %% [markdown]
# <div style="background:#e8f5e9; color:#17351f; padding:12px 16px; border-radius:8px"><strong>🔎 코드를 읽는 법</strong><br>한 번에 완성하려 하지 말고 출력으로 중간 결과를 확인하세요. 목록을 만든 뒤 세고, 센 뒤 기준과 비교합니다.</div>

# %% [markdown]
# ### 오늘 사용할 로그
#
# 아래 셀을 먼저 실행합니다. 이후 문제는 이 `logs`를 계속 사용합니다.

# %%
# 오전 종합 실습에서 사용할 로그를 준비합니다.
logs = [
    {"time": "09:01", "user": "kim01", "ip": "10.0.3.21", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:03", "user": "lee02", "ip": "10.0.7.5", "action": "LOGIN", "result": "OK"},
    {"time": "09:05", "user": "kim01", "ip": "10.0.3.21", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:08", "user": "park03", "ip": "10.0.9.8", "action": "FILE_OPEN", "result": "OK"},
    {"time": "09:11", "user": "kim01", "ip": "10.0.3.21", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:14", "user": "park03", "ip": "10.0.9.8", "action": "LOGIN", "result": "FAIL"},
]

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 4-1 · 모든 로그 확인하기</font></h3></td></tr></table>
#
# `logs` 를 하나씩 꺼내, 로그마다 시각·계정·동작·결과를 한 줄로 출력하시오.
#
# - 출력 줄은 `print(log["time"], log["user"], log["action"], log["result"])` 를 그대로 쓰면 됩니다.
#
# | | |
# |---|---|
# | 주어지는 값 | 위 `logs` |
# | 🎯 나와야 하는 결과 | `09:01 kim01 LOGIN FAIL` 등 6줄 |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. 이 문제 위의 `logs` 셀을 먼저 실행했는지 확인합니다.
# 2. `for log in logs:`로 딕셔너리를 하나씩 꺼냅니다.
# 3. `print()` 안에 값 네 개를 쉼표로 이어 넣습니다: `log["time"]`, `log["user"]`, `log["action"]`, `log["result"]`.
# 4. 쉼표로 이은 값은 사이에 빈칸이 하나씩 들어가 출력됩니다.
#
# 그래도 막히면 맨 아래 정답 4-1 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 4-2 · 로그인 실패만 모으기</font></h3></td></tr></table>
#
# 동작이 `LOGIN` 이고 결과가 `FAIL` 인 로그의 계정만 `failed_users` 에 모아 출력하시오.
#
# - 조건 두 개를 `and` 로 잇습니다. 문제 2-3과 같은 모양입니다.
# - 같은 계정이 여러 번 들어가는 것이 맞습니다.
#
# | | |
# |---|---|
# | 주어지는 값 | 위 `logs` |
# | 🎯 나와야 하는 결과 | `['kim01', 'kim01', 'kim01', 'park03']` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. 문제 2-3과 같은 모양입니다. 빈 목록 → `for` → `if` → `append` 순서입니다.
# 2. 이번에는 조건이 두 개라 `and`로 잇습니다: `log["action"] == "LOGIN"`, `log["result"] == "FAIL"`.
# 3. 조건이 참일 때 `failed_users.append(log["user"])`를 합니다.
# 4. 반복이 끝난 뒤 목록을 출력합니다. 같은 계정이 여러 번 들어가는 것이 맞습니다.
#
# 그래도 막히면 맨 아래 정답 4-2 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %%
failed_users = []

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 4-3 · 실패한 사람과 건수 비교하기</font></h3></td></tr></table>
#
# 문제 4-2의 `failed_users` 로 두 숫자를 각각 출력하시오.
#
# | 무엇 | 어떻게 세나 | 출력 모양 |
# |---|---|---|
# | 서로 다른 계정 수 | 중복을 지우고 센다 | `실패 계정 2명` |
# | 전체 실패 건수 | 목록을 그대로 센다 | `실패 로그 4건` |
#
# | | |
# |---|---|
# | 주어지는 값 | 문제 4-2의 `failed_users` |
# | 🎯 나와야 하는 결과 | `실패 계정 2명`<br>`실패 로그 4건` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. 문제 4-2 셀을 먼저 실행해야 `failed_users`가 있습니다. `NameError`가 나면 4-2부터 다시 실행합니다.
# 2. 사람 수는 중복을 지운 뒤 셉니다: `len(set(failed_users))`.
# 3. 건수는 목록 그대로 셉니다: `len(failed_users)`.
# 4. f-string 두 줄로 「실패 계정 N명」「실패 로그 N건」을 출력합니다.
#
# 그래도 막히면 맨 아래 정답 4-3 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 4-4 · 계정별 로그인 실패 횟수</font></h3></td></tr></table>
#
# 문제 4-2의 `failed_users` 로 계정별 실패 횟수를 세어 한 줄씩 출력하시오.
#
# - `Counter` 로 센 뒤 `.items()` 로 꺼냅니다. 문제 3-4와 같은 모양입니다.
# - 출력 줄은 `print(f"{user}: {count}회")` 를 그대로 쓰면 됩니다.
#
# | | |
# |---|---|
# | 주어지는 값 | 문제 4-2의 `failed_users` |
# | 🎯 나와야 하는 결과 | `kim01: 3회`<br>`park03: 1회` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. 문제 4-2의 `failed_users`를 씁니다. 없으면 4-2부터 다시 실행합니다.
# 2. `counts = Counter(failed_users)`로 계정별 횟수를 셉니다.
# 3. `for user, count in counts.items():`로 한 쌍씩 꺼냅니다.
# 4. `f"{user}: {count}회"` 모양으로 출력합니다.
#
# 그래도 막히면 맨 아래 정답 4-4 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %%
from collections import Counter

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 4-5 · 확인할 계정 찾기</font></h3></td></tr></table>
#
# 문제 4-4의 `counts` 에서 기준 이상인 계정만 골라 출력하시오.
#
# - 기준은 `THRESHOLD = 2` 입니다.
# - 출력 줄은 `print(f"확인 필요: {user} · {count}회")` 를 그대로 쓰면 됩니다.
#
# | | |
# |---|---|
# | 주어지는 값 | `THRESHOLD = 2` |
# | 🎯 나와야 하는 결과 | `확인 필요: kim01 · 3회` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. 문제 4-4의 `counts`를 다시 씁니다. 없으면 4-2, 4-4를 차례로 실행합니다.
# 2. `THRESHOLD = 2`는 이미 있습니다.
# 3. 문제 3-5처럼 반복 안에 `if count >= THRESHOLD:`를 넣습니다.
# 4. `f"확인 필요: {user} · {count}회"` 모양으로 출력합니다.
#
# 그래도 막히면 맨 아래 정답 4-5 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %%
THRESHOLD = 2

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">⭐ 도전 4-6 · IP별 로그인 실패 횟수 (선택)</font></h3></td></tr></table>
#
# 먼저 끝낸 사람만 풉니다. 계정 대신 IP를 기준으로 로그인 실패 횟수를 세어 출력하시오.
#
# | | |
# |---|---|
# | 주어지는 값 | 위 `logs` |
# | 🎯 나와야 하는 결과 | `10.0.3.21: 3회`<br>`10.0.9.8: 1회` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. 문제 4-2와 같은 모양인데, 목록에 계정 대신 IP를 담습니다: `log["ip"]`.
# 2. 빈 목록 이름은 `failed_ips`로 새로 짓습니다.
# 3. 다 모았으면 `Counter(failed_ips)`로 IP별 횟수를 셉니다.
# 4. `.items()`로 꺼내 `f"{ip}: {count}회"` 모양으로 출력합니다.
#
# 그래도 막히면 맨 아래 정답 4-6 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %%
from collections import Counter

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">⭐ 도전 4-7 · 위험도 붙이기 (선택)</font></h3></td></tr></table>
#
# 문제 4-4의 계정별 횟수에 위험도를 붙이시오. 3회 이상은 「높음」, 2회 이상은 「주의」, 나머지는 「낮음」입니다.
#
# | | |
# |---|---|
# | 주어지는 값 | 문제 4-4의 `counts` |
# | 🎯 나와야 하는 결과 | `kim01: 3회 · 높음`<br>`park03: 1회 · 낮음` |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. 문제 4-4의 `counts`를 씁니다.
# 2. `.items()` 반복 안에 1.3의 `if` → `elif` → `else` 세 갈래를 넣습니다.
# 3. 큰 기준(`>= 3`)을 먼저 검사합니다. 갈래마다 `level = "높음"`처럼 이름에 담아 둡니다.
# 4. 세 갈래가 끝난 뒤 `f"{user}: {count}회 · {level}"`을 한 번만 출력합니다.
#
# 그래도 막히면 맨 아래 정답 4-7 셀의 「코드 표시」를 누릅니다.
#
# </details>

# %%
from collections import Counter

# %% [markdown]
# ### <mark style="display:block; background:#ffecb3; color:#1a1a1a; padding:6px 12px; border-radius:4px">4.8 오늘 만든 코드를 파일로 남기고 싶을 때</mark>
#
# 1. 지금까지 쓴 셀은 코랩을 닫으면 사라집니다. 코드를 .py 파일로 구글 드라이브에 저장하면 남습니다.
# 2. 파일은 내 드라이브의 `agent_core` 폴더에 모입니다. 날마다 한 파일씩 쌓여 과정이 끝나면 내 포트폴리오 폴더가 됩니다.
# 3. 나중에 VS Code로 넘어갈 때 이 폴더를 그대로 엽니다.

# %% [markdown]
# 1. 아래 셀을 실행하면 구글 계정 선택 창이 뜹니다. 코랩을 연 계정을 고르고 허용을 누릅니다.
# 2. `Mounted at /content/drive`가 나오면 연결된 것입니다.
# 3. 코랩 연결이 끊기면 이 셀과 다음 셀을 다시 실행합니다. 드라이브에 저장한 파일은 그대로 있습니다.

# %%
from google.colab import drive  # 구글 드라이브를 코랩에 연결하는 도구
drive.mount("/content/drive")

# %% [markdown]
# `agent_core` 폴더를 만들고 그 안으로 들어갑니다. 이 셀을 빼먹으면 파일이 다른 곳에 저장되거나 `FileNotFoundError`가 납니다.

# %%
# !mkdir -p /content/drive/MyDrive/agent_core
# %cd /content/drive/MyDrive/agent_core

# %% [markdown]
# 1. 셀 맨 첫 줄에 `%%writefile 파일이름.py`를 쓰면, 그 셀의 코드는 실행되지 않고 파일로 저장됩니다. `Writing 파일이름.py`가 나오면 저장된 것입니다.
# 2. `!python 파일이름.py`는 저장한 파일을 프로그램처럼 실행합니다. 앞의 `!`는 「터미널 명령」이라는 표시입니다.
# 3. 같은 이름으로 다시 저장하면 덮어씁니다(`Overwriting …`). 고친 뒤 두 셀을 차례로 다시 실행하면 됩니다.

# %%
# %%writefile hello.py
print("agent_core에 저장된 첫 파일입니다")

# %%
# !python hello.py

# %% [markdown]
# <table width="100%" bgcolor="#A5D6A7"><tr><td bgcolor="#A5D6A7"><h3><font color="#1B5E20">✍️ 문제 4-8 · 확인할 계정 찾기를 파일로 저장하기</font></h3></td></tr></table>
#
# 문제 4-2·4-4·4-5에서 쓴 코드를 이어 붙여 파일로 저장하고 실행하시오.
#
# | 항목 | 내용 |
# |---|---|
# | 저장할 파일 | `day1_find_suspects.py` |
# | 하는 일 | ① 로그인 실패 계정을 모으고 ② `Counter` 로 세어 ③ 기준 이상인 계정을 출력한다 |
# | 실행 | 아래 `!python day1_find_suspects.py` 셀 |
#
# | | |
# |---|---|
# | 주어지는 값 | 아래 셀의 `logs` · `THRESHOLD = 2` |
# | 🎯 나와야 하는 결과 | `확인 필요: kim01 · 3회` (아래 `!python` 셀에서) |
#
# <details>
# <summary>▸ 힌트 보기</summary>
#
# 1. 첫 줄 `%%writefile day1_find_suspects.py`는 지우지 않습니다. 이 줄이 맨 위에 있어야 파일로 저장됩니다.
# 2. `logs` 아래에 문제 4-2의 코드(빈 목록 → `for` → `if` → `append`)를 붙입니다.
# 3. 이어서 문제 4-4·4-5처럼 `Counter`로 세고, 기준 이상인 계정만 출력합니다.
# 4. 셀을 실행하면 결과 대신 `Writing …`만 나옵니다. 결과는 바로 아래 `!python` 셀을 실행해야 보입니다.
# 5. `No such file`이 나오면 4.8의 드라이브 연결 셀과 폴더 이동 셀을 먼저 실행합니다.
#
# 그래도 막히면 맨 아래 정답 4-8 셀의 「코드 표시」를 누릅니다. 정답 셀에는 파일 안에 들어갈 코드만 있습니다.
#
# </details>

# %%
# %%writefile day1_find_suspects.py
from collections import Counter

THRESHOLD = 2
logs = [
    {"time": "09:01", "user": "kim01", "ip": "10.0.3.21", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:03", "user": "lee02", "ip": "10.0.7.5", "action": "LOGIN", "result": "OK"},
    {"time": "09:05", "user": "kim01", "ip": "10.0.3.21", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:08", "user": "park03", "ip": "10.0.9.8", "action": "FILE_OPEN", "result": "OK"},
    {"time": "09:11", "user": "kim01", "ip": "10.0.3.21", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:14", "user": "park03", "ip": "10.0.9.8", "action": "LOGIN", "result": "FAIL"},
]

# %%
# !python day1_find_suspects.py

# %% [markdown]
# 드라이브의 `agent_core` 폴더를 열어 보면 `hello.py`와 `day1_find_suspects.py`가 있습니다. 코랩 왼쪽 아래 터미널 버튼을 눌러 `cd /content/drive/MyDrive/agent_core` 다음 `python day1_find_suspects.py`를 쳐도 같은 결과가 나옵니다.

# %% [markdown]
# ---
#
# # <mark style="display:block; background:#c8e6c9; color:#1a1a1a; padding:6px 12px; border-radius:4px">정답 · 먼저 풀어 본 뒤에 엽니다</mark>
#
# 1. 각 셀은 제목만 보입니다. 「코드 표시」를 누르면 코드가 열립니다.
# 2. 정답 셀은 혼자서도 실행됩니다. ▶를 눌러 결과를 비교해 보세요.
# 3. 답이 달라도 결과가 같으면 맞은 것입니다. 코드를 쓰는 방법은 여러 가지입니다.

# %%
#@title 정답 1-1 { display-mode: "form" }
result = "FAIL"

if result == "FAIL":
    print("확인 필요")

# %%
#@title 정답 1-2 { display-mode: "form" }
result = "OK"

if result == "OK":
    print("정상")
else:
    print("실패")

# %%
#@title 정답 1-3 { display-mode: "form" }
fail_count = 3

if fail_count >= 5:
    print("높음")
elif fail_count >= 2:
    print("주의")
else:
    print("낮음")

# %%
#@title 정답 1-4 { display-mode: "form" }
action = "LOGIN"
result = "FAIL"

if action == "LOGIN" and result == "FAIL":
    print("로그인 실패")

# %%
#@title 정답 1-5 { display-mode: "form" }
user = "kim01"
fail_count = 6

if user == "admin" or fail_count >= 5:
    print("즉시 확인")

# %%
#@title 정답 2-1 { display-mode: "form" }
users = ["kim01", "lee02", "park03"]

for user in users:
    print(user)

# %%
#@title 정답 2-2 { display-mode: "form" }
logs = [
    {"user": "kim01", "result": "FAIL"},
    {"user": "lee02", "result": "OK"},
    {"user": "park03", "result": "FAIL"},
]

for log in logs:
    if log["result"] == "FAIL":
        print(log["user"])

# %%
#@title 정답 2-3 { display-mode: "form" }
logs = [
    {"user": "kim01", "result": "FAIL"},
    {"user": "lee02", "result": "OK"},
    {"user": "park03", "result": "FAIL"},
]
failed_users = []

for log in logs:
    if log["result"] == "FAIL":
        failed_users.append(log["user"])

print(failed_users)

# %%
#@title 정답 2-4 { display-mode: "form" }
logs = [
    {"result": "FAIL"}, {"result": "OK"},
    {"result": "FAIL"}, {"result": "FAIL"},
]
fail_count = 0

for log in logs:
    if log["result"] == "FAIL":
        fail_count = fail_count + 1

print(fail_count)

# %%
#@title 정답 2-5 { display-mode: "form" }
for number in range(5):
    print(f"{number + 1}번째 점검")

# %%
#@title 정답 2-6 { display-mode: "form" }
count = 0

while count < 3:
    count = count + 1
    print(count)

# %%
#@title 정답 3-1 { display-mode: "form" }
failed_users = ["kim01", "kim01", "lee02", "kim01"]

unique_users = set(failed_users)
print(len(unique_users))

# %%
#@title 정답 3-2 { display-mode: "form" }
from collections import Counter
failed_users = ["kim01", "kim01", "lee02", "kim01"]

counts = Counter(failed_users)
print(counts)

# %%
#@title 정답 3-3 { display-mode: "form" }
from collections import Counter
counts = Counter(["kim01", "kim01", "lee02", "kim01"])

print(counts["kim01"])

# %%
#@title 정답 3-4 { display-mode: "form" }
from collections import Counter
counts = Counter(["kim01", "kim01", "lee02"])

for user, count in counts.items():
    print(f"{user}: {count}회")

# %%
#@title 정답 3-5 { display-mode: "form" }
from collections import Counter
THRESHOLD = 2
counts = Counter(["kim01", "kim01", "lee02"])

for user, count in counts.items():
    if count >= THRESHOLD:
        print(user)

# %%
#@title 정답 3-6 { display-mode: "form" }
from collections import Counter
THRESHOLD = 3
counts = Counter(["kim01", "kim01", "lee02", "park03", "park03", "park03"])

for user, count in counts.items():
    if count >= THRESHOLD:
        print(f"{user} · {count}회")

# %%
#@title 정답 4-1 { display-mode: "form" }
logs = [
    {"time": "09:01", "user": "kim01", "ip": "10.0.3.21", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:03", "user": "lee02", "ip": "10.0.7.5", "action": "LOGIN", "result": "OK"},
    {"time": "09:05", "user": "kim01", "ip": "10.0.3.21", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:08", "user": "park03", "ip": "10.0.9.8", "action": "FILE_OPEN", "result": "OK"},
    {"time": "09:11", "user": "kim01", "ip": "10.0.3.21", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:14", "user": "park03", "ip": "10.0.9.8", "action": "LOGIN", "result": "FAIL"},
]

for log in logs:
    print(log["time"], log["user"], log["action"], log["result"])

# %%
#@title 정답 4-2 { display-mode: "form" }
logs = [
    {"time": "09:01", "user": "kim01", "ip": "10.0.3.21", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:03", "user": "lee02", "ip": "10.0.7.5", "action": "LOGIN", "result": "OK"},
    {"time": "09:05", "user": "kim01", "ip": "10.0.3.21", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:08", "user": "park03", "ip": "10.0.9.8", "action": "FILE_OPEN", "result": "OK"},
    {"time": "09:11", "user": "kim01", "ip": "10.0.3.21", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:14", "user": "park03", "ip": "10.0.9.8", "action": "LOGIN", "result": "FAIL"},
]

failed_users = []
for log in logs:
    if log["action"] == "LOGIN" and log["result"] == "FAIL":
        failed_users.append(log["user"])

print(failed_users)

# %%
#@title 정답 4-3 { display-mode: "form" }
failed_users = ["kim01", "kim01", "kim01", "park03"]  # 문제 4-2의 결과

print(f"실패 계정 {len(set(failed_users))}명")
print(f"실패 로그 {len(failed_users)}건")

# %%
#@title 정답 4-4 { display-mode: "form" }
from collections import Counter
failed_users = ["kim01", "kim01", "kim01", "park03"]  # 문제 4-2의 결과

counts = Counter(failed_users)
for user, count in counts.items():
    print(f"{user}: {count}회")

# %%
#@title 정답 4-5 { display-mode: "form" }
from collections import Counter
failed_users = ["kim01", "kim01", "kim01", "park03"]  # 문제 4-2의 결과
THRESHOLD = 2

counts = Counter(failed_users)
for user, count in counts.items():
    if count >= THRESHOLD:
        print(f"확인 필요: {user} · {count}회")

# %%
#@title 정답 4-6 { display-mode: "form" }
from collections import Counter
logs = [
    {"time": "09:01", "user": "kim01", "ip": "10.0.3.21", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:03", "user": "lee02", "ip": "10.0.7.5", "action": "LOGIN", "result": "OK"},
    {"time": "09:05", "user": "kim01", "ip": "10.0.3.21", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:08", "user": "park03", "ip": "10.0.9.8", "action": "FILE_OPEN", "result": "OK"},
    {"time": "09:11", "user": "kim01", "ip": "10.0.3.21", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:14", "user": "park03", "ip": "10.0.9.8", "action": "LOGIN", "result": "FAIL"},
]

failed_ips = []
for log in logs:
    if log["action"] == "LOGIN" and log["result"] == "FAIL":
        failed_ips.append(log["ip"])

counts = Counter(failed_ips)
for ip, count in counts.items():
    print(f"{ip}: {count}회")

# %%
#@title 정답 4-7 { display-mode: "form" }
from collections import Counter
failed_users = ["kim01", "kim01", "kim01", "park03"]  # 문제 4-2의 결과

counts = Counter(failed_users)
for user, count in counts.items():
    if count >= 3:
        level = "높음"
    elif count >= 2:
        level = "주의"
    else:
        level = "낮음"
    print(f"{user}: {count}회 · {level}")

# %%
#@title 정답 4-8 { display-mode: "form" }
from collections import Counter

THRESHOLD = 2
logs = [
    {"time": "09:01", "user": "kim01", "ip": "10.0.3.21", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:03", "user": "lee02", "ip": "10.0.7.5", "action": "LOGIN", "result": "OK"},
    {"time": "09:05", "user": "kim01", "ip": "10.0.3.21", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:08", "user": "park03", "ip": "10.0.9.8", "action": "FILE_OPEN", "result": "OK"},
    {"time": "09:11", "user": "kim01", "ip": "10.0.3.21", "action": "LOGIN", "result": "FAIL"},
    {"time": "09:14", "user": "park03", "ip": "10.0.9.8", "action": "LOGIN", "result": "FAIL"},
]

failed_users = []
for log in logs:
    if log["action"] == "LOGIN" and log["result"] == "FAIL":
        failed_users.append(log["user"])

counts = Counter(failed_users)
for user, count in counts.items():
    if count >= THRESHOLD:
        print(f"확인 필요: {user} · {count}회")
